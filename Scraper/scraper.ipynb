# %%
import pandas as pd
import numpy as np

# %%
#open csv at Data/people.csv as dataframe
people = pd.read_csv('../Data/people.csv')
people.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15036 entries, 0 to 15035
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   identifier            15036 non-null  object
#  1   name                  15036 non-null  object
#  2   unique_name           15036 non-null  object
#  3   key_bcci              1321 non-null   object
#  4   key_bcci_2            8 non-null      object
#  5   key_bigbash           296 non-null    float64
#  6   key_cricbuzz          22 non-null     float64
#  7   key_cricheroes        111 non-null    float64
#  8   key_crichq            24 non-null     float64
#  9   key_cricinfo          14991 non-null  float64
#  10  key_cricinfo_2        90 non-null     float64
#  11  key_cricingif         130 non-null    float64
#  12  key_cricketarchive    4416 non-null   float64
#  13  key_cricketarchive_2  1 non-null      float64
#  14  key_nvplay            240 non-null    object
#  15  key_nvplay_2          1 non-null      object
#  16  key_opta              67 non-null     float64
#  17  key_opta_2            1 non-null      float64
#  18  key_pulse             2010 non-null   float64
#  19  key_pulse_2           13 non-null     float64
# dtypes: float64(13), object(7)
# memory usage: 2.3+ MB

# %%
#open csv at Data/people.csv as dataframe
names = pd.read_csv('../Data/names.csv')
names.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7214 entries, 0 to 7213
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   identifier  7214 non-null   object
#  1   name        7214 non-null   object
# dtypes: object(2)
# memory usage: 112.8+ KB

# %%
people.head()
# Out:
#   identifier           name    unique_name key_bcci key_bcci_2  key_bigbash  \
# 0   b4a23876  AAA Amsterdam  AAA Amsterdam      NaN        NaN          NaN
# 1   482762af      AA Adeoye      AA Adeoye      NaN        NaN          NaN
# 2   4b0e3049     AA Alleyne     AA Alleyne      NaN        NaN          NaN
# 3   fd3c5c00      AAA Patel      AAA Patel      NaN        NaN          NaN
# 4   bc005f0d      AAA White      AAA White      NaN        NaN          NaN
#
#    key_cricbuzz  key_cricheroes  key_crichq  key_cricinfo  key_cricinfo_2  \
# 0           NaN             NaN         NaN      772407.0             NaN
# 1           NaN             NaN         NaN      380588.0             NaN
# 2           NaN             NaN         NaN      661441.0             NaN
# 3           NaN             NaN         NaN     1163136.0             NaN
# 4           NaN             NaN         NaN      474307.0             NaN
#
#    key_cricingif  key_cricketarchive  key_cricketarchive_2 key_nvplay  \
# 0            NaN                 NaN                   NaN        NaN
# 1            NaN                 NaN                   NaN        NaN
# 2            NaN           1512811.0                   NaN        NaN
# 3            NaN                 NaN                   NaN        NaN
# 4            NaN                 NaN                   NaN        NaN
#
#   key_nvplay_2  key_opta  key_opta_2  key_pulse  key_pulse_2
# 0          NaN       NaN         NaN        NaN          NaN
# 1          NaN       NaN         NaN        NaN          NaN
# 2          NaN       NaN         NaN    18542.0          NaN
# 3          NaN       NaN         NaN        NaN          NaN
# 4          NaN       NaN         NaN        NaN          NaN

# %%
names.head()
# Out:
#   identifier        name
# 0   4b0e3049     Alleyne
# 1   4b0e3049   A Alleyne
# 2   6a58e069   A A Bamal
# 3   6a58e069  Arun Bamal
# 4   b690f34a   A A Barot

# %%
# Drop all columns except identifier, name_x, name_y, unique_name, key_cricinfo
people = people[['identifier', 'name', 'unique_name', 'key_cricinfo']]

#use identifier as index
people.set_index('identifier', inplace=True)
names.set_index('identifier', inplace=True)

# %%
names.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7214 entries, 4b0e3049 to 9bf23c13
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    7214 non-null   object
# dtypes: object(1)
# memory usage: 112.7+ KB

# %%
names_from_people_arr = people[['name', 'unique_name']].values
# names_from_people_arr.shape # (15036, 2)

names_from_people_arr
# Out:
# array([['AAA Amsterdam', 'AAA Amsterdam'],
#        ['AA Adeoye', 'AA Adeoye'],
#        ['AA Alleyne', 'AA Alleyne'],
#        ...,
#        ['Zulqarnain Haider', 'Zulqarnain Haider (2)'],
#        ['Zulufat Mutoniwase', 'Zulufat Mutoniwase'],
#        ['Zumika Azmi', 'Zumika Azmi']], dtype=object)

# %%
# Add new column to people with the other names based on the identifier
names_from_names_arr = people.index.map(lambda x: names[names.index == x]['name'].values).values
names_from_names_arr
# Out:
# array([array([], dtype=object), array([], dtype=object),
#        array(['Alleyne', 'A Alleyne'], dtype=object), ...,
#        array([], dtype=object), array([], dtype=object),
#        array([], dtype=object)], dtype=object)

# %%
all_names : list[list[str]] = [None] * names_from_people_arr.shape[0]
for i in range(names_from_people_arr.shape[0]):
	all_names[i] = np.unique(np.concatenate([names_from_people_arr[i], names_from_names_arr[i]]))

all_names
# Out:
# [array(['AAA Amsterdam'], dtype=object),
#  array(['AA Adeoye'], dtype=object),
#  array(['A Alleyne', 'AA Alleyne', 'Alleyne'], dtype=object),
#  array(['AAA Patel'], dtype=object),
#  array(['AAA White'], dtype=object),
#  array(['AA Baig'], dtype=object),
#  array(['A A Bamal', 'AA Bamal', 'Arun Bamal'], dtype=object),
#  array(['AA Banner'], dtype=object),
#  array(['A A Barot', 'AA Barot', 'Avi Barot'], dtype=object),
#  array(['AA Bevilaqua'], dtype=object),
#  array(['AA Bilakhia'], dtype=object),
#  array(['A A Chakraborty', 'AA Chakraborty', 'Abhijit Chakraborty'],
#        dtype=object),
#  array(['A Chavan', 'AA Chavan'], dtype=object),
#  array(['AA Choudhury'], dtype=object),
#  array(['A Adams'], dtype=object),
#  array(['A Adekunle'], dtype=object),
#  array(['AA Deshpande'], dtype=object),
#  array(['AA Donald', 'Allan Donald'], dtype=object),
#  array(['Aaftab Alam Khan'], dtype=object),
#  array(['AA Gajic'], dtype=object),
#  array(['AA Gordon'], dtype=object),
#  array(['AAhan Achar', 'AG Achar'], dtype=object),
#  array(['A Herwadkar', 'AA Herwadkar'], dtype=object),
#  array(['A Ahmadhel'], dtype=object),
#  array(['AA Hussein'], dtype=object),
#  array(['A Aikenhead'], dtype=object),
#  array(['AAIP Bastari'], dtype=object),
#  array(['A Aitken'], dtype=object),
#  array(['AA Jangoo'], dtype=object),
#  array(['AA Jasani'], dtype=object),
#  array(['A Jhunjhunwala', 'AA Jhunjhunwala'], dtype=object),
#  array(['AA Kargave'], dtype=object),
#  array(['Aakarshit Gomel'], dtype=object),
#  array(['Aakash Chand'], dtype=object),
#  array(['Aakash Verma'], dtype=object),
#  array(['AA Kazi', 'Abrar Kazi'], dtype=object),
#  array(['A Amado'], dtype=object),
#  array(['AA Mailey', 'Arthur Mailey'], dtype=object),
#  array(['AA Mallett', 'Ashley Mallett'], dtype=object),
#  array(['AAM Eliane'], dtype=object),
#  array(['Aamer Azmat'], dtype=object),
#  array(['Aamer Ikram'], dtype=object),
#  array(['Aamer Jamal'], dtype=object),
#  array(['Aamer Malik'], dtype=object),
#  array(['Aamer Nazir', 'Aamir Nazir'], dtype=object),
#  array(['Aamer Sohail', 'Aamir Sohail'], dtype=object),
#  array(['A Yamim', 'Aamer Yamin'], dtype=object),
#  array(['Aamir Aziz'], dtype=object),
#  array(['A Gani', 'Aamir', 'Aamir Gani'], dtype=object),
#  array(['Aamir Javed'], dtype=object),
#  array(['A Kaleem', 'Aamer Kaleem', 'Aamir Kaleem'], dtype=object),
#  array(['Aamir Lal'], dtype=object),
#  array(['AA Moiane'], dtype=object),
#  array(['AA Mulla'], dtype=object),
#  array(['Aanand Pandey'], dtype=object),
#  array(['AA Navicha'], dtype=object),
#  array(['A Andrew', 'Annica Andrew'], dtype=object),
#  array(['A Andrews'], dtype=object),
#  array(['A Andriani'], dtype=object),
#  array(['AA Noffke'], dtype=object),
#  array(['Aanshul Gupta'], dtype=object),
#  array(['A Obanda', 'AA Obanda'], dtype=object),
#  array(['AA Onikoyi'], dtype=object),
#  array(['AA Paradkar'], dtype=object),
#  array(['A Patil', 'AA Patil'], dtype=object),
#  array(['A Atkinson', 'AAP Atkinson', 'Atkinson'], dtype=object),
#  array(['AA Premji'], dtype=object),
#  array(['AAP Rivero', 'Perez Rivero Agustin'], dtype=object),
#  array(['Aaqib Javed'], dtype=object),
#  array(['Aaqib Khan'], dtype=object),
#  array(['Aaqib Sulehri'], dtype=object),
#  array(['AA Rahayu'], dtype=object),
#  array(['A Aravinddaraj', 'Aravind'], dtype=object),
#  array(['A Argyropoulou'], dtype=object),
#  array(['A Sheikh', 'Aarif Sheikh'], dtype=object),
#  array(['Aarnav Patel'], dtype=object),
#  array(['A Beard', 'AP Beard', 'Aaron Beard', 'Beard'], dtype=object),
#  array(['Aaron Campbell'], dtype=object),
#  array(['A Jones', 'Aaron Jones'], dtype=object),
#  array(['A Arroz'], dtype=object),
#  array(['Aarya Desai'], dtype=object),
#  array(['AA Sanguelkar'], dtype=object),
#  array(['A A Sanklecha', 'AA Sanklecha', 'Anupam Sanklecha'], dtype=object),
#  array(['AA Sarwate'], dtype=object),
#  array(['AA Shafique'], dtype=object),
#  array(['A Ashish Reddy', 'AA Reddy', 'Ashish Reddy'], dtype=object),
#  array(['A Ashok'], dtype=object),
#  array(['A Ashokan', 'Ashokan'], dtype=object),
#  array(['Aasif Iqbal'], dtype=object),
#  array(['Aasif Sheikh'], dtype=object),
#  array(['A Askari'], dtype=object),
#  array(['AAS Silva'], dtype=object),
#  array(['A Athanaze'], dtype=object),
#  array(['A Awasthi'], dtype=object),
#  array(['Aayan Afzal Khan'], dtype=object),
#  array(['A Ayre'], dtype=object),
#  array(['A Bacher', 'Ali Bacher'], dtype=object),
#  array(['A Badoni', 'Ayush Badoni'], dtype=object),
#  array(['A Bagai'], dtype=object),
#  array(['A Agarkar', 'AB Agarkar', 'Ajit Agarkar'], dtype=object),
#  array(['A Balbirnie', 'Andy Balbirnie'], dtype=object),
#  array(['A Barnes'], dtype=object),
#  array(['A Barty'], dtype=object),
#  array(['A Barath', 'AB Barath', 'Adrian Barath'], dtype=object),
#  array(['Abbas Afridi'], dtype=object),
#  array(['AA Baig', 'Abbas Ali Baig', 'Abbas Baig'], dtype=object),
#  array(['Abbas Ghani'], dtype=object),
#  array(['Abbas Saad'], dtype=object),
#  array(['AB Bhadoriya'], dtype=object),
#  array(['ABB Sangma'], dtype=object),
#  array(['AB Chawla'], dtype=object),
#  array(['Abdalah Lubega'], dtype=object),
#  array(['AB de Villiers'], dtype=object),
#  array(['A Dinda', 'AB Dinda', 'Ashoke Dinda'], dtype=object),
#  array(['Abdul Bangalzai'], dtype=object),
#  array(['Abdul Bashir'], dtype=object),
#  array(['Abdul Basith'], dtype=object),
#  array(['Abdul Ela Al Quraishi'], dtype=object),
#  array(['A Halim', 'Abdul Halim'], dtype=object),
#  array(['Abdul Haq'], dtype=object),
#  array(['Abdul Hashim'], dtype=object),
#  array(['Abdul Jabar'], dtype=object),
#  array(['Abdul Jabbar'], dtype=object),
#  array(['Abdul Jalali'], dtype=object),
#  array(['Abdul Kadir'], dtype=object),
#  array(['Abdulla Bhoola'], dtype=object),
#  array(['Abdullah Akbarjan'], dtype=object),
#  array(['Abdullah Akhunzada'], dtype=object),
#  array(['Abdullah Al Mamun'], dtype=object),
#  array(['Abdullah Al Mamun', 'Abdullah Al Mamun (2)'], dtype=object),
#  array(['Abdullah Bayoumy'], dtype=object),
#  array(['Abdullah Ghulam'], dtype=object),
#  array(['Abdullah Jasat'], dtype=object),
#  array(['Abdullah Mahmood'], dtype=object),
#  array(['Abdullah Mazari'], dtype=object),
#  array(['Abdullah Qureshi'], dtype=object),
#  array(['Abdullah Rana'], dtype=object),
#  array(['A Shafique', 'Abdullah Shafiq', 'Abdullah Shafique'], dtype=object),
#  array(['Abdullah Shahid'], dtype=object),
#  array(['Abdullah Sheikh'], dtype=object),
#  array(['Abdullah Syed'], dtype=object),
#  array(['Abdul Majid'], dtype=object),
#  array(['Abdul Majid Abbasi'], dtype=object),
#  array(['Abdul Malik'], dtype=object),
#  array(['Abdulmalik Jabarkhel'], dtype=object),
#  array(['Abdul Manan'], dtype=object),
#  array(['Abdul Mazid'], dtype=object),
#  array(['Abdul Muqeet'], dtype=object),
#  array(['Abdul Muqeet', 'Abdul Muqeet (2)'], dtype=object),
#  array(['Abdul Nabi'], dtype=object),
#  array(['Abdul Naser Baluch'], dtype=object),
#  array(['Abdul Nasir'], dtype=object),
#  array(['Abdul Nasir', 'Abdul Nasir (2)'], dtype=object),
#  array(['Abdul Qadir'], dtype=object),
#  array(['Abdul Qadir', 'Abdul Qadir Khan'], dtype=object),
#  array(['Abdul Rahman', 'Abdul Rahman Bhadelia'], dtype=object),
#  array(['Abdul Rahman', 'Abdul Rahman Rahmani'], dtype=object),
#  array(['Abdul Rahman', 'Mohammad Abdul Rahman'], dtype=object),
#  array(['Abdulrahman Dashti'], dtype=object),
#  array(['Abdul Rashid'], dtype=object),
#  array(['Abdul Rashid Karim'], dtype=object),
#  array(['A Razzaq', 'Abdul Razzaq', 'Abdur Razzaq'], dtype=object),
#  array(['Abdul Rehman', 'Abdul Rehman (2)'], dtype=object),
#  array(['Abdul Sadiq'], dtype=object),
#  array(['Abdul Salam'], dtype=object),
#  array(['A Samad', 'Abdul Samad'], dtype=object),
#  array(['Abdul Shakoor'], dtype=object),
#  array(['Abdul Shakoor', 'Abdul Shakoor (2)'], dtype=object),
#  array(['Abdul-Shakoor Rahimzei'], dtype=object),
#  array(['Abdul Stanikzai'], dtype=object),
#  array(['Abdul Waheed'], dtype=object),
#  array(['Abdul Wahid'], dtype=object),
#  array(['Abdul Wasi'], dtype=object),
#  array(['Abdur Rahman Sudais'], dtype=object),
#  array(['Abdur Rauf'], dtype=object),
#  array(['Abdur Razzak'], dtype=object),
#  array(['A Rehman', 'Abdur Rehman'], dtype=object),
#  array(['Abeera Waris'], dtype=object),
#  array(['Abeer Maryam'], dtype=object),
#  array(['A Begg', 'Andrew Begg'], dtype=object),
#  array(['A Beggs'], dtype=object),
#  array(['A Bengeri'], dtype=object),
#  array(['A Benjamin', 'Anika Benjamin', 'Annica Benjamin'], dtype=object),
#  array(['A Bester'], dtype=object),
#  array(['AB Fudadin', 'Assad Fudadin'], dtype=object),
#  array(['A Bhadauria'], dtype=object),
#  array(['A Bhagwat'], dtype=object),
#  array(['A Bhandari'], dtype=object),
#  array(['A Bhargava'], dtype=object),
#  array(['A Bharwad'], dtype=object),
#  array(['A Bhattarai'], dtype=object),
#  array(['Abhay'], dtype=object),
#  array(['Abhay Negi'], dtype=object),
#  array(['Abhijeet Ahuja'], dtype=object),
#  array(['Abhijeet', 'Abhijeet Saket'], dtype=object),
#  array(['Abhijit Bhattacharya'], dtype=object),
#  array(['Abhijit Roy', 'Abhijit Singha Roy', 'Avijit Singha Roy'],
#        dtype=object),
#  array(['Abhilasha Singh'], dtype=object),
#  array(['Abhilash Gogoi'], dtype=object),
#  array(['Abhilash Mallick'], dtype=object),
#  array(['Abhimanyu Chauhan'], dtype=object),
#  array(['A K Rana', 'AK Rana', 'Abhimanyu Rana'], dtype=object),
#  array(['Abhinav Dixit'], dtype=object),
#  array(['Abhinav Raman'], dtype=object),
#  array(['Abhinav Srivastava'], dtype=object),
#  array(['Abhiraj Singh'], dtype=object),
#  array(['Abhisek Das'], dtype=object),
#  array(['Abhishek Ahuja'], dtype=object),
#  array(['ABHISHEK BHANDARI', 'Abhishek Bhandari'], dtype=object),
#  array(['Abhishek Goswami'], dtype=object),
#  array(['Abhishek Gupta'], dtype=object),
#  array(['Abhishek Mohan'], dtype=object),
#  array(['Abhishek Pandey'], dtype=object),
#  array(['Abhishek Kumar Raman', 'Abhishek Raman'], dtype=object),
#  array(['Abhishek Sakuja', 'Sakuja'], dtype=object),
#  array(['A Sharma', 'Abhishek Sharma'], dtype=object),
#  array(['Abhishek Tanwar'], dtype=object),
#  array(['Abhishek Thakuri'], dtype=object),
#  array(['Abhishek Yadav'], dtype=object),
#  array(['AB Holder'], dtype=object),
#  array(['AB Howard', 'Anthony Howard', 'Tony Howard'], dtype=object),
#  array(['A Ali', 'Abid Ali'], dtype=object),
#  array(['A Bidari'], dtype=object),
#  array(['Abid Mushtaq'], dtype=object),
#  array(['Abid Mushtaq', 'Abid Mushtaq (2)'], dtype=object),
#  array(['A Bierwisch'], dtype=object),
#  array(['Abishek Porel'], dtype=object),
#  array(['A Bishnoi'], dtype=object),
#  array(['A Bisson'], dtype=object),
#  array(['AB Kamara'], dtype=object),
#  array(['AB Kaur'], dtype=object),
#  array(['AB Kookna'], dtype=object),
#  array(['AB London'], dtype=object),
#  array(['A McDonald', 'AB McDonald', 'Andrew McDonald'], dtype=object),
#  array(['AB Mengoumou'], dtype=object),
#  array(['A Bohara', 'Bohara'], dtype=object),
#  array(['A Bonora'], dtype=object),
#  array(['A Bosch'], dtype=object),
#  array(['A Bose'], dtype=object),
#  array(['AB Perrin'], dtype=object),
#  array(['Abraash Khan'], dtype=object),
#  array(['A Bramble'], dtype=object),
#  array(['Abrar Ahmed'], dtype=object),
#  array(['Abrar Bilal'], dtype=object),
#  array(['A Brindle'], dtype=object),
#  array(['A Brown', 'Alan Brown'], dtype=object),
#  array(['A Brown-Carrera'], dtype=object),
#  array(['Absar Khan'], dtype=object),
#  array(['AB Slebsager'], dtype=object),
#  array(['AB Tancred', 'Augustus Tancred', 'Bernard Tancred'], dtype=object),
#  array(['Abubacarr Kuyateh'], dtype=object),
#  array(['Abu Hider'], dtype=object),
#  array(['A Jayed', 'Abu Jayed'], dtype=object),
#  array(['Abul Farhad'], dtype=object),
#  array(['A Hasan', 'Abul Hasan'], dtype=object),
#  array(['A Bulow'], dtype=object),
#  array(['A Burdett'], dtype=object),
#  array(['A Bushell'], dtype=object),
#  array(['Abu Zar'], dtype=object),
#  array(['AB Williams', 'Alvadon Williams', 'Basil Williams'], dtype=object),
#  array(['A Agar', 'AC Agar', 'Ashton Agar'], dtype=object),
#  array(['A Campbell'], dtype=object),
#  array(['A Canning'], dtype=object),
#  array(['A Capsey'], dtype=object),
#  array(['A Carter'], dtype=object),
#  array(['A Cassim'], dtype=object),
#  array(['A Cawley'], dtype=object),
#  array(['AC Bannerman', 'Alec Bannerman', 'Alexander Bannerman'],
#        dtype=object),
#  array(['ACB Langton', 'Arthur Langton', 'Chud Langton'], dtype=object),
#  array(['A Blizzard', 'AC Blizzard'], dtype=object),
#  array(['AC Botha'], dtype=object),
#  array(['AC Boyce'], dtype=object),
#  array(['AC Brodin'], dtype=object),
#  array(['AC Cummins'], dtype=object),
#  array(['AC Dale', 'Adam Dale'], dtype=object),
#  array(['AC Dawson', 'Alan Dawson'], dtype=object),
#  array(['AC Douglas'], dtype=object),
#  array(['A Evans', 'AC Evans'], dtype=object),
#  array(['ACF Stokes', 'Stokes'], dtype=object),
#  array(['ACF Wyatt'], dtype=object),
#  array(['A Gilchrist', 'AC Gilchrist', 'Adam Gilchrist'], dtype=object),
#  array(['A Chandel'], dtype=object),
#  array(['A Chandila'], dtype=object),
#  array(['AC Harris'], dtype=object),
#  array(['A Chatterjee'], dtype=object),
#  array(['A Chaudary'], dtype=object),
#  array(['A Chaudhary'], dtype=object),
#  array(['A Chaudhary', 'Aryaveer Chaudhary'], dtype=object),
#  array(['A Chetty'], dtype=object),
#  array(['A Chilia'], dtype=object),
#  array(['Achit Shigwan'], dtype=object),
#  array(['A Chopra', 'AS Chopra', 'Akash Chopra'], dtype=object),
#  array(['A Chopra', 'Anjum Chopra'], dtype=object),
#  array(['A Choudhary', 'A V Choudhary'], dtype=object),
#  array(['AC Hudson', 'Andrew Hudson'], dtype=object),
#  array(['ACI Lock', 'Alan Lock', 'Charlie Lock'], dtype=object),
#  array(['ACI Lovell'], dtype=object),
#  array(['A Ciric'], dtype=object),
#  array(['AC Jayangani', 'AMC Jayangani', 'C Athapaththu'], dtype=object),
#  array(['A Kerr', 'AC Kerr', 'Amelia Kerr'], dtype=object),
#  array(['A Clark'], dtype=object),
#  array(['A Clark', 'Amy Clark'], dtype=object),
#  array(['A Clarke'], dtype=object),
#  array(['AC Lenham'], dtype=object),
#  array(['ACL Richards'], dtype=object),
#  array(['AC Mace-Cochrane'], dtype=object),
#  array(['AC MacLaren', 'Archibald MacLaren', 'Archie MacLaren'],
#        dtype=object),
#  array(['AC McDermott'], dtype=object),
#  array(['AC Mushangwe'], dtype=object),
#  array(['A Codrington'], dtype=object),
#  array(['A Coningham', 'Arthur Coningham'], dtype=object),
#  array(['A Conteh'], dtype=object),
#  array(['A Cossa'], dtype=object),
#  array(['A Cotter', 'Albert Cotter', 'Tibby Cotter'], dtype=object),
#  array(['A Coxon', 'Alec Coxon'], dtype=object),
#  array(['AC Parore', 'Adam Parore'], dtype=object),
#  array(['A Crafford', 'Adriaan Crafford'], dtype=object),
#  array(['A Cranstone'], dtype=object),
#  array(['ACR Birch'], dtype=object),
#  array(['AC Sabino'], dtype=object),
#  array(['AC Smith', 'Alan Smith'], dtype=object),
#  array(['AC Smith', 'Asha Smith'], dtype=object),
#  array(['ACS Pigott', 'Anthony Pigott', 'Tony Pigott'], dtype=object),
#  array(['AC Stanacu'], dtype=object),
#  array(['AC Stockwell'], dtype=object),
#  array(['A Thomas', 'AC Thomas'], dtype=object),
#  array(['A Curr'], dtype=object),
#  array(['A Voges', 'AC Voges', 'Adam Voges'], dtype=object),
#  array(['AC Waller', 'Andrew Waller', 'Andy Waller'], dtype=object),
#  array(['AC Warren'], dtype=object),
#  array(['Ada Bhasin'], dtype=object),
#  array(['A Dagar'], dtype=object),
#  array(['A Dale'], dtype=object),
#  array(['AD Algar'], dtype=object),
#  array(['A Dalzell'], dtype=object),
#  array(['Adama Kamara'], dtype=object),
#  array(['Adam Birss'], dtype=object),
#  array(['Adam Khalaf'], dtype=object),
#  array(['A Dananjaya', 'Akila Dananjaya', 'MKPAD Perera'], dtype=object),
#  array(['A Daniel'], dtype=object),
#  array(['A Das'], dtype=object),
#  array(['A Dastgir'], dtype=object),
#  array(['A Daxini'], dtype=object),
#  array(['A Day'], dtype=object),
#  array(['AD Brown'], dtype=object),
#  array(['AD Carr'], dtype=object),
#  array(['AD Chopra'], dtype=object),
#  array(['AD Conwana'], dtype=object),
#  array(['A Dcosta'], dtype=object),
#  array(['AD Curtis', 'Andrew Curtis'], dtype=object),
#  array(['AD Day'], dtype=object),
#  array(['AD de Lange'], dtype=object),
#  array(['Adeel Malik'], dtype=object),
#  array(['A Raja', 'Adeel Raja'], dtype=object),
#  array(['Adel Kolasangiani'], dtype=object),
#  array(['A Dennison'], dtype=object),
#  array(['A Denuwan'], dtype=object),
#  array(['A Dercksen'], dtype=object),
#  array(['A Deshmukh'], dtype=object),
#  array(['AD Evans'], dtype=object),
#  array(['AD Gaekwad', 'Anshuman Gaekwad'], dtype=object),
#  array(['ADG Matthews', 'Austin Matthews'], dtype=object),
#  array(['ADG Roberts', 'Andrew Roberts', 'Andy Roberts'], dtype=object),
#  array(['A Hales', 'AD Hales', 'Alex Hales'], dtype=object),
#  array(['A Dhingra'], dtype=object),
#  array(['Adhip Pradhan'], dtype=object),
#  array(['Adhitya Shetty'], dtype=object),
#  array(['Adil Afzal'], dtype=object),
#  array(['Adil Amin'], dtype=object),
#  array(['Adil Bhatti'], dtype=object),
#  array(['Adil Butt'], dtype=object),
#  array(['Adil Butt', 'Adil Butt (2)'], dtype=object),
#  array(['Adil Hanif'], dtype=object),
#  array(['Adil Reshi'], dtype=object),
#  array(['A Dineshi'], dtype=object),
#  array(['Aditya'], dtype=object),
#  array(['Aditya Garhwal', 'Aditya N Garhwal'], dtype=object),
#  array(['Aditya Jadeja'], dtype=object),
#  array(['Aditya Kaushik'], dtype=object),
#  array(['Aditya Panwar'], dtype=object),
#  array(['Aditya Rout'], dtype=object),
#  array(['Aditya Partap', 'Aditya Pratap', 'Aditya Pratap Singh',
#         'Aditya Singh'], dtype=object),
#  array(['Aditya Waghmode'], dtype=object),
#  array(['A Dizija'], dtype=object),
#  array(['AD Janakanthymala'], dtype=object),
#  array(['A Djorovic', 'Aleksa Djorovic'], dtype=object),
#  array(['ADJ Pitcher'], dtype=object),
#  array(['AD Kamania'], dtype=object),
#  array(['AD Louisy'], dtype=object),
#  array(['ADL Stokoe'], dtype=object),
#  array(['AD Mascarenhas', 'D Mascarenhas'], dtype=object),
#  array(['A Mathews', 'AD Mathews', 'Angelo Mathews', 'Mathews'],
#        dtype=object),
#  array(['AD Mullally', 'Alan Mullally'], dtype=object),
#  array(['A Akmal', 'Adnan Akmal'], dtype=object),
#  array(['Adnan Butt'], dtype=object),
#  array(['Adnan Idrees'], dtype=object),
#  array(['A Ilyas', 'Adnan Ilyas'], dtype=object),
#  array(['Adnan Khan'], dtype=object),
#  array(['Adnan Liaquat'], dtype=object),
#  array(['Adnan Mirza'], dtype=object),
#  array(['A Mufti', 'Adnan Mufti'], dtype=object),
#  array(['A Rasool', 'Adnan Rasool'], dtype=object),
#  array(['Adnan Razzaq'], dtype=object),
#  array(['Adnan Syed'], dtype=object),
#  array(['A Nath', 'AD Nath', 'Aksh Deep Nath'], dtype=object),
#  array(['AD Nourse', 'Dudley Nourse'], dtype=object),
#  array(['A Doddaballapur'], dtype=object),
#  array(['AD Ogilvie', 'David Ogilvie'], dtype=object),
#  array(['A Dolin'], dtype=object),
#  array(['A Dolphin', 'Arthur Dolphin'], dtype=object),
#  array(['A Dowse'], dtype=object),
#  array(['AD Pougher', 'Arthur Pougher', 'Dick Pougher'], dtype=object),
#  array(['A Poynter', 'AD Poynter'], dtype=object),
#  array(['AD Presland'], dtype=object),
#  array(['ADR Campbell', 'Alistair Campbell'], dtype=object),
#  array(['Adriaan van den Dries'], dtype=object),
#  array(['AD Ridley'], dtype=object),
#  array(['A Russell', 'AD Russell', 'Andre Russell'], dtype=object),
#  array(['A Fletcher', 'ADS Fletcher', 'Andre Fletcher'], dtype=object),
#  array(["A D'Souza", "Antao D'Souza"], dtype=object),
#  array(['A Thomason', 'AD Thomason'], dtype=object),
#  array(['A Ducat', 'Andrew Ducat', 'Andy Ducat'], dtype=object),
#  array(['A Dutt'], dtype=object),
#  array(['AD Willoughby'], dtype=object),
#  array(['AE Cooper'], dtype=object),
#  array(['AE Dick', 'Artie Dick'], dtype=object),
#  array(['AE Dipper', 'Alfred Dipper'], dtype=object),
#  array(['A Edward', 'Ashlene Edward'], dtype=object),
#  array(['A Edwards', 'Amanda Edwards'], dtype=object),
#  array(['AE Dyson'], dtype=object),
#  array(['AEE Vogler', 'Albert Vogler', 'Bert Vogler'], dtype=object),
#  array(['AE Fagg', 'Arthur Fagg'], dtype=object),
#  array(['AE Greenidge', 'Alvin Greenidge'], dtype=object),
#  array(['AE Hall'], dtype=object),
#  array(['AE Hodgson'], dtype=object),
#  array(['AE Isesele'], dtype=object),
#  array(['A Jones', 'AE Jones', 'Amy Jones'], dtype=object),
#  array(['AE Knight', 'Albert Knight'], dtype=object),
#  array(['A Elliott'], dtype=object),
#  array(['A Emch', 'Alina Emch'], dtype=object),
#  array(['AE Moe'], dtype=object),
#  array(['AE Moss', 'Alan Moss'], dtype=object),
#  array(['AEMP Durayalage'], dtype=object),
#  array(['AEN Riley'], dtype=object),
#  array(['AE Ochse', 'Arthur Ochse'], dtype=object),
#  array(['AE Paraam'], dtype=object),
#  array(['AE Relf', 'Albert Relf'], dtype=object),
#  array(['AE Rendel'], dtype=object),
#  array(['AER Gilligan', 'Arthur Gilligan'], dtype=object),
#  array(['A Satterthwaite', 'AE Satterthwaite', 'Amy Satterthwaite'],
#        dtype=object),
#  array(['AE Smith'], dtype=object),
#  array(['AE Stoddart', 'Andrew Stoddart'], dtype=object),
#  array(['AE Trott', 'Albert Trott'], dtype=object),
#  array(['AEV Hartkopf', 'Albert Hartkopf'], dtype=object),
#  array(['AE White'], dtype=object),
#  array(['A Faletar'], dtype=object),
#  array(['AFA Lilley', 'Arthur Lilley', 'Dick Lilley'], dtype=object),
#  array(['AF Aoina'], dtype=object),
#  array(['Afaq Ahmed'], dtype=object),
#  array(['Afaq Hussain'], dtype=object),
#  array(['A Buurman', 'AF Buurman'], dtype=object),
#  array(['A Ferguson', 'Alejandro Ferguson'], dtype=object),
#  array(['AFG Griffith', 'Adrian Griffith'], dtype=object),
#  array(['AF Giles', 'Ashley Giles'], dtype=object),
#  array(['AF Gleadall'], dtype=object),
#  array(['Afia Amin'], dtype=object),
#  array(['Afida Afthab'], dtype=object),
#  array(['A Fielder', 'Arthur Fielder'], dtype=object),
#  array(['A Hossain', 'Afif Hossain'], dtype=object),
#  array(['AF Ifill'], dtype=object),
#  array(['Afif Khattak'], dtype=object),
#  array(['A Fillie'], dtype=object),
#  array(['AF Kippax', 'Alan Kippax'], dtype=object),
#  array(['A Flintoff', 'Andrew Flintoff'], dtype=object),
#  array(['AF Lissette', 'Alan Lissette', 'Allen Lissette'], dtype=object),
#  array(['A Flower', 'Andy Flower'], dtype=object),
#  array(['AFM Akhtaruddin'], dtype=object),
#  array(['A Milne', 'AF Milne', 'Adam Milne', 'Milne'], dtype=object),
#  array(['AF Rae', 'Allan Rae'], dtype=object),
#  array(['A Freeman', 'Arsheena Freeman'], dtype=object),
#  array(['A From-Hansen'], dtype=object),
#  array(['A Zazai', 'Afsar Zazai'], dtype=object),
#  array(['AF Sattaur'], dtype=object),
#  array(['Aftab Ahmed'], dtype=object),
#  array(['Aftab Ahmed', 'Aftab Ahmed (2)'], dtype=object),
#  array(['A Alam', 'Aftab Alam'], dtype=object),
#  array(['Aftab Baloch'], dtype=object),
#  array(['Aftab Gul'], dtype=object),
#  array(['Aftab Hussain'], dtype=object),
#  array(['Aftab Ibrahim'], dtype=object),
#  array(['Aftab Kayani'], dtype=object),
#  array(['A Fujikawa'], dtype=object),
#  array(['Afzaal Ahmed'], dtype=object),
#  array(['Afzaal Haider'], dtype=object),
#  array(['Afzal Faiz'], dtype=object),
#  array(['Afzalkhan Pathan'], dtype=object),
#  array(['Afzal Pathan'], dtype=object),
#  array(['Afzal Saleem'], dtype=object),
#  array(['Afzal Virk'], dtype=object),
#  array(['A Gajjar'], dtype=object),
#  array(['A Galan', 'Albertina Galan'], dtype=object),
#  array(['A Gandotra', 'Ashok Gandotra'], dtype=object),
#  array(['A Ganeshan'], dtype=object),
#  array(['AG Archer', 'Alfred Archer'], dtype=object),
#  array(['A Gardner', 'Ashleigh Gardner', 'Gardner'], dtype=object),
#  array(['A Gasteratos'], dtype=object),
#  array(['A Gavde'], dtype=object),
#  array(['AG Barrett', 'Arthur Barrett'], dtype=object),
#  array(['A Gbla'], dtype=object),
#  array(['AG Botha'], dtype=object),
#  array(['AG Chipperfield', 'Arthur Chipperfield'], dtype=object),
#  array(['AG Chouhan'], dtype=object),
#  array(['AG Cremer', 'G Cremer', 'Graeme Cremer'], dtype=object),
#  array(["AG D'Costa"], dtype=object),
#  array(['AG Dissanayake'], dtype=object),
#  array(['AG Dugmore'], dtype=object),
#  array(['AGD Wickremasinghe', 'Gamini Wickremasinghe'], dtype=object),
#  array(['A Genford'], dtype=object),
#  array(['A Gentle'], dtype=object),
#  array(['AG Fairfax', 'Alan Fairfax'], dtype=object),
#  array(['AG Ganteaume', 'Andrew Ganteaume', 'Andy Ganteaume'], dtype=object),
#  array(['AG Gerken'], dtype=object),
#  array(['AG Gordon', 'Amy Gordon'], dtype=object),
#  array(['AG Harriott'], dtype=object),
#  array(['Agha Saadat Ali'], dtype=object),
#  array(['Agha Salman'], dtype=object),
#  array(['Agha Zahid'], dtype=object),
#  array(['AGH Orr'], dtype=object),
#  array(['AG Hotton'], dtype=object),
#  array(['AG Huckle', 'Adam Huckle'], dtype=object),
#  array(['AG Hurst', 'Alan Hurst'], dtype=object),
#  array(['A G Jungade', 'AG Jungade', 'Amol Jungade'], dtype=object),
#  array(['AG Kripal Singh'], dtype=object),
#  array(['A Glen'], dtype=object),
#  array(['A G Milkha Singh', 'AG Milkha Singh'], dtype=object),
#  array(['AG Milton'], dtype=object),
#  array(['A Murtaza', 'AG Murtaza'], dtype=object),
#  array(['Agniv Pan'], dtype=object),
#  array(['A Goenka'], dtype=object),
#  array(['A Gorawara'], dtype=object),
#  array(['A Gordon'], dtype=object),
#  array(['AG Oxley', 'Alex Oxley'], dtype=object),
#  array(['AG Paunikar', 'Amit Paunikar'], dtype=object),
#  array(['A G Pradeep'], dtype=object),
#  array(['AG Prince', 'Ashwell Prince'], dtype=object),
#  array(['AG Puttick'], dtype=object),
#  array(['A Gqamane'], dtype=object),
#  array(['A G Rao', 'AG Rao', 'Anand Rao'], dtype=object),
#  array(['A Greenwood', 'Andrew Greenwood'], dtype=object),
#  array(['A Griffiths'], dtype=object),
#  array(['Agrim Tiwari'], dtype=object),
#  array(['AGR Loudon'], dtype=object),
#  array(['A Salter', 'AG Salter'], dtype=object),
#  array(['A G Sehrawat', 'AG Sehrawat', 'Ashish Sehrawat'], dtype=object),
#  array(['AGS Gous'], dtype=object),
#  array(['AG Steel', 'Allan Steel'], dtype=object),
#  array(['A Gunasekar'], dtype=object),
#  array(['A Gurung'], dtype=object),
#  array(['A Wakely', 'AG Wakely'], dtype=object),
#  array(['AG Walker'], dtype=object),
#  array(['AG Weligamage'], dtype=object),
#  array(['AG Wharf'], dtype=object),
#  array(['A Habib', 'Aftab Habib'], dtype=object),
#  array(['A Haggan'], dtype=object),
#  array(['A Halbhavi'], dtype=object),
#  array(['A Hamilton'], dtype=object),
#  array(['A Haque'], dtype=object),
#  array(['A Harikumar'], dtype=object),
#  array(['A Harinath'], dtype=object),
#  array(['A Harris'], dtype=object),
#  array(['A Harris', 'Antonio Harris'], dtype=object),
#  array(['A Harrison'], dtype=object),
#  array(['A Hartley'], dtype=object),
#  array(['AH Bakewell', 'Alfred Bakewell', 'Fred Bakewell'], dtype=object),
#  array(['AHC Cooper', 'Alfred Cooper'], dtype=object),
#  array(['A Hearne', 'Alec Hearne'], dtype=object),
#  array(['A Hepburn'], dtype=object),
#  array(['A Heywood'], dtype=object),
#  array(['AH Gray', 'Anthony Gray', 'Tony Gray'], dtype=object),
#  array(['AHH Gilligan', 'Alfred Gilligan', 'Arthur Gilligan',
#         'Harold Gilligan'], dtype=object),
#  array(['A H Hooda', 'AH Hooda', 'Ashish Hooda'], dtype=object),
#  array(['A Hickey'], dtype=object),
#  array(['A Hill', 'Allen Hill'], dtype=object),
#  array(['Ahitesh Varma', 'UAV Varma'], dtype=object),
#  array(['AH Jarvis', 'Affie Jarvis', 'Arthur Jarvis'], dtype=object),
#  array(['AH Jones', 'Andrew Jones'], dtype=object),
#  array(['AH Kapadia'], dtype=object),
#  array(['AH Kardar', 'Abdul Hafeez', 'Abdul Kardar'], dtype=object),
#  array(['A Hlubi'], dtype=object),
#  array(['Ahmadi Ravat'], dtype=object),
#  array(['Ahmad Khalid Ahmadzai'], dtype=object),
#  array(['Ahmad Khan'], dtype=object),
#  array(['Ahmad Mushtaq'], dtype=object),
#  array(['Ahmad Nasir'], dtype=object),
#  array(['Ahmad Ramdoni'], dtype=object),
#  array(['Ahmad Raza'], dtype=object),
#  array(['Ahmadschah Ahmadzai'], dtype=object),
#  array(['A Shafiq', 'Ahmad Shafiq'], dtype=object),
#  array(['Ahmadullah Shinwari'], dtype=object),
#  array(['AH Maqsood'], dtype=object),
#  array(['AH McKinnon', 'Atholl McKinnon'], dtype=object),
#  array(['Ahmed Ameel'], dtype=object),
#  array(['Ahmed Aqeel'], dtype=object),
#  array(['Ahmed Baladraf'], dtype=object),
#  array(['Ahmad Omar Banday', 'Ahmed Banday'], dtype=object),
#  array(['Ahmed Bilal'], dtype=object),
#  array(['Ahmed Daniyal'], dtype=object),
#  array(['Ahmed Faiz'], dtype=object),
#  array(['Ahmed Faiz', 'Ahmed Faiz Mohammad Noor'], dtype=object),
#  array(['Ahmed Hassan'], dtype=object),
#  array(['Ahmed Hassan', 'Ahmed Hassan (2)'], dtype=object),
#  array(['Ahmed Jamaal'], dtype=object),
#  array(['Ahmed Mustafa'], dtype=object),
#  array(['Ahmed Nadeem'], dtype=object),
#  array(['Ahmed Nisar'], dtype=object),
#  array(['Ahmed Raid'], dtype=object),
#  array(['A Raza', 'Ahmed Raza'], dtype=object),
#  array(['Ahmed Safi', 'Ahmed Safi Abdullah'], dtype=object),
#  array(['Ahmed Shah'], dtype=object),
#  array(['Ahmed Shah', 'Ahmed Shah (2)', 'Shah'], dtype=object),
#  array(['Ahmed Shahab'], dtype=object),
#  array(['Ahmed Shah Durrani'], dtype=object),
#  array(['Ahmed Shah Pakteen'], dtype=object),
#  array(['A Shehzad', 'Ahmed Shehzad'], dtype=object),
#  array(['Ahmed Wardak'], dtype=object),
#  array(['Ahmer Bin Nisar'], dtype=object),
#  array(['AH Miller'], dtype=object),
#  array(['A Hogg'], dtype=object),
#  array(['A Hoilett'], dtype=object),
#  array(['A Holder'], dtype=object),
#  array(['AH Omarshah', 'Ali Omarshah', 'Ali Shah'], dtype=object),
#  array(['AH Passi'], dtype=object),
#  array(['AHP Scott', 'Alfred Scott'], dtype=object),
#  array(['Ahram Jeong'], dtype=object),
#  array(['Ahsan Abbasi'], dtype=object),
#  array(['A Ali', 'Ahsan Ali'], dtype=object),
#  array(['Ahsan Bhatti'], dtype=object),
#  array(['Ahsan Hafeez'], dtype=object),
#  array(['Ahsan Khan'], dtype=object),
#  array(['A Malik', 'Ahsan Malik'], dtype=object),
#  array(['Ahsan Raza'], dtype=object),
#  array(['Ahsan ul Haq'], dtype=object),
#  array(['Ahsan Yusuf'], dtype=object),
#  array(['A Donald', 'AHT Donald'], dtype=object),
#  array(['AH Thomson'], dtype=object),
#  array(['A Hunter'], dtype=object),
#  array(['A Hurwood', 'Alec Hurwood', 'Alexander Hurwood'], dtype=object),
#  array(['A Husain'], dtype=object),
#  array(['A Hutchinson'], dtype=object),
#  array(['AIC Dodemaide', 'Anthony Dodemaide', 'Tony Dodemaide'],
#        dtype=object),
#  array(['AI Chudasama'], dtype=object),
#  array(['Aidan Seaver'], dtype=object),
#  array(['AI Gait'], dtype=object),
#  array(['A Igbobie'], dtype=object),
#  array(['Aijaz Ali'], dtype=object),
#  array(['AI Kallicharran', 'Alvin Kallicharran'], dtype=object),
#  array(['A Ikuzwe', 'Alice Ikuzwe'], dtype=object),
#  array(['Aima Aishath'], dtype=object),
#  array(['AI MacKinlay', 'Andrew MacKinlay'], dtype=object),
#  array(['Aimal Khan'], dtype=object),
#  array(['A Anwer', 'Aiman Anwer', 'Aimen Anwar'], dtype=object),
#  array(['A Imtiaz'], dtype=object),
#  array(['Aina Najwa'], dtype=object),
#  array(['Ainna Hamizah Hashim'], dtype=object),
#  array(['Ainool Hafizs'], dtype=object),
#  array(['Ainool Haqqiem'], dtype=object),
#  array(['A Iopu'], dtype=object),
#  array(['A Iqbal'], dtype=object),
#  array(['AI Ross', 'Alex Ross'], dtype=object),
#  array(['AISD Kainoco'], dtype=object),
#  array(['Aisha Rahman'], dtype=object),
#  array(['Aishath Meesa Rameez'], dtype=object),
#  array(['AI Shields'], dtype=object),
#  array(['Aishwary Marya', 'Aishwary Mourya', 'Aishwarya Mourya'],
#        dtype=object),
#  array(['Aisya Eleesa'], dtype=object),
#  array(['AI Taylor', 'Alistair Taylor', 'Scotch Taylor'], dtype=object),
#  array(['A I Thakur'], dtype=object),
#  array(['A Cheema', 'Aizaz Cheema'], dtype=object),
#  array(['A Khan', 'Aizaz Khan'], dtype=object),
#  array(['A Jackson', 'Archibald Jackson', 'Archie Jackson'], dtype=object),
#  array(['A Jacobs'], dtype=object),
#  array(['A Jadeja', 'AD Jadeja', 'Ajay Jadeja'], dtype=object),
#  array(['AJA Gray'], dtype=object),
#  array(['A Jain', 'Anju Jain'], dtype=object),
#  array(['A Jain', 'Arjan Jain'], dtype=object),
#  array(['A Jarvis'], dtype=object),
#  array(['A Javid'], dtype=object),
#  array(['A Wheater', 'AJA Wheater'], dtype=object),
#  array(['AJ Ayannaike'], dtype=object),
#  array(['Ajay Dev Goud'], dtype=object),
#  array(['Ajay Kumar', 'Mallireddy Ajay Kumar'], dtype=object),
#  array(['Ajay Mandal'], dtype=object),
#  array(['Ajay', 'Ajay Pradhan'], dtype=object),
#  array(['A S Sarkar', 'AS Sarkar', 'Ajay Sarkar'], dtype=object),
#  array(['Ajay Verma'], dtype=object),
#  array(['Ajay Yadav'], dtype=object),
#  array(['Ajaz Patel'], dtype=object),
#  array(['AJ Ball'], dtype=object),
#  array(['AJ Barrow'], dtype=object),
#  array(['AJ Bell', 'Alexander Bell', 'Sandy Bell'], dtype=object),
#  array(['AJ Bichel', 'Andy Bichel'], dtype=object),
#  array(['A Blackwell', 'AJ Blackwell'], dtype=object),
#  array(['A Blake', 'AJ Blake', 'Blake'], dtype=object),
#  array(['AJ Bookal'], dtype=object),
#  array(['AJ Burger'], dtype=object),
#  array(['AJ Clarke'], dtype=object),
#  array(['AJ Crosthwaite'], dtype=object),
#  array(['A Doolan', 'AJ Doolan', 'Alexander Doolan'], dtype=object),
#  array(['AJ Drummond'], dtype=object),
#  array(['AJ Evans', 'Alfred Evans', 'John Evans'], dtype=object),
#  array(['A Finch', 'AJ Finch', 'Aaron Finch'], dtype=object),
#  array(['AJ Fothergill', 'Arnold Fothergill'], dtype=object),
#  array(['AJ Freeborn'], dtype=object),
#  array(['AJ Green'], dtype=object),
#  array(['A Gregory', 'AJ Gregory'], dtype=object),
#  array(['AJ Hall', 'Andrew Hall'], dtype=object),
#  array(['AJ Harris'], dtype=object),
#  array(['AJ Harrison'], dtype=object),
#  array(['A Healy', 'AJ Healy', 'Alyssa Healy'], dtype=object),
#  array(['AJ Hickey'], dtype=object),
#  array(['AJ Hodd'], dtype=object),
#  array(['AJ Hollioake', 'Adam Hollioake'], dtype=object),
#  array(['AJ Horton'], dtype=object),
#  array(['A Hose', 'AJ Hose'], dtype=object),
#  array(['A Hosein', 'AJ Hosein', 'Akeal Hosein', 'Hosein'], dtype=object),
#  array(['AJ Ireland'], dtype=object),
#  array(['Ajith Dcosta'], dtype=object),
#  array(['AJ Jabiri'], dtype=object),
#  array(['A J Kaushik', 'AJ Kaushik', 'Abhishek Kaushik'], dtype=object),
#  array(['A Kenealy', 'AJ Kenealy'], dtype=object),
#  array(['AJ Lamb', 'Allan Lamb'], dtype=object),
#  array(['A Baum', 'AJL Baum'], dtype=object),
#  array(['AJ Leonard'], dtype=object),
#  array(['AJL Hill', 'Arthur Hill'], dtype=object),
#  array(['AJ Macleod'], dtype=object),
#  array(['AJ Malan'], dtype=object),
#  array(['AJ McKay', 'Andrew McKay'], dtype=object),
#  array(['AJ Mellor'], dtype=object),
#  array(['AJ Michael'], dtype=object),
#  array(['AJ Miles'], dtype=object),
#  array(['AJ Mosca'], dtype=object),
#  array(['AJ Nair', 'Arjun Nair'], dtype=object),
#  array(['AJ Neill'], dtype=object),
#  array(['A Johnmary'], dtype=object),
#  array(['A Johnson'], dtype=object),
#  array(['AJ Parr-Thomson'], dtype=object),
#  array(['AJ Pienaar'], dtype=object),
#  array(['AJ Pithey', 'Tony Pithey'], dtype=object),
#  array(['AJ Pycroft', 'Andrew Pycroft'], dtype=object),
#  array(['AJ Redmond', 'Aaron Redmond'], dtype=object),
#  array(['AJ Richardson', 'Arthur Richardson'], dtype=object),
#  array(['AJ Robson'], dtype=object),
#  array(['AJ Rout'], dtype=object),
#  array(['AJ Sammartino'], dtype=object),
#  array(['AJ Shantry'], dtype=object),
#  array(['AJ Staal'], dtype=object),
#  array(['AJ Stewart', 'Alec Stewart'], dtype=object),
#  array(['A Strauss', 'AJ Strauss', 'Andrew Strauss'], dtype=object),
#  array(['AJ Swann', 'Alec Swann'], dtype=object),
#  array(['AJT Dowdalls'], dtype=object),
#  array(['AJ Traicos', 'Athanasios Traicos', 'John Traicos'], dtype=object),
#  array(['AJ Tudor', 'Alex Tudor'], dtype=object),
#  array(['A Turner', 'AJ Turner', 'Ashton Turner'], dtype=object),
#  array(['A Tye', 'AJ Tye', 'Andrew Tye', 'Tye'], dtype=object),
#  array(['AJ Watkins', 'Allan Watkins'], dtype=object),
#  array(['AJ Webbe', 'Alexander Webbe'], dtype=object),
#  array(['AJ Wilkins'], dtype=object),
#  array(['AJW McIntyre', 'Arthur McIntyre'], dtype=object),
#  array(['AJ Woodcock', 'Ashley Woodcock'], dtype=object),
#  array(['AJY Hopkins', 'Albert Hopkins', 'Bert Hopkins'], dtype=object),
#  array(['A Kainessie'], dtype=object),
#  array(['A Kamboj'], dtype=object),
#  array(['A Kanada'], dtype=object),
#  array(['A Kano'], dtype=object),
#  array(['A Kansonkho'], dtype=object),
#  array(['A Kapa'], dtype=object),
#  array(['A Kapil'], dtype=object),
#  array(['A Kapoor'], dtype=object),
#  array(['A Karmacharya'], dtype=object),
#  array(['A Karn'], dtype=object),
#  array(['A Karvelas'], dtype=object),
#  array(['Akash Babu'], dtype=object),
#  array(['Akash Bhandari'], dtype=object),
#  array(['Akash Choudhary', 'Akash Kumar'], dtype=object),
#  array(['Akash Deep'], dtype=object),
#  array(['Akash Luitel'], dtype=object),
#  array(['Akash Madhwal', 'Madhwal A'], dtype=object),
#  array(['Akash Pandey'], dtype=object),
#  array(['Akash P', 'Akash Parkar'], dtype=object),
#  array(['Akash Raj'], dtype=object),
#  array(['Akash Sengupta'], dtype=object),
#  array(['A M Singh', 'Akash Singh'], dtype=object),
#  array(['Akash Sudan'], dtype=object),
#  array(['A P Vashisht', 'AP Vashisht', 'Akash Vasisht'], dtype=object),
#  array(['A Kassam'], dtype=object),
#  array(['A Kaul'], dtype=object),
#  array(['Akbar Ali'], dtype=object),
#  array(['Akbar Ali', 'Mohammad Akbar Ali'], dtype=object),
#  array(['Akbar Khan'], dtype=object),
#  array(['Akbar Khan', 'Akbar Khan (2)'], dtype=object),
#  array(['Akbar-ur-Rehman'], dtype=object),
#  array(['AK Burrows'], dtype=object),
#  array(['A K Chahal', 'AK Chahal', 'Ajit Chahal'], dtype=object),
#  array(['AK Chaudhary', 'AK Chowdhary'], dtype=object),
#  array(['AK Davidson', 'Alan Davidson'], dtype=object),
#  array(['AKD Gray'], dtype=object),
#  array(['A Keefe'], dtype=object),
#  array(['Akeem Jordan'], dtype=object),
#  array(['AK Ghose'], dtype=object),
#  array(['AK Gokoel'], dtype=object),
#  array(['AK Gonerara'], dtype=object),
#  array(['A Khaka', 'Khaka'], dtype=object),
#  array(['A Khan', 'Amjad Khan'], dtype=object),
#  array(['AK Heal'], dtype=object),
#  array(['A Kheterpal'], dtype=object),
#  array(['Akhil Anil'], dtype=object),
#  array(['Akhil Arjunan'], dtype=object),
#  array(['Akhilesh Sahani'], dtype=object),
#  array(['Akhil Rajput'], dtype=object),
#  array(['Akhtar Ahmad'], dtype=object),
#  array(['Akif Javed'], dtype=object),
#  array(['Akif Raja'], dtype=object),
#  array(['A Kind-David'], dtype=object),
#  array(['A King', 'Alana King', 'King'], dtype=object),
#  array(['A Kirschbaum', 'Alan Kirschbaum'], dtype=object),
#  array(['A Kitamura'], dtype=object),
#  array(['A Kitayama'], dtype=object),
#  array(['A Kitchen', 'AK Kitchen'], dtype=object),
#  array(['AK Kuruppuarachchi', 'Ajith Kuruppuarachchi',
#         'Kosala Kuruppuarachchi'], dtype=object),
#  array(['AKL Brijcoomar'], dtype=object),
#  array(['AK Maguire'], dtype=object),
#  array(['AK Mandal'], dtype=object),
#  array(['A Markram', 'AK Markram', 'Aiden Markram'], dtype=object),
#  array(['AK Mitra'], dtype=object),
#  array(['AK Mohan'], dtype=object),
#  array(['AK Muslar'], dtype=object),
#  array(['A Kohli'], dtype=object),
#  array(['Akoijam Singh', 'Akoijam Tenyson Singh', 'Tenyson'], dtype=object),
#  array(['A Kolan'], dtype=object),
#  array(['A Kone'], dtype=object),
#  array(['A Koul'], dtype=object),
#  array(['A Kovalevs'], dtype=object),
#  array(['A Patel', 'AK Patel'], dtype=object),
#  array(['AK Perera'], dtype=object),
#  array(['A Peters', 'AK Peters'], dtype=object),
#  array(['Akram Aslam'], dtype=object),
#  array(['Akram Khan'], dtype=object),
#  array(['Akram Raza'], dtype=object),
#  array(['Akramullah Malikzada'], dtype=object),
#  array(['AK Rana'], dtype=object),
#  array(['A Kripal Singh'], dtype=object),
#  array(['A Krishna'], dtype=object),
#  array(['AK Roy', 'Ambar Roy'], dtype=object),
#  array(['AK Russell'], dtype=object),
#  array(['A Sah', 'AK Sah'], dtype=object),
#  array(['AK Saini'], dtype=object),
#  array(['A K Sarkar', 'AK Sarkar', 'Abhijit Sarkar'], dtype=object),
#  array(['A Bains', 'A K Bains', 'AKS Bains'], dtype=object),
#  array(['AK Sengupta', 'Apoorva Sengupta'], dtype=object),
#  array(['AK Sharma', 'Ajay Sharma'], dtype=object),
#  array(['Akshat Raghuwanshi'], dtype=object),
#  array(['Akshay Chandran'], dtype=object),
#  array(['A Homraj', 'Akshay Homraj'], dtype=object),
#  array(['Akshay Jain', 'S Akshay Jain'], dtype=object),
#  array(['A K Karnewar', 'AK Karnewar', 'Akshay Karnewar'], dtype=object),
#  array(['A V Wadkar', 'AV Wadkar', 'Akshay Wadkar'], dtype=object),
#  array(['A A Wakhare', 'AA Wakhare', 'Akshay Wakhare'], dtype=object),
#  array(['AK Shukla'], dtype=object),
#  array(['Aks Swadhin'], dtype=object),
#  array(['Akteruzzaman'], dtype=object),
#  array(['A Kumble', 'Anil Kumble'], dtype=object),
#  array(['A Kuruvilla', 'Abey Kuruvilla'], dtype=object),
#  array(['AKV Tyrone', 'AKV Tyronne'], dtype=object),
#  array(['AK Wilds'], dtype=object),
#  array(['A Lambert'], dtype=object),
#  array(['Alamgir Kabir'], dtype=object),
#  array(['Al-Amin'], dtype=object),
#  array(['Al-Amin Hossain'], dtype=object),
#  array(['Alam Nakash'], dtype=object),
#  array(['A Landage'], dtype=object),
#  array(['A Langham'], dtype=object),
#  array(['A Lanning', 'AJ Lanning', 'Anna Lanning'], dtype=object),
#  array(['AL Apte', 'Arvind Apte'], dtype=object),
#  array(['A las Pinas'], dtype=object),
#  array(['Alastair Bressington'], dtype=object),
#  array(['Alastair Smith'], dtype=object),
#  array(['Alauddin Babu'], dtype=object),
#  array(['Alawi Shukri'], dtype=object),
#  array(['Al Bashid', 'Al Bashid Muhammed'], dtype=object),
#  array(['AL Casime'], dtype=object),
#  array(['A Davies', 'AL Davies'], dtype=object),
#  array(['AL Dodson'], dtype=object),
#  array(['A Learoyd', 'Anika Learoyd'], dtype=object),
#  array(['A le Breton'], dtype=object),
#  array(['AL Edgar'], dtype=object),
#  array(['A Lee'], dtype=object),
#  array(['Aleem Dar'], dtype=object),
#  array(['Aleena Khan'], dtype=object),
#  array(['Alexandros Karvelas'], dtype=object),
#  array(['Alex Carthew'], dtype=object),
#  array(['Alex J Jones'], dtype=object),
#  array(['ALF de Mel', 'Ashantha de Mel'], dtype=object),
#  array(['AL Fekete', 'Andrew Fekete', 'Fekete'], dtype=object),
#  array(['AE Hall', 'Alf Hall', 'Alfred Hall'], dtype=object),
#  array(['Alfredo Esteban Valdes Puentes', 'Alfredo Puentes'], dtype=object),
#  array(['AL Gillies'], dtype=object),
#  array(['AL Hassett', 'Arthur Hassett'], dtype=object),
#  array(['AL Hill'], dtype=object),
#  array(['AL Hodgkinson'], dtype=object),
#  array(['A Hughes', 'AL Hughes', 'Hughes'], dtype=object),
#  array(['Ali Abbas'], dtype=object),
#  array(['Ali Abdulla Popalzae'], dtype=object),
#  array(['Ali Ahmed'], dtype=object),
#  array(['A Liaqat Ali'], dtype=object),
#  array(['Ali Arman'], dtype=object),
#  array(['Ali Asad'], dtype=object),
#  array(['Ali Bushahri'], dtype=object),
#  array(['Ali Dawood'], dtype=object),
#  array(['Ali Farasat'], dtype=object),
#  array(['Alifiya Sayed'], dtype=object),
#  array(['Ali Hasan'], dtype=object),
#  array(['Ali Hussain Rizvi', 'Ali Rizvi'], dtype=object),
#  array(['Ali Ivan'], dtype=object),
#  array(['Ali Khan'], dtype=object),
#  array(['A Khan', 'Ali Khan', 'Ali Shamsher Khan'], dtype=object),
#  array(['Ali Majid'], dtype=object),
#  array(['Ali Masood'], dtype=object),
#  array(['A Limdawala'], dtype=object),
#  array(['Ali Mohammadipour'], dtype=object),
#  array(['Alimuddin'], dtype=object),
#  array(['Ali Naqi'], dtype=object),
#  array(['Ali Naqvi', 'Syed Ali U Naqvi'], dtype=object),
#  array(['Ali Naseer'], dtype=object),
#  array(['Ali Nayyer'], dtype=object),
#  array(['Ali Raza'], dtype=object),
#  array(['Ali Saleem'], dtype=object),
#  array(['Alisa Mohammed'], dtype=object),
#  array(['Ali Shafiq'], dtype=object),
#  array(['Al Islam'], dtype=object),
#  array(['Alison Smith'], dtype=object),
#  array(['A Lister'], dtype=object),
#  array(['A Littlejohns'], dtype=object),
#  array(['Ali Waqar'], dtype=object),
#  array(['A Waqas', 'Ali Waqas'], dtype=object),
#  array(['Ali Yalmaz'], dtype=object),
#  array(['A Riaz', 'Aliya Riaz'], dtype=object),
#  array(['Ali Zaheer'], dtype=object),
#  array(['AL Kandappah'], dtype=object),
#  array(['Alkandari Abdulrahman'], dtype=object),
#  array(['Alkandari Mohammad'], dtype=object),
#  array(['AL Kane'], dtype=object),
#  array(['AL Kerai'], dtype=object),
#  array(['AL Kerrison'], dtype=object),
#  array(['AL Logie', 'Gus Logie'], dtype=object),
#  array(['AL MacDonald'], dtype=object),
#  array(['AL Mangue'], dtype=object),
#  array(['AL Mann', 'Anthony Mann', 'Tony Mann'], dtype=object),
#  array(['Almas Akram'], dtype=object),
#  array(['Al Maseera Jahangir'], dtype=object),
#  array(['A Menaria', 'AL Menaria', 'Ashok Menaria'], dtype=object),
#  array(['AL Ndhlovu'], dtype=object),
#  array(['AL Nicholls'], dtype=object),
#  array(['AL Ochse', 'Arthur Ochse'], dtype=object),
#  array(['Alok Kapali'], dtype=object),
#  array(['Alok Chandra Sahoo', 'Alok Sahoo'], dtype=object),
#  array(['AL Olliver'], dtype=object),
#  array(['Alotaibi Mohammed'], dtype=object),
#  array(['A Louw'], dtype=object),
#  array(['AL Padmore', 'Albert Padmore'], dtype=object),
#  array(['A Phehlukwayo', 'AL Phehlukwayo', 'Andile Phehlukwayo',
#         'Phehlukwayo'], dtype=object),
#  array(['Alqallaf Mohammad'], dtype=object),
#  array(['AL Roberts'], dtype=object),
#  array(['Al Sahariar', 'Al Sahariar Rokon'], dtype=object),
#  array(['AL Seddon'], dtype=object),
#  array(['AL Stephen'], dtype=object),
#  array(['Altaf Gill'], dtype=object),
#  array(['AL Thomas'], dtype=object),
#  array(['AL Thomson', 'Alan Thomson', 'Froggy Thomson'], dtype=object),
#  array(['AL Tiwari'], dtype=object),
#  array(['AL Valentine', 'Alf Valentine', 'Alfred Valentine'], dtype=object),
#  array(['AL Wadekar', 'Ajit Wadekar'], dtype=object),
#  array(['AL Watkins'], dtype=object),
#  array(['A Lyth', 'Adam Lyth'], dtype=object),
#  array(['A Lyttelton', 'Alfred Lyttelton'], dtype=object),
#  array(['A Maasz'], dtype=object),
#  array(['A Butt', 'Amad Butt'], dtype=object),
#  array(['AMA Dewar'], dtype=object),
#  array(['Amad Sheikh'], dtype=object),
#  array(['A Magdalenic'], dtype=object),
#  array(['A Maheshwari'], dtype=object),
#  array(['A Makesh'], dtype=object),
#  array(['A Makri'], dtype=object),
#  array(['AM Ali'], dtype=object),
#  array(['Amalin Sorfina'], dtype=object),
#  array(['AM Ally'], dtype=object),
#  array(['AM Amla'], dtype=object),
#  array(['Aman Ali'], dtype=object),
#  array(['A Manatos'], dtype=object),
#  array(['Amandeep Khare'], dtype=object),
#  array(['Amandeep Singh'], dtype=object),
#  ...]

# %%
people['all_names'] = all_names
people.drop(columns=['name', 'unique_name'], inplace=True)
people.head()
# Out:
#             key_cricinfo                         all_names
# identifier
# b4a23876        772407.0                   [AAA Amsterdam]
# 482762af        380588.0                       [AA Adeoye]
# 4b0e3049        661441.0  [A Alleyne, AA Alleyne, Alleyne]
# fd3c5c00       1163136.0                       [AAA Patel]
# bc005f0d        474307.0                       [AAA White]

# %%
# convert key_cricinfo to int
people['key_cricinfo'] = people['key_cricinfo'].astype('Int64')
people.tail()
# Out:
#             key_cricinfo                                   all_names
# identifier
# 9bf23c13           43707                   [Zulqarnain, Zulquarnain]
# ee9bdbc8           43860                         [Zulqarnain Haider]
# 2d46e8ed         1046641  [Zulqarnain Haider, Zulqarnain Haider (2)]
# b71670a0         1380564                        [Zulufat Mutoniwase]
# d35c1fc7         1050037                               [Zumika Azmi]

# %%
import pandas as pd
import numpy as np

def combinedNames(people: pd.core.frame.DataFrame, names: pd.core.frame.DataFrame):
    #use identifier as index
	people.set_index('identifier', inplace=True)
	names.set_index('identifier', inplace=True)

	names_from_people_arr = people[['name', 'unique_name']].values
	names_from_names_arr = people.index.map(lambda x: names[names.index == x]['name'].values).values

	all_names : list[list[str]] = [None] * names_from_people_arr.shape[0]
	for i in range(names_from_people_arr.shape[0]):
		all_names[i] = np.unique(np.concatenate([names_from_people_arr[i], names_from_names_arr[i]]))

	people['all_names'] = all_names
	people.drop(columns=['name', 'unique_name'], inplace=True)
	people = people[['all_names', 'key_cricinfo']]
	return people

df = combinedNames(pd.read_csv("../Data/people.csv"), pd.read_csv("../Data/names.csv"))

# %%
df.head(20)
# Out:
#                                                     all_names  key_cricinfo
# identifier
# b4a23876                                      [AAA Amsterdam]      772407.0
# 482762af                                          [AA Adeoye]      380588.0
# 4b0e3049                     [A Alleyne, AA Alleyne, Alleyne]      661441.0
# fd3c5c00                                          [AAA Patel]     1163136.0
# bc005f0d                                          [AAA White]      474307.0
# 5c67c7a6                                            [AA Baig]      524897.0
# 6a58e069                    [A A Bamal, AA Bamal, Arun Bamal]     1123075.0
# 02d11602                                          [AA Banner]      590021.0
# b690f34a                     [A A Barot, AA Barot, Avi Barot]      398519.0
# c7a9ffbf                                       [AA Bevilaqua]      959617.0
# bff458c6                                        [AA Bilakhia]       26946.0
# 44e58b5b    [A A Chakraborty, AA Chakraborty, Abhijit Chak...      680363.0
# 29d72eb2                                [A Chavan, AA Chavan]      337913.0
# b2c38dce                                       [AA Choudhury]     1339014.0
# d37fd2c3                                            [A Adams]      464322.0
# 1b0ce76e                                         [A Adekunle]     1365288.0
# cfa56623                                       [AA Deshpande]      220679.0
# 4c931d56                            [AA Donald, Allan Donald]       44716.0
# 9dbc77b3                                   [Aaftab Alam Khan]     1269467.0
# a768a762                                           [AA Gajic]     1323426.0

# %%
# number of rows in the dataframe
df.shape[0]
# Out:
# 15036

# %%
# save the dataframe to a csv file
df.to_csv('supportive_csv_files/combined_names_with_id.csv')

# %% [markdown]
# # Web Scraper to Get Batsman/Bowler Type

# %%
import requests
from bs4 import BeautifulSoup


class Player:
    def __init__(self, identifier, key_cricinfo, all_names):
        self.identifier = identifier
        self.key_cricinfo = key_cricinfo
        self.all_names = all_names
        self._urls = [
            f'https://www.espncricinfo.com/cricketers/{name.lower().replace(" ", "-")}-{key_cricinfo}'
            for name in all_names
        ]
        self.valid_url = None
        self.batting_style = None
        self.bowling_style = None
        self.soup = None  # Single attribute for parsed HTML

    def __str__(self):
        return f"PlayerURL(key_cricinfo={self.key_cricinfo}, all_names={self.all_names}, valid_url={self.valid_url})"

    def get_valid_url(self):
        """
        Fetches and stores the first valid URL from self.urls.

        Returns:
            str: The first valid URL from self.urls or None if none are valid.
        """
        if not self.valid_url:
            for url in self._urls:
                response = requests.get(url)
                if response.status_code == 200:
                    self.valid_url = url
                    self.soup = BeautifulSoup(response.content, 'html.parser')
                    break
        return self.valid_url

    def scrape_info(self):
        """
        Scrapes the valid URL (if available) to get player type information.

        Raises:
            ValueError: If no valid URL is found.

        Returns:
            tuple(str, str): A tuple containing batsman and bowler types (or None if not found).
        """

		# if no valid url, set player_type to None
        if not self.valid_url:
            print(f"No Valid URL Found for {self}")
            return 
	
	


        if not self.soup:
            # Fetch and parse HTML only if not already done
            response = requests.get(self.valid_url)
            response.raise_for_status()  # Raise exception for non-200 status codes
            self.soup = BeautifulSoup(response.content, 'html.parser')

        try:
            self.batting_style = self.soup.find(text="Batting Style").parent.parent.find_all("p")[1].text
            self.bowling_style = self.soup.find(text="Bowling Style").parent.parent.find_all("p")[1].text
        except (AttributeError, TypeError):
            self.batting_style = None
            self.bowling_style = None

# %%
import pandas as pd
df = pd.read_csv('supportive_csv_files/combined_names_with_id.csv')
df.head(20)
# Out:
#    identifier                                          all_names  key_cricinfo
# 0    b4a23876                                  ['AAA Amsterdam']      772407.0
# 1    482762af                                      ['AA Adeoye']      380588.0
# 2    4b0e3049               ['A Alleyne' 'AA Alleyne' 'Alleyne']      661441.0
# 3    fd3c5c00                                      ['AAA Patel']     1163136.0
# 4    bc005f0d                                      ['AAA White']      474307.0
# 5    5c67c7a6                                        ['AA Baig']      524897.0
# 6    6a58e069              ['A A Bamal' 'AA Bamal' 'Arun Bamal']     1123075.0
# 7    02d11602                                      ['AA Banner']      590021.0
# 8    b690f34a               ['A A Barot' 'AA Barot' 'Avi Barot']      398519.0
# 9    c7a9ffbf                                   ['AA Bevilaqua']      959617.0
# 10   bff458c6                                    ['AA Bilakhia']       26946.0
# 11   44e58b5b  ['A A Chakraborty' 'AA Chakraborty' 'Abhijit C...      680363.0
# 12   29d72eb2                           ['A Chavan' 'AA Chavan']      337913.0
# 13   b2c38dce                                   ['AA Choudhury']     1339014.0
# 14   d37fd2c3                                        ['A Adams']      464322.0
# 15   1b0ce76e                                     ['A Adekunle']     1365288.0
# 16   cfa56623                                   ['AA Deshpande']      220679.0
# 17   4c931d56                       ['AA Donald' 'Allan Donald']       44716.0
# 18   9dbc77b3                               ['Aaftab Alam Khan']     1269467.0
# 19   a768a762                                       ['AA Gajic']     1323426.0

# %% [markdown]
# <strong>please mention here alredy scraped range!</strong>  \
# completed

# %%
# For each player in df, create a PlayerURL object and fetch player type and add to df as new columns
df_with_types = df.iloc[8300:8400, ].copy()

# Using multithreading to speed up the process
from concurrent.futures import ThreadPoolExecutor

def get_player_info(index, row):
    player = Player(index, row['key_cricinfo'], row['all_names'])
    player.get_valid_url()
    player.scrape_info()
    return player

with ThreadPoolExecutor() as executor:
    players = list(executor.map(lambda x: get_player_info(*x), df_with_types.iterrows()))

for player in players:
	df_with_types.at[player.identifier, 'batting_style'] = player.batting_style
	df_with_types.at[player.identifier, 'bowling_style'] = player.bowling_style
# Out:
# No Valid URL Found for PlayerURL(key_cricinfo=914573.0, all_names=['Mehmood Kharotai'], valid_url=None)

# %%
df_with_types.head(50)
# Out:
#      identifier                                          all_names  \
# 8300   3342d234                                       ['M Davies']
# 8301   1b3acd33                                       ['MD Bates']
# 8302   f53d6c10              ['M Bates' 'MD Bates' 'MD Bates (2)']
# 8303   4921afa2                         ['MD Bell' 'Matthew Bell']
# 8304   c1a0cebe       ['BIMENYIMANA Marie Diane' 'MD Bimenyimana']
# 8305   dedcacf9                                     ['MD Bunkall']
# 8306   d0601d66                                   ['MDC Ferguson']
# 8307   c8574282                ['M Craig' 'MD Craig' 'Mark Craig']
# 8308   ed7f7d09                        ['MD Crowe' 'Martin Crowe']
# 8309   5be810ba                                 ['M Dai' 'MD Dai']
# 8310   e5ad357a                                    ['MD du Preez']
# 8311   d34a2268                          ['M Holden' 'MDE Holden']
# 8312   d4eef961                 ['M de Lange' 'Marchant de Lange']
# 8313   9a7d3339                                    ['M del Valle']
# 8314   5bb7ec70                                    ['M De Ridder']
# 8315   7ec52f4a                                      ['M Desmond']
# 8316   7183799b                                        ['M Deyal']
# 8317   8f2dfebf                           ['M Fisher' 'MD Fisher']
# 8318   aa4154ad                                     ['MD Garratt']
# 8319   509a7ca1  ['D Gunathilaka' 'Danushka Gunathilaka' 'MD Gu...
# 8320   1f3e6df4                                  ['M Dharmichand']
# 8321   ca81c65c                                ['M Dheeraj Kumar']
# 8322   069c55b1                                        ['MD Hunn']
# 8323   5af87ad6                       ['M Dillon' 'Merwyn Dillon']
# 8324   a584021c                       ['MD Ingale' 'Manoj Ingale']
# 8325   d85d52c2                                ['Dixit' 'M Dixit']
# 8326   37b67a54                                     ['MDJ Walker']
# 8327   f21043a5         ['KJ Perera' 'Kusal Perera' 'MDKJ Perera']
# 8328   5531248e                   ['Dilruwan Perera' 'MDK Perera']
# 8329   877a3433                                      ['M Dlamini']
# 8330   43fdb946                 ['MD Marshall' 'Malcolm Marshall']
# 8331   487c072e                                     ['MD Martell']
# 8332   81cebf35                                       ['MD McKay']
# 8333   6afb26d6                           ['M Mishra' 'MD Mishra']
# 8334   66e822a2                        ['MD Moxon' 'Martyn Moxon']
# 8335   1471c041                          ['Md Nazim' 'Mohd Nazim']
# 8336   dfc89c58                        ['MDN Hansika' 'N Hansika']
# 8337   96513a65                     ['MD Nidheesh' 'Nidheesh M D']
# 8338   71afd6ad                                  ['Md Nurul Huda']
# 8339   84cf842e                                      ['M Donegan']
# 8340   25d7f1ac                             ['M Patel' 'MD Patel']
# 8341   ca5ef21b                                     ['MD Poskitt']
# 8342   1c06d60a                                         ['MD Rae']
# 8343   c10a99ec                  ['MD Rahmatullah' 'Rahmat Ullah']
# 8344   c037d0ca                                     ['MD Ralston']
# 8345   22ee7ea8                                         ['MD Rao']
# 8346   30aa04d2                                       ['MD Rocha']
# 8347   febe4bfa                                     ['Md Saptula']
# 8348   27128c74                              ['Md Shafiqul Haque']
# 8349   3ff033bb         ['D Shanaka' 'Dasun Shanaka' 'MD Shanaka']
#
#       key_cricinfo   batting_style                      bowling_style
# 8300       12457.0  Right hand Bat                   Right arm Medium
# 8301       36590.0  Right hand Bat               Left arm Medium fast
# 8302      351424.0            None                               None
# 8303       36294.0  Right hand Bat                 Right arm Offbreak
# 8304     1172637.0  Right hand Bat                   Right arm Medium
# 8305      438262.0  Right hand Bat                   Right arm Medium
# 8306      542343.0            None                               None
# 8307      497543.0   Left hand Bat                 Right arm Offbreak
# 8308       36622.0  Right hand Bat                   Right arm Medium
# 8309       25051.0  Right hand Bat  Right arm Medium, Legbreak Googly
# 8310      577345.0  Right hand Bat                           Legbreak
# 8311      641387.0   Left hand Bat                 Right arm Offbreak
# 8312      393279.0  Right hand Bat                     Right arm Fast
# 8313     1203264.0  Right hand Bat                   Right arm Medium
# 8314      499268.0            None                               None
# 8315     1172353.0  Right hand Bat                           Legbreak
# 8316      848623.0   Left hand Bat                 Right arm Offbreak
# 8317      639080.0  Right hand Bat              Right arm Fast medium
# 8318     1156440.0  Right hand Bat                   Right arm Medium
# 8319      345821.0   Left hand Bat                 Right arm Offbreak
# 8320       28070.0  Right hand Bat                 Right arm Offbreak
# 8321     1246430.0  Right hand Bat                 Right arm Offbreak
# 8322      523366.0  Right hand Bat              Right arm Fast medium
# 8323       51651.0  Right hand Bat              Right arm Fast medium
# 8324     1175610.0  Right hand Bat                   Right arm Medium
# 8325     1198920.0  Right hand Bat               Left arm Medium fast
# 8326       38760.0  Right hand Bat                   Right arm Medium
# 8327      300631.0            None                               None
# 8328       49920.0  Right hand Bat                 Right arm Offbreak
# 8329     1276656.0  Right hand Bat              Right arm Medium fast
# 8330       52419.0  Right hand Bat                     Right arm Fast
# 8331      266250.0            None                               None
# 8332     1068920.0            None                               None
# 8333       31028.0  Right hand Bat                 Right arm Offbreak
# 8334       17119.0  Right hand Bat                   Right arm Medium
# 8335     1246445.0  Right hand Bat              Right arm Medium fast
# 8336      342862.0   Left hand Bat              Right arm Medium fast
# 8337      822703.0  Right hand Bat                   Right arm Medium
# 8338     1156466.0  Right hand Bat                 Right arm Offbreak
# 8339     1112208.0            None                               None
# 8340     1159641.0            None                               None
# 8341     1151390.0            None                               None
# 8342      622772.0  Right hand Bat              Right arm Medium fast
# 8343     1159822.0            None                               None
# 8344      338730.0            None                               None
# 8345      876175.0            None                               None
# 8346     1196252.0  Right hand Bat                   Right arm Medium
# 8347     1246523.0  Right hand Bat                 Right arm Offbreak
# 8348     1093678.0  Right hand Bat                 Right arm Offbreak
# 8349      437316.0  Right hand Bat                   Right arm Medium

# %%
# import pandas as pd

# # Create a new DataFrame with the same columns but no data
# df_empty = pd.DataFrame(columns=df_with_types.columns)
# df_empty.drop(columns=['key_cricinfo'], inplace=True)

# # Write the empty DataFrame to CSV files
# df_empty.to_csv('scraper_outputs/player_type.csv', index=False)
# df_empty.to_csv('scraper_outputs/couldnt_find.csv', index=False)

# %%
# Drop the 'key_cricinfo' column without affecting df_with_types
new_data = df_with_types.drop(columns=['key_cricinfo'])

# Filter the data
couldnt_find = new_data[(new_data['batting_style'].isna()) | (new_data['bowling_style'].isna())]
player_type = new_data.drop(couldnt_find.index)


# Append the data to the existing CSV files
couldnt_find.to_csv('scraper_outputs/couldnt_find.csv', mode='a', header=False, index=False)
player_type.to_csv('scraper_outputs/player_type.csv', mode='a', header=False, index=False)

new_data.head(10)
# Out:
#       identifier                          all_names   batting_style  \
# 15000   f0b16e64                         ['Z Mali']  Right hand Bat
# 15001   679302a1                   ['Z McLaughlin']  Right hand Bat
# 15002   57d72252                    ['Z Mkhwanazi']  Right hand Bat
# 15003   5f6e3137                    ['ZM Ringrose']   Left hand Bat
# 15004   96fe3e9f                       ['ZM Tribe']  Right hand Bat
# 15005   eec5fe00  ['Gibson' 'Z Gibson' 'ZN Gibson']  Right hand Bat
# 15006   ec29da98                       ['Z Nizami']            None
# 15007   a3a1c7ef                    ['Zohaib Khan']  Right hand Bat
# 15008   bd3cecc6                  ['Zohaib Sarwar']  Right hand Bat
# 15009   7d70dc87                     ['Zoha Irfan']  Right hand Bat
#
#                 bowling_style
# 15000        Right arm Medium
# 15001                Legbreak
# 15002        Right arm Medium
# 15003        Right arm Medium
# 15004         Legbreak Googly
# 15005        Right arm Medium
# 15006                    None
# 15007  Slow Left arm Orthodox
# 15008   Right arm Medium fast
# 15009   Right arm Medium fast

# %%
# remove duplicates from csv

import pandas as pd

# Load your data
df1 = pd.read_csv('scraper_outputs/player_type.csv')
df2 = pd.read_csv('scraper_outputs/couldnt_find.csv')

# df.set_index('identifier')

# Remove duplicates
df1 = df1.drop_duplicates()
df2 = df2.drop_duplicates()

# Write the result back to CSV
df1.to_csv('scraper_outputs/player_type.csv', index=False)
df2.to_csv('scraper_outputs/couldnt_find.csv', index=False)

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('scraper_outputs/player_type.csv')

# Check the unique values in the batting_style column
batting_styles = df['batting_style'].unique()

# Check the unique values in the bowling_style column
bowling_styles = df['bowling_style'].unique()

# Count the number of unique batting styles
num_batting_styles = len(batting_styles)

# Count the number of unique bowling styles
num_bowling_styles = len(bowling_styles)

# Print the results
print(f"Number of unique batting styles: {num_batting_styles}")
print(f"Number of unique bowling styles: {num_bowling_styles}")
# Out:
# Number of unique batting styles: 2
# Number of unique bowling styles: 10

# %%
import pandas as pd

data = {
    'bowling style': bowling_styles,
}

df = pd.DataFrame(data)
df
# Out:
#          bowling style
# 0     Right arm Medium
# 1    Left arm Orthodox
# 2   Right arm Offbreak
# 3   Right arm Legbreak
# 4       Right arm Fast
# 5      Left arm Medium
# 6        Left arm Fast
# 7   Right arm offbreak
# 8  Left arm Wrist spin
# 9     Right arm Bowler

# %% [markdown]
# Right arm Medium fast ---> Right arm Medium
# Left arm Medium fast ---> Left arm Medium
# Right arm Fast medium ---> Right arm Fast
# Left arm Medium fast ---> Left arm Medium
# Legbreak Googly ---> legbreak
# Slow Left arm Orthodox ---> Left arm Orthodox
# Left arm slow ---> Left arm Orthodox
# Right arm slow ---> Right arm offbreak
# Right arm Slow medium ---> Right arm offbreak
# Left arm Slow medium ---> Left arm Slow
# Right arm Offbrea ---> Right arm Offbreak

# %%
for style in df['bowling style']:
    print(style)
# Out:
# Right arm Medium
# Left arm Orthodox
# Right arm Offbreak
# Right arm Legbreak
# Right arm Fast
# Left arm Medium
# Left arm Fast medium
# Right arm offbreak
# Left arm Wrist spin
# Left arm Fast
# Right arm Bowler
# Left arm Slow

# %%
# Read the CSV file
df = pd.read_csv('scraper_outputs/player_type.csv')

# Define a dictionary for the replacements
replacements = {
    'Right arm Medium fast': 'Right arm Medium',
    'Left arm Medium fast': 'Left arm Medium',
    'Right arm Fast medium': 'Right arm Fast',
    'Legbreak Googly': 'Right arm Legbreak',
    'Slow Left arm Orthodox': 'Left arm Orthodox',
    'Left arm slow': 'Left arm Orthodox',
    'Right arm slow': 'Right arm offbreak',
    'Right arm Slow medium': 'Right arm offbreak',
    'Left arm Slow medium': 'Left arm Slow',
    'Right arm Offbrea': 'Right arm Offbreak',
    'Right arm Slow' : 'Right arm offbreak',
    'Legbreak' : 'Right arm Legbreak',
    'Left arm Fast medium' : 'Left arm Fast',
    'Left arm Slow': 'Left arm Orthodox',
    
}

# Replace the values in the 'batting_style' column
df['bowling_style'] = df['bowling_style'].replace(replacements)

# Save the DataFrame back to CSV
df.to_csv('scraper_outputs/player_type.csv', index=False)

# %%
# remove duplicates from csv

import pandas as pd

# Load your data
df1 = pd.read_csv('scraper_outputs/player_type.csv')
df2 = pd.read_csv('scraper_outputs/couldnt_find.csv')

# df.set_index('identifier')

# Remove duplicates
df1 = df1.drop_duplicates()
df2 = df2.drop_duplicates()

# Write the result back to CSV
df1.to_csv('scraper_outputs/player_type.csv', index=False)
df2.to_csv('scraper_outputs/couldnt_find.csv', index=False)
