# %%
from converters import json_to_csv

# allData,playerMapping = json_to_csv('211028_test.json', output_file=True)
# print("player Mapping",playerMapping)
json_to_csv('211028_test.json', output_file=True)
# print("player Mapping",playerMapping)

# %%
import pandas as pd

df = pd.read_csv('csv_files/211028_Australia_2.csv')
df.head(25)
# Out:
#     Unnamed: 0        batter   bowler   non_striker  runs_by_bat  extra_runs  \
# 0            0  AC Gilchrist  D Gough     ML Hayden            0           0
# 1            1  AC Gilchrist  D Gough     ML Hayden            4           0
# 2            2  AC Gilchrist  D Gough     ML Hayden            0           0
# 3            3  AC Gilchrist  D Gough     ML Hayden            0           0
# 4            4  AC Gilchrist  D Gough     ML Hayden            4           0
# 5            5  AC Gilchrist  D Gough     ML Hayden            0           0
# 6            6     ML Hayden  J Lewis  AC Gilchrist            4           0
# 7            7     ML Hayden  J Lewis  AC Gilchrist            1           0
# 8            8  AC Gilchrist  J Lewis     ML Hayden            0           0
# 9            9  AC Gilchrist  J Lewis     ML Hayden            0           0
# 10          10  AC Gilchrist  J Lewis     ML Hayden            4           0
# ...

# %%
from summaryData import Summary
match = Summary('211028.json')
match.fall_of_wicket(2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 from summaryData import Summary
# ----> 2 match = Summary('211028.json')
#       3 match.fall_of_wicket(2)
#
# File f:\AAATheCodex\CE\Sem6\CO544\Project\Repo\e19-co544-cricket-analytics-and-prediction\JSON2CSV\summaryData.py:14, in Summary.__init__(self, match)
#      12 self.match = match
#      13 if match.endswith(".json"):
# ---> 14     self.teams_df, self.info = json_to_csv(match)
#      15 else:
#      16     print("enter a valid json file")
#
# File f:\AAATheCodex\CE\Sem6\CO544\Project\Repo\e19-co544-cricket-analytics-and-prediction\JSON2CSV\converters.py:86, in json_to_csv(match_file, output_file)
#      84 def json_to_csv(match_file, output_file=False):
# ---> 86     with open(match_file, "r") as f:
#      87         file = json.load(f)
#      89     info = file["info"]
#
# ...
