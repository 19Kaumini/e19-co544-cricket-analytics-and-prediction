# %%
import pandas as pd
df = pd.read_csv("merged_data.csv")
df.head()
# Out:
# C:\Users\Mansitha Eashwara\AppData\Local\Temp\ipykernel_7240\3411486647.py:2: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("merged_data.csv")
#    Unnamed: 0     batter      bowler non_striker  runs_by_bat  extra_runs  \
# 0           0   AJ Finch  SL Malinga   M Klinger            0           0
# 1           1   AJ Finch  SL Malinga   M Klinger            0           0
# 2           2   AJ Finch  SL Malinga   M Klinger            1           0
# 3           3  M Klinger  SL Malinga    AJ Finch            2           0
# 4           4  M Klinger  SL Malinga    AJ Finch            0           0
#
#    total  team_total  batter_runs  balls_faced  ...  toss_decision  \
# 0      0           0            0            1  ...          field
# 1      0           0            0            2  ...          field
# 2      1           1            1            3  ...          field
# ...
