# %% [markdown]
# # Batting Order Model Development
#
# This notebook will explore different models to get the win probability of a match given the state of the match and the next batsman to walk in to the crease. The input also contains the remaining quota of balls for different bowler types. This is a future value, but under the assumption of 5 bowlers or 4 bowlers with two part time bowlers, that future value is already available for the team.

# %% [markdown]
# Input --> Batter,  Team , Ball number, Innings, Non- striker
# Ouput --> Win Probability

# %%
import pandas as pd

# Load the data
data = pd.read_csv('../Data/selected_data/processed_data.csv')
venue_data = pd.read_csv('../Data/selected_data/venues.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217242 entries, 0 to 217241
# Data columns (total 32 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   batter               217242 non-null  object
#  1   bowler               217242 non-null  object
#  2   non_striker          217242 non-null  object
#  3   runs_by_bat          217242 non-null  int64
#  4   extra_runs           217242 non-null  int64
#  5   total_runs_delivery  217242 non-null  int64
#  6   current_team_total   217242 non-null  int64
#  7   runs_remain          217242 non-null  float64
#  8   batter_runs          217242 non-null  int64
#  9   balls_faced          217242 non-null  int64
#  10  wickets_fallen       217242 non-null  int64
#  11  extra_type           217242 non-null  object
#  12  delivery             217242 non-null  float64
#  13  over                 217242 non-null  int64
#  14  wicket_type          217242 non-null  object
#  15  player_out           217242 non-null  object
#  16  toss_decision        217242 non-null  object
#  17  toss_winner          217242 non-null  object
#  18  innings              217242 non-null  int64
#  19  venue                217242 non-null  object
#  20  year                 217242 non-null  int64
#  21  month                217242 non-null  int64
#  22  match_id             217242 non-null  object
#  23  winning_team         217242 non-null  object
#  24  batting_team         217242 non-null  object
#  25  bowling_team         217242 non-null  object
#  26  won                  217242 non-null  float64
#  27  final_team_total     217242 non-null  int64
#  28  batter_type          217242 non-null  object
#  29  non_striker_type     217242 non-null  object
#  30  bowler_type          217242 non-null  object
#  31  replacements         217242 non-null  object
# dtypes: float64(3), int64(12), object(17)
# memory usage: 53.0+ MB

# %% [markdown]
# Selecting Player "KM Mendis"

# %%
# sl_batsmen = data[data['batting_team'] == "Sri Lanka"]['batter'].unique()
# sl_batsmen

# %%
all_batsmen = data['batter'].unique()
all_batsmen
# Out:
# array(['AJ Finch', 'M Klinger', 'TM Head', 'MC Henriques', 'AJ Turner',
#        'JP Faulkner', 'N Dickwella', 'WU Tharanga', 'EMDY Munaweera',
#        'DAS Gunaratne', 'TAM Siriwardana', 'CK Kapugedera', 'S Prasanna',
#        'BR Dunk', 'TD Paine', 'PJ Cummins', 'AJ Tye', 'JA Richardson',
#        'BKG Mendis', 'KMDN Kulasekara', 'SL Malinga', 'MD Shanaka',
#        'JRMVB Sanjaya', 'KL Rahul', 'AT Rayudu', 'Mandeep Singh',
#        'MK Pandey', 'KM Jadhav', 'MS Dhoni', 'AR Patel', 'R Dhawan',
#        'CJ Chibhabha', 'H Masakadza', 'R Mutumbami', 'Sikandar Raza',
#        'MN Waller', 'CT Mutombodzi', 'E Chigumbura', 'AG Cremer',
#        'N Madziva', 'PJ Moor', 'DT Tiripano', 'T Muzarabani',
#        'DS Kulkarni', 'V Sibanda', 'T Maruma', 'Tamim Iqbal',
#        'Imrul Kayes', 'Sabbir Rahman', 'Shakib Al Hasan', 'Soumya Sarkar',
#        'Mahmudullah', 'Mosaddek Hossain', 'Mashrafe Mortaza',
#        'Nurul Hasan', 'Rubel Hossain', 'NT Broom', 'KS Williamson',
#        'C Munro', 'CJ Anderson', 'TC Bruce', 'C de Grandhomme',
#        'Mustafizur Rahman', 'L Ronchi', 'JDS Neesham', 'MJ Santner',
#        'GD Phillips', 'BM Wheeler', 'TG Southee', 'TA Boult', 'HM Amla',
#        'Q de Kock', 'F du Plessis', 'AB de Villiers', 'JP Duminy',
#        'F Behardien', 'CH Morris', 'WD Parnell', 'JJ Roy', 'AD Hales',
#        'JM Bairstow', 'JT Smuts', 'RR Hendricks', 'DA Miller',
#        'SW Billings', 'LS Livingstone', 'JC Buttler', 'EJG Morgan',
#        'LA Dawson', 'M Mosehle', 'AL Phehlukwayo', 'M Morkel',
#        'D Paterson', 'DJ Malan', 'LE Plunkett', 'DJ Willey', 'TK Curran',
#        'JE Root', 'AU Rashid', 'CJ Jordan', 'CH Gayle', 'E Lewis',
#        'MN Samuels', 'CAK Walton', 'KA Pollard', 'R Powell',
#        'CR Brathwaite', 'SP Narine', 'AR Nurse', 'JE Taylor',
#        'KOK Williams', 'BA Stokes', 'V Kohli', 'SK Raina', 'Yuvraj Singh',
#        'HH Pandya', 'Parvez Rasool', 'MM Ali', 'TS Mills', 'RR Pant',
#        'RG Sharma', 'AM Rahane', 'J Charles', 'AD Russell', 'DJ Bravo',
#        'LMP Simmons', 'ADS Fletcher', 'S Badree', 'Sharjeel Khan',
#        'Khalid Latif', 'Babar Azam', 'N Pooran', 'Shoaib Malik',
#        'Sarfraz Ahmed', 'Umar Akmal', 'DA Warner', 'DJM Short', 'CA Lynn',
#        'GJ Maxwell', 'MJ Guptill', 'LRPL Taylor', 'TA Blundell',
#        'IS Sodhi', 'MP Stoinis', 'AT Carey', 'MA Wood', 'JM Vince',
#        'MS Chapman', 'TL Seifert', 'AC Agar', 'Mushfiqur Rahim',
#        'Mohammad Saifuddin', 'Mehedi Hasan Miraz', 'Taskin Ahmed',
#        'Shafiul Islam', 'Liton Das', 'Kamran Akmal', 'Ahmed Shehzad',
#        'Mohammad Hafeez', 'JO Holder', 'Fakhar Zaman', 'Imad Wasim',
#        'Sohail Tanvir', 'Shadab Khan', 'Wahab Riaz', 'Hasan Ali',
#        'MDKJ Perera', 'NLTC Perera', 'JN Mohammed', 'S Dhawan',
#        'KD Karthik', 'RA Jadeja', 'R Ashwin', 'AD Mathews',
#        'SMA Priyanjan', 'I Udana', 'AK Kitchen', 'DAJ Bracewell',
#        'SD Hope', 'SO Hetmyer', 'RR Emrit', 'Umar Amin',
#        'Mohammad Nawaz (3)', 'Haris Sohail', 'Faheem Ashraf',
#        'Mohammad Amir', 'SHA Rance', 'Aamer Yamin', 'DT Christian',
#        'NM Coulter-Nile', 'A Zampa', 'B Kumar', 'Kuldeep Yadav',
#        'JJ Bumrah', 'YS Chahal', 'KW Richardson', 'MJ Swepson',
#        'B Stanlake', 'TWM Latham', 'HM Nicholls', 'SS Iyer',
#        'MD Gunathilaka', 'S Samarawickrama', 'ML Udawatte',
#        'SS Pathirana', 'PC de Silva', 'H Klaasen', 'CJ Dala', 'T Shamsi',
#        'C Jonker', 'A Dananjaya', 'PVD Chameera', 'MVT Fernando',
#        'N Pradeep', 'Zakir Hasan', 'Afif Hossain', 'Ariful Haque',
#        'Mohammad Mithun', 'Mahedi Hasan', 'Abu Jayed', 'Nazmul Islam',
#        'LD Chandimal', 'BMAJ Mendis', 'RAS Lakmal', 'V Shankar',
#        'Mohammad Shahzad', 'Karim Sadiq', 'Asghar Stanikzai',
#        'Mohammad Nabi', 'Sharafuddin Ashraf', 'Najibullah Zadran',
#        'Shafiqullah', 'SF Mire', 'BRM Taylor', 'RP Burl', 'KM Jarvis',
#        'TL Chatara', 'B Muzarabani', 'Gulbadin Naib', 'Rashid Khan',
#        'Aftab Alam', 'Hussain Talat', 'Asif Ali', 'D Ramdin', 'KMA Paul',
#        'OF Smith', 'AM McCarthy', 'JL Denly', 'DM de Silva',
#        'PHKD Mendis', 'MA Aponso', 'PADLR Sandakan', 'PR Stirling',
#        'JNK Shannon', 'A Balbirnie', 'Simi Singh', 'GC Wilson',
#        "KJ O'Brien", 'SW Poynter', 'SR Thompson', 'GH Dockrell',
#        'WB Rankin', 'PKD Chase', 'WTS Porterfield', 'K Rabada', 'L Ngidi',
#        'TK Musakanda', 'TS Chisoro', 'J Nyumbu', 'CB Mpofu', 'C Zhuwao',
#        'NJ Maddinson', 'B Mavuta', 'WP Masakadza', 'JD Wildermuth',
#        'Sahibzada Farhan', 'GL Cloete', 'HE van der Dussen',
#        'SC Williams', 'Mohammad Rizwan', 'JN Malan',
#        'Shaheen Shah Afridi', 'BE Hendricks', 'L Sipamla', 'DW Steyn',
#        'Imran Tahir', 'WIA Fernando', 'AK Perera', 'AK Markram',
#        'D Pretorius', 'BR McDermott', 'KH Pandya', 'Usman Ghani',
#        'Samiullah Shenwari', 'Karim Janat', 'Abul Hasan', 'Abu Hider',
#        'Hazratullah', 'J Little', 'TE Kane', 'BM Duckett', 'Imam-ul-Haq',
#        'DM Bravo', 'FA Allen', 'SS Cottrell', 'O Thomas', 'SE Rutherford',
#        'KK Ahmed', 'DJ Mitchell', 'SC Kuggeleijn', 'CAK Rajitha',
#        'CBRLS Kumara', 'MR Marsh', 'NM Lyon', 'LH Ferguson', 'K Pierre',
#        'D Bishoo', 'OC McCoy', 'JD Campbell', 'SC Getkate', 'L Tucker',
#        'Najeeb Tarakai', 'PSP Handscomb', 'UT Yadav', 'CR Ervine',
#        'GJ Thompson', 'MR Adair', 'GJ Delany', 'PBB Rajapaksa',
#        'BOP Fernando', 'PWH de Silva', 'SPD Smith', 'GSNFG Jayasuriya',
#        'Iftikhar Ahmed', 'Khushdil Shah', 'Mohammad Hasnain', 'T Bavuma',
#        'BC Fortuin', 'MS Wade', 'MA Starc', 'PJ van Biljon', 'A Nortje',
#        'Washington Sundar', 'Navdeep Saini', 'Mohammad Naim', 'S Dube',
#        'Aminul Islam', 'BA King', 'DL Chahar', 'HR Walsh', 'SM Curran',
#        'L Gregory', 'S Mahmood', 'PR Brown', 'T Banton', 'BM Tickner',
#        'SV Samson', 'SN Thakur', 'HK Bennett', 'HD Rutherford',
#        'TD Astle', 'LD Madushanka', 'Rahmanullah Gurbaz',
#        'Ibrahim Zadran', 'Fareed Ahmad', 'Naveen-ul-Haq',
#        'Mujeeb Ur Rahman', 'RW Chakabva', 'Taijul Islam',
#        'Nazmul Hossain Shanto', 'A Ndlovu', 'Fazal Niazai', 'Haider Ali',
#        'M Bhanuka', 'HT Tector', 'BJ McCarthy', 'CA Young', 'Ahsan Ali',
#        'TS Kamunhukamwe', 'W Madhevere', 'CT Mumba', 'SA Abbott',
#        'DR Sams', 'Abdullah Shafique', 'M Shumba', 'M Faraz Akram',
#        'DP Conway', 'KR Mayers', 'Haris Rauf', 'JR Philippe',
#        'KA Jamieson', 'Shoriful Islam', 'Nasum Ahmed', 'FH Allen',
#        'WA Young', 'GF Linde', 'MW Parkinson', 'Sohaib Maqsood',
#        'Azam Khan', 'GJ Snyman', 'Usman Qadir', 'Ishan Kishan',
#        'JC Archer', 'SA Yadav', 'B Fernando', 'WJ Lubbe', 'SSB Magala',
#        'PWA Mulder', 'LB Williams', 'B White', 'P Nissanka',
#        'KNA Bandara', 'K Sinclair', 'FH Edwards', 'R Shepherd',
#        'AJ Hosein', 'HC Brook', 'PD Salt', 'GHS Garton', 'RJW Topley',
#        'Danish Aziz', 'T Marumani', 'LM Jongwe', 'Arshad Iqbal',
#        'R Ngarava', 'PP Shaw', 'KIC Asalanka', 'C Karunaratne',
#        'RD Gaikwad', 'D Padikkal', 'N Rana', 'RTM Mendis', 'RD Chahar',
#        'CV Varun', 'C Sakariya', 'JR Hazlewood', 'JP Behrendorff',
#        'Mohammad Wasim', 'JP Inglis', 'M Theekshana', 'JDF Vandersay',
#        'K Mishara', 'J Liyanage', 'D Myers', 'Shamim Hossain', 'NT Ellis',
#        'P Jayawickrama', 'R Ravindra', 'CE McConchie', 'AY Patel',
#        'JA Duffy', 'C Campher', 'NA Rock', 'W McClintock', 'AR McBrine',
#        'KA Maharaj', 'R Rampaul', 'RL Chase', 'CR Woakes', 'DJ Hooda',
#        'HV Patel', 'Arshdeep Singh', 'RJ Gleeson', 'Avesh Khan',
#        'Ravi Bishnoi', 'RR Rossouw', 'T Stubbs', 'Saif Hassan',
#        'Mohammad Nawaz', 'VR Iyer', 'AF Milne', 'DC Drakes', 'M Jansen',
#        'DC Thomas', 'SSJ Brooks', 'M Labuschagne', 'C Green',
#        'BJ Dwarshuis', 'T Munyonga', 'TH David', 'Azmatullah Omarzai',
#        'Fazalhaq Farooqi', 'Shan Masood', 'F Hand', 'Hasan Mahmud',
#        'B Evans', 'Yasir Ali Chowdhury', 'Mohammed Shami',
#        'Mohammad Haris', 'Naseem Shah', 'Darwish Rasooli', 'Qais Ahmad',
#        'Munim Shahriar', 'D Cleaver', 'MG Bracewell',
#        'Hashmatullah Shahidi', 'GI Hume', 'N Thushara', 'I Kaia',
#        'Ihsanullah', 'Afsar Zazai', 'Noor Ahmad', 'Nijat Masood',
#        'C Madande', 'Anamul Haque', 'RA Reifer', 'AS Joseph', 'Y Cariah',
#        'CJ Bowes', 'HB Shipley', 'PM Liyanagamage', 'D Madushanka',
#        'Parvez Hossain Emon', 'VM Nyauchi', 'WG Jacks', 'OP Stone',
#        'Aamer Jamal', 'M Pathirana', 'Shahnawaz Dhani', 'AM Fernando',
#        'Mohammed Siraj', 'L Wood', 'AAP Atkinson', 'Rehan Ahmed',
#        'BA Carse', 'MJ Henry', 'BG Lister', 'Saim Ayub', 'Zaman Khan',
#        'GR Adair', 'ST Doheny', 'GS Ballance', 'Shubman Gill',
#        'RA Tripathi', 'Shivam Mavi', 'Umran Malik', 'Rony Talukdar',
#        'Towhid Hridoy', 'Rishad Hossain', 'Tayyab Tahir',
#        'Sediqullah Atal', 'MW Short', 'AM Hardie', 'D Brevis',
#        'G Coetzee', 'MP Breetzke', 'D Ferreira', 'MW Forde', 'G Motie',
#        'Tilak Varma', 'Mukesh Kumar', 'YBK Jaiswal', 'RK Singh',
#        'JM Sharma', 'N Burger', 'BV Sears', 'Tanvir Islam', 'Usama Mir',
#        'Abbas Afridi', 'Haseebullah Khan', 'JA Clarkson', 'T Sangha',
#        'CJ Green', 'Rahmat Shah', 'Noor Ali Zadran', 'Shahidullah',
#        'Zahir Khan', 'S Daniel', 'L Croospulle', 'MNK Fernando',
#        'SSD Arachchige', 'LU Igalagamage', 'RS Fernando',
#        'SMLD Samarakoon', 'V Viyaskanth', 'N Vimukthi',
#        'Mahmudul Hasan Joy', 'Shahadat Hossain', 'Jaker Ali',
#        'Mrittunjoy Chowdhury', 'Rakibul Hasan', 'R Mondol',
#        'Omair Yousuf', 'Mirza Baig', 'Rohail Nazir', 'Qasim Akram',
#        'Arafat Minhas', 'Sufiyan Muqeem', 'Zubaid Akbari', 'BJ Bennett',
#        'T Gwandu', 'Mohammad Ishaq', 'Ijaz Ahmad Ahmadzai',
#        'Nangeyalia Kharote', 'AC Gilchrist', 'ML Hayden', 'A Symonds',
#        'MJ Clarke', 'MEK Hussey', 'RT Ponting', 'DR Martyn', 'B Lee',
#        'JN Gillespie', 'MS Kasprowicz', 'GD McGrath', 'ME Trescothick',
#        'GO Jones', 'A Flintoff', 'KP Pietersen', 'MP Vaughan',
#        'PD Collingwood', 'AJ Strauss', 'VS Solanki', 'SM Katich',
#        'BB McCullum', 'SP Fleming', 'MS Sinclair', 'SB Styris',
#        'CD McMillan', 'CL Cairns', 'HJH Marshall', 'AR Adams',
#        'JW Wilson', 'DR Tuffey', 'KD Mills', 'NJ Astle', 'JDP Oram',
#        'GC Smith', 'JH Kallis', 'HH Gibbs', 'JM Kemp', 'MV Boucher',
#        'SM Pollock', 'AG Prince', 'JA Morkel', 'CK Langeveldt', 'M Ntini',
#        'A Nel', 'IR Bell', 'JWM Dalrymple', 'MH Yardy', 'CMW Read',
#        'SI Mahmood', 'Younis Khan', 'Shahid Afridi', 'Mohammad Yousuf',
#        'Inzamam-ul-Haq', 'Abdul Razzaq', 'TT Bresnan', 'ST Jayasuriya',
#        'DPMD Jayawardene', 'TM Dilshan', 'KC Sangakkara', 'RP Arnold',
#        'MF Maharoof', 'CRD Fernando', 'JR Hopes', 'HH Dippenaar',
#        'AJ Hall', 'JA Rudolph', 'J Botha', 'GJP Kruger', 'M Zondeki',
#        'L Vincent', 'PG Fulton', 'JEC Franklin', 'SE Bond', 'D Ganga',
#        'RS Morton', 'DR Smith', 'WW Hinds', 'S Chanderpaul', 'SR Watson',
#        'GB Hogg', 'NW Bracken', 'LE Bosman', 'JJ van der Wath',
#        'CL White', 'EC Joyce', 'PA Nixon', 'J Lewis', 'MS Panesar',
#        'JM Anderson', 'JAH Marshall', 'PD McGlashan', 'MR Gillespie',
#        'MS Atapattu', 'LPC Silva', 'HMCM Bandara', 'V Sehwag',
#        'SR Tendulkar', 'D Mongia', 'RJ Peterson', 'R Telemachus',
#        'T Henderson', 'AN Cook', 'MJ Prior', 'IJL Trott', 'OA Shah',
#        'AD Mascarenhas', 'SCJ Broad', 'DS Smith', 'DJG Sammy',
#        'ACL Richards', 'RR Sarwan', 'BJ Hodge', 'BJ Haddin', 'MG Johnson',
#        'T Taibu', 'S Matsikenyeri', 'Nazimuddin', 'Aftab Ahmed',
#        'Mohammad Ashraful', 'Alok Kapali', 'DBL Powell', 'DL Maddy',
#        'LJ Wright', 'CP Schofield', 'P Utseya', 'RJ Kirtley', 'G Gambhir',
#        'RV Uthappa', 'IK Pathan', 'Harbhajan Singh', 'AB Agarkar',
#        'S Sreesanth', 'Salman Butt', 'Imran Nazir', 'Misbah-ul-Haq',
#        'Yasir Arafat', 'DL Vettori', 'Farhad Reza', 'Abdur Razzak',
#        'Syed Rasel', 'RP Singh', 'JS Patel', 'JN Snape', 'VD Philander',
#        'J Mubarak', 'G Wijekoon', 'WPUJC Vaas', 'Nadif Chowdhury',
#        'NL McCullum', 'Junaid Siddique', 'YK Pathan', 'Umar Gul',
#        'Mohammad Asif', 'AC Voges', 'LA Pomersbach', 'JM How', 'P Kumar',
#        'I Sharma', 'DR Flynn', 'MJ Mason', 'GJ Hopkins', 'JL Ontong',
#        'RN Lewis', 'P Mustard', 'GP Swann', 'RJ Sidebottom', 'JD Ryder',
#        'CS Martin', 'PA Hitchcock', 'Shoaib Akhtar', 'MN van Wyk',
#        'GH Bodi', 'BA Parchment', 'SE Marsh', 'DJ Hussey', 'XM Marshall',
#        'WKD Perkins', 'Dhiman Ghosh', 'Fawad Alam', 'RS Bopara',
#        'Raqibul Hasan', 'Naeem Islam', 'Mehrab Hossain jnr',
#        'RK Kleinveldt', 'J Louw', 'VB van Jaarsveld', 'CJ Ferguson',
#        'RE van der Merwe', 'BW Hilfenhaus', 'SW Tait', 'LL Tsotsobe',
#        'ND McKenzie', 'PM Siddle', 'GD Elliott', 'SM Davies', 'GJ Batty',
#        'A Khan', 'JS Foster', 'JP Bray', "NJ O'Brien", 'JF Mooney',
#        'NM Hauritz', 'AC Botha', 'AR White', 'RM West', 'AR Cusack',
#        'WK McCallan', 'DT Johnston', 'PC Connell', 'AJ Redmond',
#        'SJ Benn', 'IG Butler', 'Shahzaib Hasan', 'M Muralitharan',
#        'BAW Mendis', 'Z Khan', 'Shoaib Khan jnr', 'SHT Kandamby',
#        'K Weeraratne', 'T Thushara', 'SE Findlay', 'CS Baugh',
#        'EP Thompson', 'HG Kuhn', 'R McLaren', 'MJ North',
#        'Nazmul Hossain', 'DM Richards', 'TM Dowlin', 'FL Reifer',
#        'DE Bernard', 'RJMGM Rupasinghe', 'TR Birt', 'N Deonarine',
#        'NO Miller', 'DP Nannes', 'Imran Farhat', 'Naved-ul-Hasan',
#        'Saeed Ajmal', 'Suhrawadi Shuvo', 'MJ Lumb', 'C Kieswetter',
#        'M Vijay', 'Mohammad Sami', 'AM Blignaut', 'CK Coventry',
#        'GA Lamb', 'RW Price', 'RJ Harris', 'Jahurul Islam', 'A Nehra',
#        'Abdur Rehman', 'S Randiv', 'UWMBCA Welegedara', 'CU Jayasinghe',
#        'PJ Ingram', "SNJ O'Keefe", 'BJ Watling', 'AB Dinda', 'PP Ojha',
#        'AB Barath', 'SW Masakadza', 'AN Petersen', 'KAJ Roach',
#        'JW Hastings', 'CJ McKay', 'A Shahzad', 'NV Ojha', 'EC Rainsford',
#        'RJ Nicol', 'AJ McKay', 'Zulqarnain Haider', 'CA Ingram',
#        'KM Dabengwa', 'J Theron', 'DG Brownlie', 'Asad Shafiq',
#        'SR Patel', 'PA Patel', 'R Dravid', 'R Vinay Kumar', 'MM Patel',
#        'Mohammad Salman', 'Junaid Khan', 'DP Hyatt', 'CD Barnwell',
#        'S Badrinath', 'JL Pattinson', 'MDK Perera', 'HMRKB Herath',
#        'GJ Bailey', 'XJ Doherty', 'F Mutizwa', 'KO Meth', 'AM Ellis',
#        'RE Levi', 'MK Tiwary', 'Rameez Raja (2)', 'Yasir Shah',
#        'NE Bonner', 'DO Christian', 'SG Borthwick', 'JW Dernbach',
#        'MC Bascombe', 'Awais Zia', 'Hammad Azam', 'Aizaz Cheema',
#        'Nasir Hossain', 'BV Vitori', 'NG Jones', 'Ziaur Rahman',
#        'Elias Sunny', 'HDRL Thirimanne', 'Nasir Jamshed', 'ST Finn',
#        'GE Mathurin', 'Shakeel Ansar', 'KS Lokuarachchi',
#        'SMSM Senanayake', 'RMS Eranga', 'JC Tredwell', 'PP Chawla',
#        'Fawad Ahmed', 'MC Sorensen', 'RM Hira', 'MJ McClenaghan',
#        'H Davids', 'KJ Abbott', 'Raza Hasan', 'BJ Rohrer', 'BCJ Cutting',
#        "N M'shangwe", 'Shamsur Rahman', 'Sohag Gazi', 'Mominul Haque',
#        'T Panyangara', 'D Wiese', 'Zulfiqar Babar', 'TL Best',
#        'Mohammad Irfan', 'Bilawal Bhatti', 'Usman Shinwari', 'Anwar Ali',
#        'KOA Powell', 'MA Carberry', 'KDK Vithanage', 'Al-Amin Hossain',
#        'AP Devcich', 'AD Poynter', 'JM Muirhead', 'DE Bollinger',
#        'Arafat Sunny', 'TJ Murtagh', 'PJ Hughes', 'Saad Nasim',
#        'NJ Reardon', 'CJ Boyce', 'GH Worker', 'AM Phangiso',
#        'Mukhtar Ahmed', 'Nauman Anwar', 'UT Khawaja', 'PM Nevill',
#        'STR Binny', 'MM Sharma', 'Sandeep Sharma', 'Rafatullah Mohmand',
#        'Imran Khan (1)', 'RLB Rambukwella', 'KMC Bandara', 'TB de Bruyn',
#        'ST de Silva', 'Shuvagata Hom', 'Muktar Ali', 'Khurram Manzoor'],
#       dtype=object)

# %%
# SL ICC T20 Team
# selected_batters = ["PWH de Silva",'KIC Asalanka','BKG Mendis',"P Nissanka",'PHKD Mendis','S Samarawickrama','AD Mathews','MD Shanaka','DM de Silva','M Theekshana','PVD Chameera','N Thushara','M Pathirana','D Madushanka']

# %%
def getPlayerScores(player_name: str, innings: list[int] = [1, 2] ) -> pd.DataFrame:
    # Get the data for BKG Mendis if batter is BKG Mendis or non-striker is BKG Mendis
	player_data = data.loc[
		((data['batter'] == player_name) | (data['non_striker'] == player_name)) & (data['innings'].isin(innings))
	]

	player_data.head()

	# 3 matches missing from the data
	# group data by match_id
	gp = player_data.groupby('match_id')
	cols = ['batting_team', 'batter', 'non_striker', 'batter_runs', 'balls_faced', 'wicket_type', 'won', 'innings', 'over', 'delivery', 'wickets_fallen','bowling_team','venue']
	player_scores= gp.last().loc[:, cols]

	# get the first ball he faced or at non-striker
	first_ball = gp.first().loc[:, ['over', 'delivery', 'wickets_fallen']]
	first_ball['first_ball'] = (first_ball['over'] * 6 + first_ball['delivery']).astype(int)

	player_scores['first_ball'] = first_ball['first_ball']
	player_scores['wickets_fallen'] = first_ball['wickets_fallen']

	# when BKG Mendis is the non-striker when the last ball was bowled
	# The batter_runs and balls_faced are not his, but the on_strike batter's
	# So, we need to get the last ball he faced
	# he might not even have faced a ball

	# get the last ball he faced

	matches_non_striker = player_scores[player_scores['non_striker'] == player_name].index
	
	# Sometimes the player might not even have faced a single ball
	# Eg: Afghanistan_Sri Lanka_2022-11-01 MD Shanaka not out on the non strikers end

	player_scores.loc[matches_non_striker, ['batter_runs', 'balls_faced']] = [0, 0]
	
	
	# get the last batter == player_name row from gp data
	gp = player_data[(player_data['batter'] == player_name) & (player_data['match_id'].isin(matches_non_striker))].groupby(['match_id'])
	last_batter_scores = gp.last()[['batter_runs', 'balls_faced']]	
	
	# update the rows with non_striker with correct values
	player_scores.update(last_batter_scores)
	
	



	# adding new features
	# strike rate
	player_scores['strike_rate'] = round(player_scores['batter_runs'] / player_scores['balls_faced'] * 100, 2)
	player_scores['out'] = player_scores['wicket_type'] != '0'
	player_scores['last_ball'] = (player_scores['over'] * 6 + player_scores['delivery']).astype(int)
 
 
	player_scores['batter'] = player_name
	player_scores.drop('non_striker', inplace=True, axis = 1)

	# drop over and delivery
	player_scores.drop(['over', 'delivery'], inplace=True, axis=1)
 
	return player_scores

# %%
# getPlayerScores('BKG Mendis')

# merged_df = pd.DataFrame()

# for player in selected_batters:
#     player_scores = getPlayerScores(player)
    
#     merged_df = pd.concat([merged_df, player_scores])

# %%
# merged_df = pd.DataFrame()

# for player in all_batsmen:
#     player_scores = getPlayerScores(player)
    
#     merged_df = pd.concat([merged_df, player_scores])
    
    
merged_df = pd.read_csv("./all_batters.csv")

# %%
merged_df.drop(columns=["batter_runs","balls_faced","wicket_type","strike_rate","out","last_ball"],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 merged_df.drop(columns=["batter_runs","balls_faced","wicket_type","strike_rate","out","last_ball"],inplace=True)
#
# File c:\Users\Mansitha Eashwara\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
#    5574         inplace=inplace,
#    5575         errors=errors,
#    5576     )
#
# File c:\Users\Mansitha Eashwara\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4785, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4783 for axis, labels in axes.items():
#    4784     if labels is not None:
# -> 4785         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4787 if inplace:
#    4788     self._update_inplace(obj)
#
# File c:\Users\Mansitha Eashwara\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4827, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4825         new_axis = axis.drop(labels, level=level, errors=errors)
#    4826     else:
# -> 4827         new_axis = axis.drop(labels, errors=errors)
#    4828     indexer = axis.get_indexer(new_axis)
#    4830 # Case for non-unique axis
#    4831 else:
#
# File c:\Users\Mansitha Eashwara\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['batter_runs', 'balls_faced', 'wicket_type', 'strike_rate', 'out', 'last_ball'] not found in axis"

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14957 entries, 0 to 14956
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   batting_team    14957 non-null  object
#  1   batter          14957 non-null  object
#  2   won             14957 non-null  float64
#  3   innings         14957 non-null  int64
#  4   wickets_fallen  14957 non-null  int64
#  5   bowling_team    14957 non-null  object
#  6   venue           14957 non-null  object
#  7   first_ball      14957 non-null  int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 934.9+ KB

# %%
# merged_df["venue_score"] = merged_df["venue"].apply(lambda x:venue_data.loc[venue_data["venue"]==x]["total_mean"])
merged_df["venue_score"] = merged_df["venue"].map(venue_data.set_index("venue")["total_mean"])

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14957 entries, 0 to 14956
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   batting_team    14957 non-null  object
#  1   batter          14957 non-null  object
#  2   won             14957 non-null  float64
#  3   innings         14957 non-null  int64
#  4   wickets_fallen  14957 non-null  int64
#  5   bowling_team    14957 non-null  object
#  6   venue           14957 non-null  object
#  7   first_ball      14957 non-null  int64
#  8   venue_score     8033 non-null   float64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 1.0+ MB

# %%
merged_df.loc[merged_df["venue_score"].isnull()]
# Out:
#       batting_team         batter  won  innings  wickets_fallen bowling_team  \
# 12       Australia       AJ Finch  1.0        1               0        India
# 16       Australia       AJ Finch  0.0        1               0        India
# 17       Australia       AJ Finch  0.0        1               0        India
# 18       Australia       AJ Finch  1.0        1               0      Ireland
# 19       Australia       AJ Finch  1.0        1               0  New Zealand
# ...            ...            ...  ...      ...             ...          ...
# 14930    Australia      PM Nevill  1.0        2               7   Bangladesh
# 14932    Australia      PM Nevill  0.0        1               6        India
# 14934    Australia      PM Nevill  1.0        2               6    Sri Lanka
# 14950   Bangladesh  Shuvagata Hom  0.0        1               3    Australia
# 14953   Bangladesh  Shuvagata Hom  0.0        2               8        India
#
#                                                    venue  first_ball  \
# 12                Brisbane Cricket Ground, Woolloongabba           1
# 16     Vidarbha Cricket Association Stadium, Jamtha, ...           1
# 17     Rajiv Gandhi International Stadium, Uppal, Hyd...           1
# 18      Brisbane Cricket Ground, Woolloongabba, Brisbane           1
# 19                                       Westpac Stadium           0
# ...                                                  ...         ...
# 14930                              M Chinnaswamy Stadium         109
# 14932  Punjab Cricket Association IS Bindra Stadium, ...         116
# 14934                                R Premadasa Stadium         103
# 14950                              M Chinnaswamy Stadium          57
# 14953                              M Chinnaswamy Stadium         119
#
#        venue_score
# 12             NaN
# 16             NaN
# 17             NaN
# 18             NaN
# 19             NaN
# ...            ...
# 14930          NaN
# 14932          NaN
# 14934          NaN
# 14950          NaN
# 14953          NaN
#
# [6924 rows x 9 columns]

# %%
# merged_df.to_csv('./all_batters.csv',index=False)

# %%
# from sklearn.model_selection import cross_val_score, train_test_split # type: ignore
# from sklearn.ensemble import RandomForestClassifier # type: ignore
# from sklearn.metrics import accuracy_score# type: ignore
# RANDOM_STATE = 42
# data =merged_df

# # features = ['batter', 'innings', 'wickets_fallen', 'bowling_team', 'first_ball']
# target = 'won'

# # Preprocess the data
# data = pd.get_dummies(data=data,columns=['batter', 'batting_team', 'bowling_team','venue'],dtype=int)



# data.head()
# data["won"].value_counts()
# y = data[target]
# X = data.drop(columns=[target])

# model = RandomForestClassifier(n_estimators=100, random_state=RANDOM_STATE)
# scores = cross_val_score(model, X, y, cv=5)

# # Print the mean and standard deviation of the cross-validation scores
# print('Cross-validation scores:', scores)
# print('Mean cross-validation score:', scores.mean())
# print('Standard deviation of cross-validation scores:', scores.std())

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=RANDOM_STATE)

# model.fit(X_train, y_train)

# y_pred = model.predict(X_test)
# print('Accuracy:', accuracy_score(y_test, y_pred))
# win_probability = model.predict_proba(X_test)[:, 1]
# print('Win probability:', win_probability)

# %%
# X_test.head()

# %%
# win_proba_df = pd.DataFrame(win_probability, columns=['win_probability'])

# X_test = X_test.reset_index(drop=True)
# win_proba_df = win_proba_df.reset_index(drop=True)
# result = pd.concat([X_test, win_proba_df], axis=1)

# result.head()

# %%
# y_train.value_counts()

# %%
# y_test.value_counts()
