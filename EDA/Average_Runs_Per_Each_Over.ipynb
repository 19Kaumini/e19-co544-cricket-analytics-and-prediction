# %%
import pandas as pd

usecols = ['Col1', 'batter', 'total_runs_delivery', 'balls_faced', 'winning_team']

df = pd.read_csv("merged_data.csv", usecols=usecols)

print(df.head())
# Out:
#    Col1     batter  total_runs_delivery  balls_faced winning_team
# 0     0   AJ Finch                    0            1    Sri Lanka
# 1     1   AJ Finch                    0            2    Sri Lanka
# 2     2   AJ Finch                    1            3    Sri Lanka
# 3     3  M Klinger                    2            1    Sri Lanka
# 4     4  M Klinger                    0            2    Sri Lanka

# %%
import pandas as pd

df = pd.read_csv("merged_data.csv", usecols=['Col1', 'batter', 'total_runs_delivery', 'balls_faced', 'winning_team'])

inning_boundaries_indices = df[df['Col1'] == 0].index

print("Inning Boundaries Indices:")
print(inning_boundaries_indices)
# Out:
# Inning Boundaries Indices:
# Index([     0,    125,    250,    373,    497,    622,    737,    866,    990,
#          1072,
#        ...
#        216106, 216225, 216345, 216463, 216584, 216677, 216760, 216883, 217006,
#        217116],
#       dtype='int64', length=1896)

# %%
import pandas as pd

# Read the CSV file with the specified columns
df = pd.read_csv("merged_data.csv", usecols=['Col1', 'batter', 'total_runs_delivery', 'balls_faced', 'winning_team'])

# Identify the boundaries of each inning
inning_boundaries_indices = df[df['Col1'] == 0].index

# Append the end of the DataFrame as the last boundary
inning_boundaries_indices = list(inning_boundaries_indices) + [len(df)]

print("Inning Boundaries Indices:")
print(inning_boundaries_indices)

# Function to process each inning
def process_inning(df_inning):
    total_runs = df_inning['total_runs_delivery'].sum()
    return total_runs

# List to store the total runs for each inning
total_runs_per_inning = []

# Iterate through each inning using the boundaries
for i in range(len(inning_boundaries_indices) - 1):
    start_idx = inning_boundaries_indices[i]
    end_idx = inning_boundaries_indices[i + 1]
    df_inning = df.iloc[start_idx:end_idx]
    total_runs = process_inning(df_inning)
    total_runs_per_inning.append(total_runs)

# Display the total runs for each inning
for i, total_runs in enumerate(total_runs_per_inning, start=1):
    print(f"Inning {i}: Total Runs = {total_runs}")
# Out:
# Inning Boundaries Indices:
# [0, 125, 250, 373, 497, 622, 737, 866, 990, 1072, 1197, 1320, 1444, 1578, 1688, 1805, 1929, 2052, 2174, 2265, 2387, 2476, 2597, 2723, 2848, 2971, 3094, 3215, 3342, 3455, 3583, 3706, 3829, 3931, 4059, 4183, 4309, 4321, 4444, 4534, 4660, 4785, 4914, 5007, 5128, 5199, 5325, 5439, 5563, 5654, 5781, 5903, 6030, 6155, 6284, 6409, 6533, 6622, 6746, 6873, 6998, 7115, 7237, 7344, 7468, 7589, 7712, 7839, 7954, 8079, 8189, 8311, 8404, 8521, 8642, 8767, 8886, 9006, 9129, 9253, 9368, 9425, 9549, 9654, 9752, 9873, 9989, 10118, 10242, 10365, 10479, 10512, 10607, 10732, 10855, 10977, 11102, 11216, 11335, 11458, 11579, 11692, 11815, 11941, 12062, 12188, 12237, 12287, 12393, 12505, 12629, 12751, 12875, 12997, 13126, 13252, 13373, 13490, 13616, 13738, 13863, 13961, 14087, 14198, 14317, 14443, 14575, 14683, 14804, 14932, 15057, 15175, 15308, 15422, 15546, 15674, 15783, 15904, 16030, 16152, 16276, 16401, 16525, 16647, 16739, 16866, 16994, 17115, 17239, 17324, 17446, 17563, 17666, 17787, 17909, 18030, 18156, 18277, 18409, 18487, 18589, 18690, 18814, 18924, 18993, 19116, 19240, 19368, 19489, 19612, 19734, 19859, 19985, 20109, 20233, 20355, 20479, 20587, 20691, 20813, 20939, 21061, 21187, 21314, 21441, 21566, 21687, 21693, 21819, 21827, 21951, 22075, 22199, 22305, 22369, 22433, 22540, 22651, 22773, 22901, 23024, 23146, 23263, 23379, 23501, 23627, 23750, 23876, 23933, 24055, 24184, 24311, 24419, 24536, 24646, 24769, 24860, 24980, 25103, 25219, 25285, 25417, 25537, 25650, 25773, 25893, 26018, 26136, 26264, 26391, 26514, 26644, 26751, 26852, 26973, 27098, 27222, 27339, 27463, 27584, 27707, 27830, 27953, 28055, 28176, 28287, 28410, 28539, 28663, 28789, 28919, 29040, 29170, 29291, 29362, 29426, 29505, 29628, 29749, 29883, 30009, 30137, 30262, 30384, 30509, 30632, 30757, 30826, 30906, 31027, 31131, 31256, 31378, 31459, 31576, 31688, 31809, 31829, 31919, 32035, 32155, 32233, 32357, 32477, 32602, 32724, 32847, 32965, 33094, 33226, 33316, 33440, 33561, 33690, 33787, 33905, 34025, 34151, 34256, 34377, 34498, 34622, 34721, 34839, 34961, 35084, 35208, 35339, 35455, 35580, 35705, 35817, 35938, 36058, 36180, 36305, 36434, 36559, 36668, 36741, 36747, 36813, 36820, 36944, 37069, 37177, 37300, 37422, 37428, 37548, 37554, 37681, 37686, 37809, 37815, 37937, 38061, 38170, 38294, 38421, 38520, 38636, 38760, 38882, 39007, 39129, 39249, 39350, 39474, 39601, 39722, 39847, 39971, 40100, 40226, 40337, 40449, 40573, 40699, 40825, 40947, 41071, 41194, 41317, 41439, 41564, 41682, 41808, 41930, 42053, 42169, 42289, 42412, 42511, 42629, 42754, 42878, 43003, 43111, 43234, 43356, 43480, 43604, 43732, 43837, 43960, 44083, 44182, 44311, 44437, 44552, 44565, 44682, 44750, 44874, 44994, 45119, 45222, 45346, 45471, 45598, 45706, 45831, 45953, 46052, 46172, 46265, 46386, 46510, 46631, 46755, 46761, 46884, 46890, 47011, 47136, 47261, 47382, 47509, 47633, 47749, 47871, 47965, 48088, 48185, 48308, 48409, 48519, 48648, 48777, 48793, 48909, 49032, 49150, 49270, 49391, 49512, 49624, 49748, 49876, 50000, 50124, 50228, 50351, 50468, 50596, 50690, 50816, 50940, 51042, 51153, 51211, 51272, 51395, 51522, 51644, 51769, 51881, 52004, 52125, 52248, 52374, 52497, 52616, 52739, 52861, 52983, 53106, 53208, 53327, 53449, 53544, 53666, 53791, 53900, 54012, 54135, 54259, 54383, 54514, 54636, 54744, 54869, 54969, 55093, 55218, 55337, 55462, 55582, 55709, 55794, 55903, 56024, 56154, 56273, 56400, 56523, 56644, 56765, 56888, 57011, 57142, 57264, 57390, 57498, 57622, 57744, 57867, 57951, 58077, 58191, 58314, 58432, 58553, 58656, 58784, 58908, 59035, 59160, 59288, 59413, 59540, 59667, 59796, 59918, 60043, 60164, 60286, 60406, 60531, 60647, 60772, 60892, 61015, 61107, 61230, 61324, 61449, 61573, 61703, 61833, 61958, 62082, 62210, 62336, 62437, 62562, 62688, 62816, 62943, 63038, 63168, 63294, 63423, 63556, 63612, 63737, 63861, 63869, 63887, 64011, 64129, 64253, 64256, 64378, 64384, 64486, 64611, 64726, 64847, 64973, 65097, 65218, 65333, 65456, 65583, 65707, 65828, 65953, 66077, 66198, 66316, 66437, 66560, 66676, 66 ...
# Inning 1: Total Runs = 168
# Inning 2: Total Runs = 172
# Inning 3: Total Runs = 173
# Inning 4: Total Runs = 176
# Inning 5: Total Runs = 187
# Inning 6: Total Runs = 146
# Inning 7: Total Runs = 168
# Inning 8: Total Runs = 170
# Inning 9: Total Runs = 103
# Inning 10: Total Runs = 99
# Inning 11: Total Runs = 138
# Inning 12: Total Runs = 135
# Inning 13: Total Runs = 141
# Inning 14: Total Runs = 143
# Inning 15: Total Runs = 148
# Inning 16: Total Runs = 195
# Inning 17: Total Runs = 167
# Inning 18: Total Runs = 194
# Inning 19: Total Runs = 107
# Inning 20: Total Runs = 185
# Inning 21: Total Runs = 143
# Inning 22: Total Runs = 142
# Inning 23: Total Runs = 171
# Inning 24: Total Runs = 174
# Inning 25: Total Runs = 181
# Inning 26: Total Runs = 162
# Inning 27: Total Runs = 155
# Inning 28: Total Runs = 176
# Inning 29: Total Runs = 148
# Inning 30: Total Runs = 147
# Inning 31: Total Runs = 139
# Inning 32: Total Runs = 144
# Inning 33: Total Runs = 127
# Inning 34: Total Runs = 202
# Inning 35: Total Runs = 244
# Inning 36: Total Runs = 245
# Inning 37: Total Runs = 15
# Inning 38: Total Runs = 143
# Inning 39: Total Runs = 116
# Inning 40: Total Runs = 115
# Inning 41: Total Runs = 160
# Inning 42: Total Runs = 144
# Inning 43: Total Runs = 108
# Inning 44: Total Runs = 103
# Inning 45: Total Runs = 96
# Inning 46: Total Runs = 117
# Inning 47: Total Runs = 161
# Inning 48: Total Runs = 155
# Inning 49: Total Runs = 138
# Inning 50: Total Runs = 137
# Inning 51: Total Runs = 184
# Inning 52: Total Runs = 196
# Inning 53: Total Runs = 245
# Inning 54: Total Runs = 243
# Inning 55: Total Runs = 194
# Inning 56: Total Runs = 192
# Inning 57: Total Runs = 121
# Inning 58: Total Runs = 150
# Inning 59: Total Runs = 175
# Inning 60: Total Runs = 195
# Inning 61: Total Runs = 141
# Inning 62: Total Runs = 224
# Inning 63: Total Runs = 115
# Inning 64: Total Runs = 111
# Inning 65: Total Runs = 132
# Inning 66: Total Runs = 129
# Inning 67: Total Runs = 155
# Inning 68: Total Runs = 158
# Inning 69: Total Runs = 176
# Inning 70: Total Runs = 131
# Inning 71: Total Runs = 137
# Inning 72: Total Runs = 138
# Inning 73: Total Runs = 127
# Inning 74: Total Runs = 124
# Inning 75: Total Runs = 190
# Inning 76: Total Runs = 194
# Inning 77: Total Runs = 174
# Inning 78: Total Runs = 170
# Inning 79: Total Runs = 187
# Inning 80: Total Runs = 140
# Inning 81: Total Runs = 102
# Inning 82: Total Runs = 243
# Inning 83: Total Runs = 124
# Inning 84: Total Runs = 106
# Inning 85: Total Runs = 105
# Inning 86: Total Runs = 153
# Inning 87: Total Runs = 201
# Inning 88: Total Runs = 163
# Inning 89: Total Runs = 181
# Inning 90: Total Runs = 118
# Inning 91: Total Runs = 49
# Inning 92: Total Runs = 122
# Inning 93: Total Runs = 118
# Inning 94: Total Runs = 193
# Inning 95: Total Runs = 221
# Inning 96: Total Runs = 159
# Inning 97: Total Runs = 163
# Inning 98: Total Runs = 149
# Inning 99: Total Runs = 148
# Inning 100: Total Runs = 198
# Inning 101: Total Runs = 201
# Inning 102: Total Runs = 202
# Inning 103: Total Runs = 149
# Inning 104: Total Runs = 156
# Inning 105: Total Runs = 196
# Inning 106: Total Runs = 67
# Inning 107: Total Runs = 61
# Inning 108: Total Runs = 103
# Inning 109: Total Runs = 102
# Inning 110: Total Runs = 125
# Inning 111: Total Runs = 124
# Inning 112: Total Runs = 180
# Inning 113: Total Runs = 144
# Inning 114: Total Runs = 203
# Inning 115: Total Runs = 175
# Inning 116: Total Runs = 188
# Inning 117: Total Runs = 189
# Inning 118: Total Runs = 172
# Inning 119: Total Runs = 165
# Inning 120: Total Runs = 180
# Inning 121: Total Runs = 87
# Inning 122: Total Runs = 260
# Inning 123: Total Runs = 172
# Inning 124: Total Runs = 139
# Inning 125: Total Runs = 135
# Inning 126: Total Runs = 193
# Inning 127: Total Runs = 194
# Inning 128: Total Runs = 135
# Inning 129: Total Runs = 210
# Inning 130: Total Runs = 174
# Inning 131: Total Runs = 175
# Inning 132: Total Runs = 139
# Inning 133: Total Runs = 140
# Inning 134: Total Runs = 215
# Inning 135: Total Runs = 214
# Inning 136: Total Runs = 153
# Inning 137: Total Runs = 152
# Inning 138: Total Runs = 159
# Inning 139: Total Runs = 176
# Inning 140: Total Runs = 160
# Inning 141: Total Runs = 159
# Inning 142: Total Runs = 166
# Inning 143: Total Runs = 168
# Inning 144: Total Runs = 121
# Inning 145: Total Runs = 120
# Inning 146: Total Runs = 158
# Inning 147: Total Runs = 141
# Inning 148: Total Runs = 203
# Inning 149: Total Runs = 60
# Inning 150: Total Runs = 205
# Inning 151: Total Runs = 123
# Inning 152: Total Runs = 154
# Inning 153: Total Runs = 153
# Inning 154: Total Runs = 187
# Inning 155: Total Runs = 157
# Inning 156: Total Runs = 208
# Inning 157: Total Runs = 132
# Inning 158: Total Runs = 213
# Inning 159: Total Runs = 70
# Inning 160: Total Runs = 98
# Inning 161: Total Runs = 99
# Inning 162: Total Runs = 182
# Inning 163: Total Runs = 108
# Inning 164: Total Runs = 117
# Inning 165: Total Runs = 116
# Inning 166: Total Runs = 229
# Inning 167: Total Runs = 129
# Inning 168: Total Runs = 163
# Inning 169: Total Runs = 162
# Inning 170: Total Runs = 149
# Inning 171: Total Runs = 194
# Inning 172: Total Runs = 154
# Inning 173: Total Runs = 151
# Inning 174: Total Runs = 183
# Inning 175: Total Runs = 187
# Inning 176: Total Runs = 160
# Inning 177: Total Runs = 126
# Inning 178: Total Runs = 135
# Inning 179: Total Runs = 132
# Inning 180: Total Runs = 186
# Inning 181: Total Runs = 192
# Inning 182: Total Runs = 181
# Inning 183: Total Runs = 188
# Inning 184: Total Runs = 168
# Inning 185: Total Runs = 141
# Inning 186: Total Runs = 134
# Inning 187: Total Runs = 14
# Inning 188: Total Runs = 134
# Inning 189: Total Runs = 5
# Inning 190: Total Runs = 180
# Inning 191: Total Runs = 164
# Inning 192: Total Runs = 198
# Inning 193: Total Runs = 137
# Inning 194: Total Runs = 87
# Inning 195: Total Runs = 108
# Inning 196: Total Runs = 158
# Inning 197: Total Runs = 169
# Inning 198: Total Runs = 132
# Inning 199: Total Runs = 164
# Inning 200: Total Runs = 168
# Inning 201: Total Runs = 167
# Inning 202: Total Runs = 122
# Inning 203: Total Runs = 135
# Inning 204: Total Runs = 134
# Inning 205: Total Runs = 145
# Inning 206: Total Runs = 144
# Inning 207: Total Runs = 143
# Inning 208: Total Runs = 93
# Inning 209: Total Runs = 171
# Inning 210: Total Runs = 159
# Inning 211: Total Runs = 184
# Inning 212: Total Runs = 135
# Inning 213: Total Runs = 160
# Inning 214: Total Runs = 144
# Inning 215: Total Runs = 160
# Inning 216: Total Runs = 79
# Inning 217: Total Runs = 175
# Inning 218: Total Runs = 173
# Inning 219: Total Runs = 129
# Inning 220: Total Runs = 130
# Inning 221: Total Runs = 211
# Inning 222: Total Runs = 175
# Inning 223: Total Runs = 140
# Inning 224: Total Runs = 190
# Inning 225: Total Runs = 139
# Inning 226: Total Runs = 219
# Inning 227: Total Runs = 162
# Inning 228: Total Runs = 158
# Inning 229: Total Runs = 208
# Inning 230: Total Runs = 212
# Inning 231: Total Runs = 179
# Inning 232: Total Runs = 144
# Inning 233: Total Runs = 89
# Inning 234: Total Runs = 155
# Inning 235: Total Runs = 136
# Inning 236: Total Runs = 147
# Inning 237: Total Runs = 117
# Inning 238: Total Runs = 150
# Inning 239: Total Runs = 146
# Inning 240: Total Runs = 148
# Inning 241: Total Runs = 153
# Inning 242: Total Runs = 154
# Inning 243: Total Runs = 119
# Inning 244: Total Runs = 166
# Inning 245: Total Runs = 110
# Inning 246: Total Runs = 109
# Inning 247: Total Runs = 195
# Inning 248: Total Runs = 124
# Inning 249: Total Runs = 182
# Inning 250: Total Runs = 181
# Inning 251: Total Runs = 161
# Inning 252: Total Runs = 160
# Inning 253: Total Runs = 182
# Inning 254: Total Runs = 45
# Inning 255: Total Runs = 72
# Inning 256: Total Runs = 71
# Inning 257: Total Runs = 136
# Inning 258: Total Runs = 132
# Inning 259: Total Runs = 278
# Inning 260: Total Runs = 194
# Inning 261: Total Runs = 210
# Inning 262: Total Runs = 178
# Inning 263: Total Runs = 127
# Inning 264: Total Runs = 126
# Inning 265: Total Runs = 194
# Inning 266: Total Runs = 190
# Inning 267: Total Runs = 134
# Inning 268: Total Runs = 132
# Inning 269: Total Runs = 171
# Inning 270: Total Runs = 172
# Inning 271: Total Runs = 233
# Inning 272: Total Runs = 99
# Inning 273: Total Runs = 118
# Inning 274: Total Runs = 117
# Inning 275: Total Runs = 145
# Inning 276: Total Runs = 142
# Inning 277: Total Runs = 41
# Inning 278: Total Runs = 107
# Inning 279: Total Runs = 151
# Inning 280: Total Runs = 150
# Inning 281: Total Runs = 109
# Inning 282: Total Runs = 106
# Inning 283: Total Runs = 176
# Inning 284: Total Runs = 177
# Inning 285: Total Runs = 204
# Inning 286: Total Runs = 202
# Inning 287: Total Runs = 226
# Inning 288: Total Runs = 222
# Inning 289: Total Runs = 196
# Inning 290: Total Runs = 89
# Inning 291: Total Runs = 146
# Inning 292: Total Runs = 158
# Inning 293: Total Runs = 193
# Inning 294: Total Runs = 96
# Inning 295: Total Runs = 151
# Inning 296: Total Runs = 149
# Inning 297: Total Runs = 134
# Inning 298: Total Runs = 140
# Inning 299: Total Runs = 154
# Inning 300: Total Runs = 148
# Inning 301: Total Runs = 153
# Inning 302: Total Runs = 154
# Inning 303: Total Runs = 144
# Inning 304: Total Runs = 174
# Inning 305: Total Runs = 209
# Inning 306: Total Runs = 207
# Inning 307: Total Runs = 170
# Inning 308: Total Runs = 173
# Inning 309: Total Runs = 240
# Inning 310: Total Runs = 173
# Inning 311: Total Runs = 154
# Inning 312: Total Runs = 153
# Inning 313: Total Runs = 155
# Inning 314: Total Runs = 176
# Inning 315: Total Runs = 166
# Inning 316: Total Runs = 180
# Inning 317: Total Runs = 241
# Inning 318: Total Runs = 165
# Inning 319: Total Runs = 146
# Inning 320: Total Runs = 17
# Inning 321: Total Runs = 146
# Inning 322: Total Runs = 8
# Inning 323: Total Runs = 204
# Inning 324: Total Runs = 203
# Inning 325: Total Runs = 135
# Inning 326: Total Runs = 132
# Inning 327: Total Runs = 179
# Inning 328: Total Runs = 20
# Inning 329: Total Runs = 179
# Inning 330: Total Runs = 17
# Inning 331: Total Runs = 165
# Inning 332: Total Runs = 16
# Inning 333: Total Runs = 165
# Inning 334: Total Runs = 13
# Inning 335: Total Runs = 163
# Inning 336: Total Runs = 156
# Inning 337: Total Runs = 98
# Inning 338: Total Runs = 95
# Inning 339: Total Runs = 167
# Inning 340: Total Runs = 98
# Inning 341: Total Runs = 150
# Inning 342: Total Runs = 146
# Inning 343: Total Runs = 175
# Inning 344: Total Runs = 174
# Inning 345: Total Runs = 165
# Inning 346: Total Runs = 161
# Inning 347: Total Runs = 88
# Inning 348: Total Runs = 125
# Inning 349: Total Runs = 134
# Inning 350: Total Runs = 164
# Inning 351: Total Runs = 147
# Inning 352: Total Runs = 106
# Inning 353: Total Runs = 156
# Inning 354: Total Runs = 127
# Inning 355: Total Runs = 148
# Inning 356: Total Runs = 144
# Inning 357: Total Runs = 197
# Inning 358: Total Runs = 169
# Inning 359: Total Runs = 164
# Inning 360: Total Runs = 139
# Inning 361: Total Runs = 175
# Inning 362: Total Runs = 136
# Inning 363: Total Runs = 155
# Inning 364: Total Runs = 156
# Inning 365: Total Runs = 138
# Inning 366: Total Runs = 139
# Inning 367: Total Runs = 160
# Inning 368: Total Runs = 162
# Inning 369: Total Runs = 157
# Inning 370: Total Runs = 158
# Inning 371: Total Runs = 146
# Inning 372: Total Runs = 145
# Inning 373: Total Runs = 131
# Inning 374: Total Runs = 199
# Inning 375: Total Runs = 195
# Inning 376: Total Runs = 185
# Inning 377: Total Runs = 190
# Inning 378: Total Runs = 101
# Inning 379: Total Runs = 165
# Inning 380: Total Runs = 147
# Inning 381: Total Runs = 182
# Inning 382: Total Runs = 134
# Inning 383: Total Runs = 147
# Inning 384: Total Runs = 144
# Inning 385: Total Runs = 142
# Inning 386: Total Runs = 201
# Inning 387: Total Runs = 123
# Inning 388: Total Runs = 208
# Inning 389: Total Runs = 204
# Inning 390: Total Runs = 147
# Inning 391: Total Runs = 16
# Inning 392: Total Runs = 138
# Inning 393: Total Runs = 140
# Inning 394: Total Runs = 141
# Inning 395: Total Runs = 142
# Inning 396: Total Runs = 136
# Inning 397: Total Runs = 137
# Inning 398: Total Runs = 171
# Inning 399: Total Runs = 196
# Inning 400: Total Runs = 155
# Inning 401: Total Runs = 158
# Inning 402: Total Runs = 200
# Inning 403: Total Runs = 152
# Inning 404: Total Runs = 120
# Inning 405: Total Runs = 119
# Inning 406: Total Runs = 133
# Inning 407: Total Runs = 172
# Inning 408: Total Runs = 184
# Inning 409: Total Runs = 163
# Inning 410: Total Runs = 142
# Inning 411: Total Runs = 8
# Inning 412: Total Runs = 142
# Inning 413: Total Runs = 12
# Inning 414: Total Runs = 150
# Inning 415: Total Runs = 161
# Inning 416: Total Runs = 194
# Inning 417: Total Runs = 195
# Inning 418: Total Runs = 186
# Inning 419: Total Runs = 174
# Inning 420: Total Runs = 157
# Inning 421: Total Runs = 156
# Inning 422: Total Runs = 137
# Inning 423: Total Runs = 134
# Inning 424: Total Runs = 130
# Inning 425: Total Runs = 129
# Inning 426: Total Runs = 179
# Inning 427: Total Runs = 180
# Inning 428: Total Runs = 238
# Inning 429: Total Runs = 166
# Inning 430: Total Runs = 25
# Inning 431: Total Runs = 156
# Inning 432: Total Runs = 153
# Inning 433: Total Runs = 164
# Inning 434: Total Runs = 163
# Inning 435: Total Runs = 173
# Inning 436: Total Runs = 177
# Inning 437: Total Runs = 131
# Inning 438: Total Runs = 184
# Inning 439: Total Runs = 215
# Inning 440: Total Runs = 219
# Inning 441: Total Runs = 208
# Inning 442: Total Runs = 144
# Inning 443: Total Runs = 156
# Inning 444: Total Runs = 106
# Inning 445: Total Runs = 142
# Inning 446: Total Runs = 143
# Inning 447: Total Runs = 144
# Inning 448: Total Runs = 210
# Inning 449: Total Runs = 142
# Inning 450: Total Runs = 173
# Inning 451: Total Runs = 76
# Inning 452: Total Runs = 141
# Inning 453: Total Runs = 183
# Inning 454: Total Runs = 179
# Inning 455: Total Runs = 147
# Inning 456: Total Runs = 146
# Inning 457: Total Runs = 192
# Inning 458: Total Runs = 191
# Inning 459: Total Runs = 201
# Inning 460: Total Runs = 232
# Inning 461: Total Runs = 200
# Inning 462: Total Runs = 155
# Inning 463: Total Runs = 155
# Inning 464: Total Runs = 154
# Inning 465: Total Runs = 169
# Inning 466: Total Runs = 166
# Inning 467: Total Runs = 144
# Inning 468: Total Runs = 145
# Inning 469: Total Runs = 169
# Inning 470: Total Runs = 164
# Inning 471: Total Runs = 130
# Inning 472: Total Runs = 124
# Inning 473: Total Runs = 164
# Inning 474: Total Runs = 166
# Inning 475: Total Runs = 158
# Inning 476: Total Runs = 156
# Inning 477: Total Runs = 177
# Inning 478: Total Runs = 185
# Inning 479: Total Runs = 188
# Inning 480: Total Runs = 224
# Inning 481: Total Runs = 130
# Inning 482: Total Runs = 129
# Inning 483: Total Runs = 108
# Inning 484: Total Runs = 111
# Inning 485: Total Runs = 180
# Inning 486: Total Runs = 91
# Inning 487: Total Runs = 189
# Inning 488: Total Runs = 188
# Inning 489: Total Runs = 140
# Inning 490: Total Runs = 141
# Inning 491: Total Runs = 205
# Inning 492: Total Runs = 203
# Inning 493: Total Runs = 149
# Inning 494: Total Runs = 144
# Inning 495: Total Runs = 132
# Inning 496: Total Runs = 165
# Inning 497: Total Runs = 117
# Inning 498: Total Runs = 159
# Inning 499: Total Runs = 140
# Inning 500: Total Runs = 189
# Inning 501: Total Runs = 198
# Inning 502: Total Runs = 150
# Inning 503: Total Runs = 193
# Inning 504: Total Runs = 148
# Inning 505: Total Runs = 183
# Inning 506: Total Runs = 136
# Inning 507: Total Runs = 131
# Inning 508: Total Runs = 134
# Inning 509: Total Runs = 160
# Inning 510: Total Runs = 117
# Inning 511: Total Runs = 131
# Inning 512: Total Runs = 134
# Inning 513: Total Runs = 103
# Inning 514: Total Runs = 104
# Inning 515: Total Runs = 171
# Inning 516: Total Runs = 170
# Inning 517: Total Runs = 204
# Inning 518: Total Runs = 224
# Inning 519: Total Runs = 193
# Inning 520: Total Runs = 159
# Inning 521: Total Runs = 162
# Inning 522: Total Runs = 179
# Inning 523: Total Runs = 149
# Inning 524: Total Runs = 138
# Inning 525: Total Runs = 99
# Inning 526: Total Runs = 118
# Inning 527: Total Runs = 165
# Inning 528: Total Runs = 141
# Inning 529: Total Runs = 164
# Inning 530: Total Runs = 126
# Inning 531: Total Runs = 132
# Inning 532: Total Runs = 133
# Inning 533: Total Runs = 81
# Inning 534: Total Runs = 82
# Inning 535: Total Runs = 160
# Inning 536: Total Runs = 161
# Inning 537: Total Runs = 166
# Inning 538: Total Runs = 150
# Inning 539: Total Runs = 167
# Inning 540: Total Runs = 166
# Inning 541: Total Runs = 146
# Inning 542: Total Runs = 167
# Inning 543: Total Runs = 168
# Inning 544: Total Runs = 143
# Inning 545: Total Runs = 127
# Inning 546: Total Runs = 145
# Inning 547: Total Runs = 140
# Inning 548: Total Runs = 196
# Inning 549: Total Runs = 141
# Inning 550: Total Runs = 142
# Inning 551: Total Runs = 189
# Inning 552: Total Runs = 185
# Inning 553: Total Runs = 183
# Inning 554: Total Runs = 199
# Inning 555: Total Runs = 85
# Inning 556: Total Runs = 157
# Inning 557: Total Runs = 150
# Inning 558: Total Runs = 15
# Inning 559: Total Runs = 30
# Inning 560: Total Runs = 149
# Inning 561: Total Runs = 122
# Inning 562: Total Runs = 164
# Inning 563: Total Runs = 9
# Inning 564: Total Runs = 164
# Inning 565: Total Runs = 5
# Inning 566: Total Runs = 124
# Inning 567: Total Runs = 121
# Inning 568: Total Runs = 143
# Inning 569: Total Runs = 139
# Inning 570: Total Runs = 154
# Inning 571: Total Runs = 155
# Inning 572: Total Runs = 153
# Inning 573: Total Runs = 152
# Inning 574: Total Runs = 143
# Inning 575: Total Runs = 166
# Inning 576: Total Runs = 194
# Inning 577: Total Runs = 193
# Inning 578: Total Runs = 108
# Inning 579: Total Runs = 131
# Inning 580: Total Runs = 121
# Inning 581: Total Runs = 123
# Inning 582: Total Runs = 117
# Inning 583: Total Runs = 127
# Inning 584: Total Runs = 105
# Inning 585: Total Runs = 104
# Inning 586: Total Runs = 62
# Inning 587: Total Runs = 122
# Inning 588: Total Runs = 163
# Inning 589: Total Runs = 135
# Inning 590: Total Runs = 105
# Inning 591: Total Runs = 103
# Inning 592: Total Runs = 121
# Inning 593: Total Runs = 120
# Inning 594: Total Runs = 62
# Inning 595: Total Runs = 60
# Inning 596: Total Runs = 141
# Inning 597: Total Runs = 137
# Inning 598: Total Runs = 76
# Inning 599: Total Runs = 128
# Inning 600: Total Runs = 96
# Inning 601: Total Runs = 93
# Inning 602: Total Runs = 134
# Inning 603: Total Runs = 161
# Inning 604: Total Runs = 114
# Inning 605: Total Runs = 117
# Inning 606: Total Runs = 153
# Inning 607: Total Runs = 152
# Inning 608: Total Runs = 178
# Inning 609: Total Runs = 138
# Inning 610: Total Runs = 174
# Inning 611: Total Runs = 110
# Inning 612: Total Runs = 119
# Inning 613: Total Runs = 124
# Inning 614: Total Runs = 101
# Inning 615: Total Runs = 171
# Inning 616: Total Runs = 121
# Inning 617: Total Runs = 118
# Inning 618: Total Runs = 56
# Inning 619: Total Runs = 55
# Inning 620: Total Runs = 171
# Inning 621: Total Runs = 172
# Inning 622: Total Runs = 151
# Inning 623: Total Runs = 152
# Inning 624: Total Runs = 144
# Inning 625: Total Runs = 143
# Inning 626: Total Runs = 134
# Inning 627: Total Runs = 135
# Inning 628: Total Runs = 124
# Inning 629: Total Runs = 126
# Inning 630: Total Runs = 155
# Inning 631: Total Runs = 154
# Inning 632: Total Runs = 139
# Inning 633: Total Runs = 142
# Inning 634: Total Runs = 147
# Inning 635: Total Runs = 148
# Inning 636: Total Runs = 146
# Inning 637: Total Runs = 142
# Inning 638: Total Runs = 125
# Inning 639: Total Runs = 126
# Inning 640: Total Runs = 110
# Inning 641: Total Runs = 111
# Inning 642: Total Runs = 163
# Inning 643: Total Runs = 137
# Inning 644: Total Runs = 84
# Inning 645: Total Runs = 86
# Inning 646: Total Runs = 144
# Inning 647: Total Runs = 210
# Inning 648: Total Runs = 78
# Inning 649: Total Runs = 73
# Inning 650: Total Runs = 189
# Inning 651: Total Runs = 169
# Inning 652: Total Runs = 161
# Inning 653: Total Runs = 157
# Inning 654: Total Runs = 179
# Inning 655: Total Runs = 189
# Inning 656: Total Runs = 124
# Inning 657: Total Runs = 125
# Inning 658: Total Runs = 166
# Inning 659: Total Runs = 167
# Inning 660: Total Runs = 177
# Inning 661: Total Runs = 176
# Inning 662: Total Runs = 173
# Inning 663: Total Runs = 172
# Inning 664: Total Runs = 148
# Inning 665: Total Runs = 198
# Inning 666: Total Runs = 121
# Inning 667: Total Runs = 170
# Inning 668: Total Runs = 215
# Inning 669: Total Runs = 198
# Inning 670: Total Runs = 234
# Inning 671: Total Runs = 193
# Inning 672: Total Runs = 149
# Inning 673: Total Runs = 207
# Inning 674: Total Runs = 101
# Inning 675: Total Runs = 191
# Inning 676: Total Runs = 127
# Inning 677: Total Runs = 132
# Inning 678: Total Runs = 108
# Inning 679: Total Runs = 109
# Inning 680: Total Runs = 124
# Inning 681: Total Runs = 127
# Inning 682: Total Runs = 166
# Inning 683: Total Runs = 164
# Inning 684: Total Runs = 155
# Inning 685: Total Runs = 153
# Inning 686: Total Runs = 184
# Inning 687: Total Runs = 111
# Inning 688: Total Runs = 162
# Inning 689: Total Runs = 157
# Inning 690: Total Runs = 186
# Inning 691: Total Runs = 178
# Inning 692: Total Runs = 184
# Inning 693: Total Runs = 167
# Inning 694: Total Runs = 199
# Inning 695: Total Runs = 137
# Inning 696: Total Runs = 186
# Inning 697: Total Runs = 183
# Inning 698: Total Runs = 148
# Inning 699: Total Runs = 146
# Inning 700: Total Runs = 211
# Inning 701: Total Runs = 212
# Inning 702: Total Runs = 148
# Inning 703: Total Runs = 149
# Inning 704: Total Runs = 179
# Inning 705: Total Runs = 131
# Inning 706: Total Runs = 169
# Inning 707: Total Runs = 87
# Inning 708: Total Runs = 28
# Inning 709: Total Runs = 200
# Inning 710: Total Runs = 137
# Inning 711: Total Runs = 172
# Inning 712: Total Runs = 163
# Inning 713: Total Runs = 208
# Inning 714: Total Runs = 207
# Inning 715: Total Runs = 163
# Inning 716: Total Runs = 162
# Inning 717: Total Runs = 143
# Inning 718: Total Runs = 174
# Inning 719: Total Runs = 153
# Inning 720: Total Runs = 122
# Inning 721: Total Runs = 150
# Inning 722: Total Runs = 146
# Inning 723: Total Runs = 111
# Inning 724: Total Runs = 200
# Inning 725: Total Runs = 112
# Inning 726: Total Runs = 113
# Inning 727: Total Runs = 128
# Inning 728: Total Runs = 133
# Inning 729: Total Runs = 160
# Inning 730: Total Runs = 159
# Inning 731: Total Runs = 51
# Inning 732: Total Runs = 79
# Inning 733: Total Runs = 158
# Inning 734: Total Runs = 157
# Inning 735: Total Runs = 105
# Inning 736: Total Runs = 157
# Inning 737: Total Runs = 101
# Inning 738: Total Runs = 205
# Inning 739: Total Runs = 129
# Inning 740: Total Runs = 130
# Inning 741: Total Runs = 167
# Inning 742: Total Runs = 102
# Inning 743: Total Runs = 150
# Inning 744: Total Runs = 147
# Inning 745: Total Runs = 133
# Inning 746: Total Runs = 137
# Inning 747: Total Runs = 179
# Inning 748: Total Runs = 137
# Inning 749: Total Runs = 144
# Inning 750: Total Runs = 148
# Inning 751: Total Runs = 179
# Inning 752: Total Runs = 159
# Inning 753: Total Runs = 145
# Inning 754: Total Runs = 184
# Inning 755: Total Runs = 185
# Inning 756: Total Runs = 108
# Inning 757: Total Runs = 150
# Inning 758: Total Runs = 185
# Inning 759: Total Runs = 164
# Inning 760: Total Runs = 168
# Inning 761: Total Runs = 144
# Inning 762: Total Runs = 141
# Inning 763: Total Runs = 127
# Inning 764: Total Runs = 128
# Inning 765: Total Runs = 186
# Inning 766: Total Runs = 115
# Inning 767: Total Runs = 152
# Inning 768: Total Runs = 153
# Inning 769: Total Runs = 170
# Inning 770: Total Runs = 168
# Inning 771: Total Runs = 138
# Inning 772: Total Runs = 137
# Inning 773: Total Runs = 94
# Inning 774: Total Runs = 155
# Inning 775: Total Runs = 121
# Inning 776: Total Runs = 115
# Inning 777: Total Runs = 111
# Inning 778: Total Runs = 108
# Inning 779: Total Runs = 225
# Inning 780: Total Runs = 221
# Inning 781: Total Runs = 142
# Inning 782: Total Runs = 173
# Inning 783: Total Runs = 91
# Inning 784: Total Runs = 179
# Inning 785: Total Runs = 174
# Inning 786: Total Runs = 180
# Inning 787: Total Runs = 190
# Inning 788: Total Runs = 211
# Inning 789: Total Runs = 138
# Inning 790: Total Runs = 182
# Inning 791: Total Runs = 168
# Inning 792: Total Runs = 171
# Inning 793: Total Runs = 122
# Inning 794: Total Runs = 125
# Inning 795: Total Runs = 189
# Inning 796: Total Runs = 167
# Inning 797: Total Runs = 132
# Inning 798: Total Runs = 105
# Inning 799: Total Runs = 95
# Inning 800: Total Runs = 56
# Inning 801: Total Runs = 134
# Inning 802: Total Runs = 128
# Inning 803: Total Runs = 126
# Inning 804: Total Runs = 124
# Inning 805: Total Runs = 176
# Inning 806: Total Runs = 177
# Inning 807: Total Runs = 160
# Inning 808: Total Runs = 159
# Inning 809: Total Runs = 170
# Inning 810: Total Runs = 149
# Inning 811: Total Runs = 125
# Inning 812: Total Runs = 90
# Inning 813: Total Runs = 105
# Inning 814: Total Runs = 158
# Inning 815: Total Runs = 193
# Inning 816: Total Runs = 163
# Inning 817: Total Runs = 169
# Inning 818: Total Runs = 146
# Inning 819: Total Runs = 145
# Inning 820: Total Runs = 178
# Inning 821: Total Runs = 147
# Inning 822: Total Runs = 200
# Inning 823: Total Runs = 208
# Inning 824: Total Runs = 170
# Inning 825: Total Runs = 178
# Inning 826: Total Runs = 30
# Inning 827: Total Runs = 112
# Inning 828: Total Runs = 190
# Inning 829: Total Runs = 122
# Inning 830: Total Runs = 138
# Inning 831: Total Runs = 141
# Inning 832: Total Runs = 165
# Inning 833: Total Runs = 164
# Inning 834: Total Runs = 191
# Inning 835: Total Runs = 132
# Inning 836: Total Runs = 188
# Inning 837: Total Runs = 100
# Inning 838: Total Runs = 185
# Inning 839: Total Runs = 172
# Inning 840: Total Runs = 215
# Inning 841: Total Runs = 125
# Inning 842: Total Runs = 145
# Inning 843: Total Runs = 150
# Inning 844: Total Runs = 191
# Inning 845: Total Runs = 126
# Inning 846: Total Runs = 75
# Inning 847: Total Runs = 160
# Inning 848: Total Runs = 146
# Inning 849: Total Runs = 167
# Inning 850: Total Runs = 147
# Inning 851: Total Runs = 149
# Inning 852: Total Runs = 137
# Inning 853: Total Runs = 142
# Inning 854: Total Runs = 131
# Inning 855: Total Runs = 130
# Inning 856: Total Runs = 160
# Inning 857: Total Runs = 208
# Inning 858: Total Runs = 173
# Inning 859: Total Runs = 177
# Inning 860: Total Runs = 163
# Inning 861: Total Runs = 168
# Inning 862: Total Runs = 196
# Inning 863: Total Runs = 8
# Inning 864: Total Runs = 196
# Inning 865: Total Runs = 12
# Inning 866: Total Runs = 146
# Inning 867: Total Runs = 141
# Inning 868: Total Runs = 183
# Inning 869: Total Runs = 182
# Inning 870: Total Runs = 188
# Inning 871: Total Runs = 205
# Inning 872: Total Runs = 136
# Inning 873: Total Runs = 135
# Inning 874: Total Runs = 146
# Inning 875: Total Runs = 156
# Inning 876: Total Runs = 160
# Inning 877: Total Runs = 158
# Inning 878: Total Runs = 199
# Inning 879: Total Runs = 203
# Inning 880: Total Runs = 221
# Inning 881: Total Runs = 158
# Inning 882: Total Runs = 163
# Inning 883: Total Runs = 166
# Inning 884: Total Runs = 139
# Inning 885: Total Runs = 145
# Inning 886: Total Runs = 170
# Inning 887: Total Runs = 169
# Inning 888: Total Runs = 209
# Inning 889: Total Runs = 142
# Inning 890: Total Runs = 106
# Inning 891: Total Runs = 105
# Inning 892: Total Runs = 148
# Inning 893: Total Runs = 147
# Inning 894: Total Runs = 131
# Inning 895: Total Runs = 127
# Inning 896: Total Runs = 183
# Inning 897: Total Runs = 184
# Inning 898: Total Runs = 175
# Inning 899: Total Runs = 179
# Inning 900: Total Runs = 181
# Inning 901: Total Runs = 182
# Inning 902: Total Runs = 173
# Inning 903: Total Runs = 174
# Inning 904: Total Runs = 129
# Inning 905: Total Runs = 131
# Inning 906: Total Runs = 111
# Inning 907: Total Runs = 212
# Inning 908: Total Runs = 121
# Inning 909: Total Runs = 124
# Inning 910: Total Runs = 147
# Inning 911: Total Runs = 170
# Inning 912: Total Runs = 211
# Inning 913: Total Runs = 208
# Inning 914: Total Runs = 90
# Inning 915: Total Runs = 92
# Inning 916: Total Runs = 186
# Inning 917: Total Runs = 187
# Inning 918: Total Runs = 110
# Inning 919: Total Runs = 106
# Inning 920: Total Runs = 237
# Inning 921: Total Runs = 221
# Inning 922: Total Runs = 178
# Inning 923: Total Runs = 227
# Inning 924: Total Runs = 143
# Inning 925: Total Runs = 139
# Inning 926: Total Runs = 198
# Inning 927: Total Runs = 103
# Inning 928: Total Runs = 128
# Inning 929: Total Runs = 202
# Inning 930: Total Runs = 175
# Inning 931: Total Runs = 179
# Inning 932: Total Runs = 131
# Inning 933: Total Runs = 132
# Inning 934: Total Runs = 259
# Inning 935: Total Runs = 258
# Inning 936: Total Runs = 213
# Inning 937: Total Runs = 220
# Inning 938: Total Runs = 94
# Inning 939: Total Runs = 182
# Inning 940: Total Runs = 154
# Inning 941: Total Runs = 192
# Inning 942: Total Runs = 163
# Inning 943: Total Runs = 159
# Inning 944: Total Runs = 164
# Inning 945: Total Runs = 194
# Inning 946: Total Runs = 193
# Inning 947: Total Runs = 114
# Inning 948: Total Runs = 118
# Inning 949: Total Runs = 150
# Inning 950: Total Runs = 144
# Inning 951: Total Runs = 141
# Inning 952: Total Runs = 144
# Inning 953: Total Runs = 162
# Inning 954: Total Runs = 160
# Inning 955: Total Runs = 190
# Inning 956: Total Runs = 206
# Inning 957: Total Runs = 228
# Inning 958: Total Runs = 137
# Inning 959: Total Runs = 155
# Inning 960: Total Runs = 176
# Inning 961: Total Runs = 101
# Inning 962: Total Runs = 99
# Inning 963: Total Runs = 234
# Inning 964: Total Runs = 66
# Inning 965: Total Runs = 158
# Inning 966: Total Runs = 156
# Inning 967: Total Runs = 120
# Inning 968: Total Runs = 117
# Inning 969: Total Runs = 158
# Inning 970: Total Runs = 142
# Inning 971: Total Runs = 207
# Inning 972: Total Runs = 81
# Inning 973: Total Runs = 202
# Inning 974: Total Runs = 125
# Inning 975: Total Runs = 124
# Inning 976: Total Runs = 126
# Inning 977: Total Runs = 98
# Inning 978: Total Runs = 92
# Inning 979: Total Runs = 133
# Inning 980: Total Runs = 130
# Inning 981: Total Runs = 116
# Inning 982: Total Runs = 182
# Inning 983: Total Runs = 226
# Inning 984: Total Runs = 115
# Inning 985: Total Runs = 168
# Inning 986: Total Runs = 164
# Inning 987: Total Runs = 191
# Inning 988: Total Runs = 190
# Inning 989: Total Runs = 171
# Inning 990: Total Runs = 172
# Inning 991: Total Runs = 166
# Inning 992: Total Runs = 176
# Inning 993: Total Runs = 226
# Inning 994: Total Runs = 222
# Inning 995: Total Runs = 267
# Inning 996: Total Runs = 192
# Inning 997: Total Runs = 132
# Inning 998: Total Runs = 133
# Inning 999: Total Runs = 213
# Inning 1000: Total Runs = 202
# Inning 1001: Total Runs = 241
# Inning 1002: Total Runs = 207
# Inning 1003: Total Runs = 183
# Inning 1004: Total Runs = 220
# Inning 1005: Total Runs = 154
# Inning 1006: Total Runs = 157
# Inning 1007: Total Runs = 116
# Inning 1008: Total Runs = 119
# Inning 1009: Total Runs = 145
# Inning 1010: Total Runs = 149
# Inning 1011: Total Runs = 152
# Inning 1012: Total Runs = 155
# Inning 1013: Total Runs = 164
# Inning 1014: Total Runs = 159
# Inning 1015: Total Runs = 179
# Inning 1016: Total Runs = 178
# Inning 1017: Total Runs = 165
# Inning 1018: Total Runs = 171
# Inning 1019: Total Runs = 47
# Inning 1020: Total Runs = 139
# Inning 1021: Total Runs = 185
# Inning 1022: Total Runs = 152
# Inning 1023: Total Runs = 180
# Inning 1024: Total Runs = 154
# Inning 1025: Total Runs = 201
# Inning 1026: Total Runs = 95
# Inning 1027: Total Runs = 137
# Inning 1028: Total Runs = 134
# Inning 1029: Total Runs = 72
# Inning 1030: Total Runs = 110
# Inning 1031: Total Runs = 95
# Inning 1032: Total Runs = 226
# Inning 1033: Total Runs = 180
# Inning 1034: Total Runs = 194
# Inning 1035: Total Runs = 173
# Inning 1036: Total Runs = 224
# Inning 1037: Total Runs = 179
# Inning 1038: Total Runs = 159
# Inning 1039: Total Runs = 158
# Inning 1040: Total Runs = 92
# Inning 1041: Total Runs = 134
# Inning 1042: Total Runs = 216
# Inning 1043: Total Runs = 215
# Inning 1044: Total Runs = 174
# Inning 1045: Total Runs = 102
# Inning 1046: Total Runs = 118
# Inning 1047: Total Runs = 98
# Inning 1048: Total Runs = 208
# Inning 1049: Total Runs = 209
# Inning 1050: Total Runs = 191
# Inning 1051: Total Runs = 235
# Inning 1052: Total Runs = 225
# Inning 1053: Total Runs = 222
# Inning 1054: Total Runs = 154
# Inning 1055: Total Runs = 174
# Inning 1056: Total Runs = 154
# Inning 1057: Total Runs = 160
# Inning 1058: Total Runs = 158
# Inning 1059: Total Runs = 159
# Inning 1060: Total Runs = 172
# Inning 1061: Total Runs = 173
# Inning 1062: Total Runs = 212
# Inning 1063: Total Runs = 16
# Inning 1064: Total Runs = 1
# Inning 1065: Total Runs = 212
# Inning 1066: Total Runs = 16
# Inning 1067: Total Runs = 11
# Inning 1068: Total Runs = 116
# Inning 1069: Total Runs = 108
# Inning 1070: Total Runs = 96
# Inning 1071: Total Runs = 97
# Inning 1072: Total Runs = 116
# Inning 1073: Total Runs = 115
# Inning 1074: Total Runs = 65
# Inning 1075: Total Runs = 48
# Inning 1076: Total Runs = 112
# Inning 1077: Total Runs = 147
# Inning 1078: Total Runs = 148
# Inning 1079: Total Runs = 166
# Inning 1080: Total Runs = 165
# Inning 1081: Total Runs = 141
# Inning 1082: Total Runs = 140
# Inning 1083: Total Runs = 144
# Inning 1084: Total Runs = 143
# Inning 1085: Total Runs = 173
# Inning 1086: Total Runs = 178
# Inning 1087: Total Runs = 88
# Inning 1088: Total Runs = 82
# Inning 1089: Total Runs = 156
# Inning 1090: Total Runs = 160
# Inning 1091: Total Runs = 115
# Inning 1092: Total Runs = 187
# Inning 1093: Total Runs = 209
# Inning 1094: Total Runs = 206
# Inning 1095: Total Runs = 111
# Inning 1096: Total Runs = 149
# Inning 1097: Total Runs = 152
# Inning 1098: Total Runs = 142
# Inning 1099: Total Runs = 155
# Inning 1100: Total Runs = 98
# Inning 1101: Total Runs = 203
# Inning 1102: Total Runs = 206
# Inning 1103: Total Runs = 170
# Inning 1104: Total Runs = 165
# Inning 1105: Total Runs = 146
# Inning 1106: Total Runs = 174
# Inning 1107: Total Runs = 79
# Inning 1108: Total Runs = 179
# Inning 1109: Total Runs = 214
# Inning 1110: Total Runs = 170
# Inning 1111: Total Runs = 134
# Inning 1112: Total Runs = 133
# Inning 1113: Total Runs = 144
# Inning 1114: Total Runs = 148
# Inning 1115: Total Runs = 161
# Inning 1116: Total Runs = 163
# Inning 1117: Total Runs = 209
# Inning 1118: Total Runs = 114
# Inning 1119: Total Runs = 126
# Inning 1120: Total Runs = 126
# Inning 1121: Total Runs = 199
# Inning 1122: Total Runs = 201
# Inning 1123: Total Runs = 221
# Inning 1124: Total Runs = 144
# Inning 1125: Total Runs = 162
# Inning 1126: Total Runs = 62
# Inning 1127: Total Runs = 116
# Inning 1128: Total Runs = 115
# Inning 1129: Total Runs = 127
# Inning 1130: Total Runs = 126
# Inning 1131: Total Runs = 193
# Inning 1132: Total Runs = 208
# Inning 1133: Total Runs = 173
# Inning 1134: Total Runs = 169
# Inning 1135: Total Runs = 208
# Inning 1136: Total Runs = 205
# Inning 1137: Total Runs = 138
# Inning 1138: Total Runs = 139
# Inning 1139: Total Runs = 165
# Inning 1140: Total Runs = 164
# Inning 1141: Total Runs = 188
# Inning 1142: Total Runs = 138
# Inning 1143: Total Runs = 136
# Inning 1144: Total Runs = 135
# Inning 1145: Total Runs = 141
# Inning 1146: Total Runs = 141
# Inning 1147: Total Runs = 164
# Inning 1148: Total Runs = 168
# Inning 1149: Total Runs = 144
# Inning 1150: Total Runs = 146
# Inning 1151: Total Runs = 180
# Inning 1152: Total Runs = 190
# Inning 1153: Total Runs = 124
# Inning 1154: Total Runs = 123
# Inning 1155: Total Runs = 135
# Inning 1156: Total Runs = 154
# Inning 1157: Total Runs = 189
# Inning 1158: Total Runs = 156
# Inning 1159: Total Runs = 159
# Inning 1160: Total Runs = 164
# Inning 1161: Total Runs = 164
# Inning 1162: Total Runs = 165
# Inning 1163: Total Runs = 83
# Inning 1164: Total Runs = 147
# Inning 1165: Total Runs = 153
# Inning 1166: Total Runs = 158
# Inning 1167: Total Runs = 200
# Inning 1168: Total Runs = 218
# Inning 1169: Total Runs = 102
# Inning 1170: Total Runs = 101
# Inning 1171: Total Runs = 140
# Inning 1172: Total Runs = 141
# Inning 1173: Total Runs = 153
# Inning 1174: Total Runs = 116
# Inning 1175: Total Runs = 143
# Inning 1176: Total Runs = 147
# Inning 1177: Total Runs = 173
# Inning 1178: Total Runs = 188
# Inning 1179: Total Runs = 157
# Inning 1180: Total Runs = 152
# Inning 1181: Total Runs = 186
# Inning 1182: Total Runs = 132
# Inning 1183: Total Runs = 75
# Inning 1184: Total Runs = 74
# Inning 1185: Total Runs = 127
# Inning 1186: Total Runs = 123
# Inning 1187: Total Runs = 166
# Inning 1188: Total Runs = 167
# Inning 1189: Total Runs = 129
# Inning 1190: Total Runs = 131
# Inning 1191: Total Runs = 134
# Inning 1192: Total Runs = 131
# Inning 1193: Total Runs = 184
# Inning 1194: Total Runs = 152
# Inning 1195: Total Runs = 193
# Inning 1196: Total Runs = 143
# Inning 1197: Total Runs = 161
# Inning 1198: Total Runs = 191
# Inning 1199: Total Runs = 58
# Inning 1200: Total Runs = 60
# Inning 1201: Total Runs = 97
# Inning 1202: Total Runs = 102
# Inning 1203: Total Runs = 101
# Inning 1204: Total Runs = 203
# Inning 1205: Total Runs = 145
# Inning 1206: Total Runs = 4
# Inning 1207: Total Runs = 109
# Inning 1208: Total Runs = 118
# Inning 1209: Total Runs = 166
# Inning 1210: Total Runs = 168
# Inning 1211: Total Runs = 139
# Inning 1212: Total Runs = 156
# Inning 1213: Total Runs = 182
# Inning 1214: Total Runs = 130
# Inning 1215: Total Runs = 161
# Inning 1216: Total Runs = 157
# Inning 1217: Total Runs = 150
# Inning 1218: Total Runs = 149
# Inning 1219: Total Runs = 121
# Inning 1220: Total Runs = 123
# Inning 1221: Total Runs = 169
# Inning 1222: Total Runs = 172
# Inning 1223: Total Runs = 155
# Inning 1224: Total Runs = 180
# Inning 1225: Total Runs = 185
# Inning 1226: Total Runs = 137
# Inning 1227: Total Runs = 137
# Inning 1228: Total Runs = 138
# Inning 1229: Total Runs = 159
# Inning 1230: Total Runs = 160
# Inning 1231: Total Runs = 127
# Inning 1232: Total Runs = 128
# Inning 1233: Total Runs = 113
# Inning 1234: Total Runs = 112
# Inning 1235: Total Runs = 192
# Inning 1236: Total Runs = 177
# Inning 1237: Total Runs = 115
# Inning 1238: Total Runs = 198
# Inning 1239: Total Runs = 111
# Inning 1240: Total Runs = 114
# Inning 1241: Total Runs = 131
# Inning 1242: Total Runs = 150
# Inning 1243: Total Runs = 153
# Inning 1244: Total Runs = 156
# Inning 1245: Total Runs = 183
# Inning 1246: Total Runs = 163
# Inning 1247: Total Runs = 99
# Inning 1248: Total Runs = 100
# Inning 1249: Total Runs = 135
# Inning 1250: Total Runs = 144
# Inning 1251: Total Runs = 153
# Inning 1252: Total Runs = 150
# Inning 1253: Total Runs = 161
# Inning 1254: Total Runs = 82
# Inning 1255: Total Runs = 120
# Inning 1256: Total Runs = 159
# Inning 1257: Total Runs = 110
# Inning 1258: Total Runs = 158
# Inning 1259: Total Runs = 118
# Inning 1260: Total Runs = 130
# Inning 1261: Total Runs = 149
# Inning 1262: Total Runs = 142
# Inning 1263: Total Runs = 158
# Inning 1264: Total Runs = 101
# Inning 1265: Total Runs = 139
# Inning 1266: Total Runs = 138
# Inning 1267: Total Runs = 141
# Inning 1268: Total Runs = 137
# Inning 1269: Total Runs = 132
# Inning 1270: Total Runs = 133
# Inning 1271: Total Runs = 149
# Inning 1272: Total Runs = 150
# Inning 1273: Total Runs = 155
# Inning 1274: Total Runs = 15
# Inning 1275: Total Runs = 155
# Inning 1276: Total Runs = 25
# Inning 1277: Total Runs = 191
# Inning 1278: Total Runs = 155
# Inning 1279: Total Runs = 162
# Inning 1280: Total Runs = 166
# Inning 1281: Total Runs = 174
# Inning 1282: Total Runs = 171
# Inning 1283: Total Runs = 202
# Inning 1284: Total Runs = 127
# Inning 1285: Total Runs = 157
# Inning 1286: Total Runs = 241
# Inning 1287: Total Runs = 108
# Inning 1288: Total Runs = 109
# Inning 1289: Total Runs = 118
# Inning 1290: Total Runs = 119
# Inning 1291: Total Runs = 172
# Inning 1292: Total Runs = 120
# Inning 1293: Total Runs = 141
# Inning 1294: Total Runs = 138
# Inning 1295: Total Runs = 170
# Inning 1296: Total Runs = 148
# Inning 1297: Total Runs = 179
# Inning 1298: Total Runs = 141
# Inning 1299: Total Runs = 142
# Inning 1300: Total Runs = 138
# Inning 1301: Total Runs = 127
# Inning 1302: Total Runs = 125
# Inning 1303: Total Runs = 68
# Inning 1304: Total Runs = 138
# Inning 1305: Total Runs = 139
# Inning 1306: Total Runs = 135
# Inning 1307: Total Runs = 151
# Inning 1308: Total Runs = 172
# Inning 1309: Total Runs = 120
# Inning 1310: Total Runs = 14
# Inning 1311: Total Runs = 186
# Inning 1312: Total Runs = 172
# Inning 1313: Total Runs = 191
# Inning 1314: Total Runs = 157
# Inning 1315: Total Runs = 36
# Inning 1316: Total Runs = 84
# Inning 1317: Total Runs = 191
# Inning 1318: Total Runs = 60
# Inning 1319: Total Runs = 173
# Inning 1320: Total Runs = 29
# Inning 1321: Total Runs = 141
# Inning 1322: Total Runs = 114
# Inning 1323: Total Runs = 151
# Inning 1324: Total Runs = 147
# Inning 1325: Total Runs = 157
# Inning 1326: Total Runs = 170
# Inning 1327: Total Runs = 184
# Inning 1328: Total Runs = 135
# Inning 1329: Total Runs = 195
# Inning 1330: Total Runs = 138
# Inning 1331: Total Runs = 133
# Inning 1332: Total Runs = 132
# Inning 1333: Total Runs = 168
# Inning 1334: Total Runs = 129
# Inning 1335: Total Runs = 155
# Inning 1336: Total Runs = 169
# Inning 1337: Total Runs = 168
# Inning 1338: Total Runs = 87
# Inning 1339: Total Runs = 148
# Inning 1340: Total Runs = 137
# Inning 1341: Total Runs = 153
# Inning 1342: Total Runs = 149
# Inning 1343: Total Runs = 163
# Inning 1344: Total Runs = 167
# Inning 1345: Total Runs = 109
# Inning 1346: Total Runs = 105
# Inning 1347: Total Runs = 132
# Inning 1348: Total Runs = 128
# Inning 1349: Total Runs = 197
# Inning 1350: Total Runs = 191
# Inning 1351: Total Runs = 147
# Inning 1352: Total Runs = 148
# Inning 1353: Total Runs = 78
# Inning 1354: Total Runs = 79
# Inning 1355: Total Runs = 119
# Inning 1356: Total Runs = 118
# Inning 1357: Total Runs = 214
# Inning 1358: Total Runs = 6
# Inning 1359: Total Runs = 214
# Inning 1360: Total Runs = 9
# Inning 1361: Total Runs = 144
# Inning 1362: Total Runs = 167
# Inning 1363: Total Runs = 151
# Inning 1364: Total Runs = 162
# Inning 1365: Total Runs = 129
# Inning 1366: Total Runs = 126
# Inning 1367: Total Runs = 90
# Inning 1368: Total Runs = 89
# Inning 1369: Total Runs = 112
# Inning 1370: Total Runs = 161
# Inning 1371: Total Runs = 146
# Inning 1372: Total Runs = 153
# Inning 1373: Total Runs = 186
# Inning 1374: Total Runs = 215
# Inning 1375: Total Runs = 211
# Inning 1376: Total Runs = 206
# Inning 1377: Total Runs = 79
# Inning 1378: Total Runs = 105
# Inning 1379: Total Runs = 136
# Inning 1380: Total Runs = 123
# Inning 1381: Total Runs = 130
# Inning 1382: Total Runs = 129
# Inning 1383: Total Runs = 148
# Inning 1384: Total Runs = 149
# Inning 1385: Total Runs = 133
# Inning 1386: Total Runs = 135
# Inning 1387: Total Runs = 157
# Inning 1388: Total Runs = 158
# Inning 1389: Total Runs = 147
# Inning 1390: Total Runs = 143
# Inning 1391: Total Runs = 120
# Inning 1392: Total Runs = 119
# Inning 1393: Total Runs = 112
# Inning 1394: Total Runs = 111
# Inning 1395: Total Runs = 144
# Inning 1396: Total Runs = 140
# Inning 1397: Total Runs = 120
# Inning 1398: Total Runs = 92
# Inning 1399: Total Runs = 81
# Inning 1400: Total Runs = 82
# Inning 1401: Total Runs = 120
# Inning 1402: Total Runs = 125
# Inning 1403: Total Runs = 169
# Inning 1404: Total Runs = 168
# Inning 1405: Total Runs = 194
# Inning 1406: Total Runs = 186
# Inning 1407: Total Runs = 168
# Inning 1408: Total Runs = 147
# Inning 1409: Total Runs = 146
# Inning 1410: Total Runs = 143
# Inning 1411: Total Runs = 185
# Inning 1412: Total Runs = 146
# Inning 1413: Total Runs = 80
# Inning 1414: Total Runs = 183
# Inning 1415: Total Runs = 136
# Inning 1416: Total Runs = 137
# Inning 1417: Total Runs = 169
# Inning 1418: Total Runs = 165
# Inning 1419: Total Runs = 119
# Inning 1420: Total Runs = 120
# Inning 1421: Total Runs = 143
# Inning 1422: Total Runs = 150
# Inning 1423: Total Runs = 159
# Inning 1424: Total Runs = 143
# Inning 1425: Total Runs = 147
# Inning 1426: Total Runs = 146
# Inning 1427: Total Runs = 147
# Inning 1428: Total Runs = 148
# Inning 1429: Total Runs = 163
# Inning 1430: Total Runs = 198
# Inning 1431: Total Runs = 149
# Inning 1432: Total Runs = 157
# Inning 1433: Total Runs = 171
# Inning 1434: Total Runs = 140
# Inning 1435: Total Runs = 131
# Inning 1436: Total Runs = 135
# Inning 1437: Total Runs = 160
# Inning 1438: Total Runs = 159
# Inning 1439: Total Runs = 202
# Inning 1440: Total Runs = 200
# Inning 1441: Total Runs = 148
# Inning 1442: Total Runs = 147
# Inning 1443: Total Runs = 173
# Inning 1444: Total Runs = 174
# Inning 1445: Total Runs = 162
# Inning 1446: Total Runs = 165
# Inning 1447: Total Runs = 121
# Inning 1448: Total Runs = 120
# Inning 1449: Total Runs = 198
# Inning 1450: Total Runs = 113
# Inning 1451: Total Runs = 141
# Inning 1452: Total Runs = 136
# Inning 1453: Total Runs = 128
# Inning 1454: Total Runs = 125
# Inning 1455: Total Runs = 88
# Inning 1456: Total Runs = 113
# Inning 1457: Total Runs = 127
# Inning 1458: Total Runs = 123
# Inning 1459: Total Runs = 187
# Inning 1460: Total Runs = 154
# Inning 1461: Total Runs = 142
# Inning 1462: Total Runs = 141
# Inning 1463: Total Runs = 136
# Inning 1464: Total Runs = 144
# Inning 1465: Total Runs = 150
# Inning 1466: Total Runs = 112
# Inning 1467: Total Runs = 129
# Inning 1468: Total Runs = 124
# Inning 1469: Total Runs = 135
# Inning 1470: Total Runs = 132
# Inning 1471: Total Runs = 182
# Inning 1472: Total Runs = 100
# Inning 1473: Total Runs = 125
# Inning 1474: Total Runs = 123
# Inning 1475: Total Runs = 94
# Inning 1476: Total Runs = 93
# Inning 1477: Total Runs = 132
# Inning 1478: Total Runs = 191
# Inning 1479: Total Runs = 78
# Inning 1480: Total Runs = 46
# Inning 1481: Total Runs = 100
# Inning 1482: Total Runs = 191
# Inning 1483: Total Runs = 164
# Inning 1484: Total Runs = 177
# Inning 1485: Total Runs = 80
# Inning 1486: Total Runs = 170
# Inning 1487: Total Runs = 129
# Inning 1488: Total Runs = 175
# Inning 1489: Total Runs = 178
# Inning 1490: Total Runs = 174
# Inning 1491: Total Runs = 7
# Inning 1492: Total Runs = 174
# Inning 1493: Total Runs = 13
# Inning 1494: Total Runs = 164
# Inning 1495: Total Runs = 179
# Inning 1496: Total Runs = 136
# Inning 1497: Total Runs = 133
# Inning 1498: Total Runs = 141
# Inning 1499: Total Runs = 140
# Inning 1500: Total Runs = 149
# Inning 1501: Total Runs = 148
# Inning 1502: Total Runs = 130
# Inning 1503: Total Runs = 129
# Inning 1504: Total Runs = 147
# Inning 1505: Total Runs = 146
# Inning 1506: Total Runs = 129
# Inning 1507: Total Runs = 128
# Inning 1508: Total Runs = 139
# Inning 1509: Total Runs = 17
# Inning 1510: Total Runs = 139
# Inning 1511: Total Runs = 19
# Inning 1512: Total Runs = 150
# Inning 1513: Total Runs = 169
# Inning 1514: Total Runs = 117
# Inning 1515: Total Runs = 149
# Inning 1516: Total Runs = 152
# Inning 1517: Total Runs = 151
# Inning 1518: Total Runs = 123
# Inning 1519: Total Runs = 139
# Inning 1520: Total Runs = 131
# Inning 1521: Total Runs = 205
# Inning 1522: Total Runs = 101
# Inning 1523: Total Runs = 137
# Inning 1524: Total Runs = 173
# Inning 1525: Total Runs = 172
# Inning 1526: Total Runs = 118
# Inning 1527: Total Runs = 119
# Inning 1528: Total Runs = 29
# Inning 1529: Total Runs = 77
# Inning 1530: Total Runs = 118
# Inning 1531: Total Runs = 90
# Inning 1532: Total Runs = 85
# Inning 1533: Total Runs = 135
# Inning 1534: Total Runs = 153
# Inning 1535: Total Runs = 150
# Inning 1536: Total Runs = 146
# Inning 1537: Total Runs = 160
# Inning 1538: Total Runs = 71
# Inning 1539: Total Runs = 219
# Inning 1540: Total Runs = 153
# Inning 1541: Total Runs = 209
# Inning 1542: Total Runs = 116
# Inning 1543: Total Runs = 177
# Inning 1544: Total Runs = 95
# Inning 1545: Total Runs = 132
# Inning 1546: Total Runs = 122
# Inning 1547: Total Runs = 99
# Inning 1548: Total Runs = 155
# Inning 1549: Total Runs = 116
# Inning 1550: Total Runs = 157
# Inning 1551: Total Runs = 158
# Inning 1552: Total Runs = 181
# Inning 1553: Total Runs = 177
# Inning 1554: Total Runs = 166
# Inning 1555: Total Runs = 167
# Inning 1556: Total Runs = 196
# Inning 1557: Total Runs = 201
# Inning 1558: Total Runs = 2
# Inning 1559: Total Runs = 248
# Inning 1560: Total Runs = 209
# Inning 1561: Total Runs = 168
# Inning 1562: Total Runs = 195
# Inning 1563: Total Runs = 190
# Inning 1564: Total Runs = 119
# Inning 1565: Total Runs = 86
# Inning 1566: Total Runs = 87
# Inning 1567: Total Runs = 169
# Inning 1568: Total Runs = 165
# Inning 1569: Total Runs = 146
# Inning 1570: Total Runs = 179
# Inning 1571: Total Runs = 195
# Inning 1572: Total Runs = 100
# Inning 1573: Total Runs = 214
# Inning 1574: Total Runs = 174
# Inning 1575: Total Runs = 137
# Inning 1576: Total Runs = 192
# Inning 1577: Total Runs = 143
# Inning 1578: Total Runs = 139
# Inning 1579: Total Runs = 89
# Inning 1580: Total Runs = 90
# Inning 1581: Total Runs = 151
# Inning 1582: Total Runs = 11
# Inning 1583: Total Runs = 151
# Inning 1584: Total Runs = 12
# Inning 1585: Total Runs = 168
# Inning 1586: Total Runs = 74
# Inning 1587: Total Runs = 137
# Inning 1588: Total Runs = 139
# Inning 1589: Total Runs = 119
# Inning 1590: Total Runs = 161
# Inning 1591: Total Runs = 164
# Inning 1592: Total Runs = 191
# Inning 1593: Total Runs = 74
# Inning 1594: Total Runs = 6
# Inning 1595: Total Runs = 179
# Inning 1596: Total Runs = 197
# Inning 1597: Total Runs = 133
# Inning 1598: Total Runs = 134
# Inning 1599: Total Runs = 192
# Inning 1600: Total Runs = 181
# Inning 1601: Total Runs = 131
# Inning 1602: Total Runs = 130
# Inning 1603: Total Runs = 158
# Inning 1604: Total Runs = 117
# Inning 1605: Total Runs = 181
# Inning 1606: Total Runs = 198
# Inning 1607: Total Runs = 162
# Inning 1608: Total Runs = 168
# Inning 1609: Total Runs = 168
# Inning 1610: Total Runs = 134
# Inning 1611: Total Runs = 115
# Inning 1612: Total Runs = 103
# Inning 1613: Total Runs = 145
# Inning 1614: Total Runs = 123
# Inning 1615: Total Runs = 163
# Inning 1616: Total Runs = 164
# Inning 1617: Total Runs = 213
# Inning 1618: Total Runs = 200
# Inning 1619: Total Runs = 131
# Inning 1620: Total Runs = 130
# Inning 1621: Total Runs = 195
# Inning 1622: Total Runs = 111
# Inning 1623: Total Runs = 143
# Inning 1624: Total Runs = 170
# Inning 1625: Total Runs = 152
# Inning 1626: Total Runs = 155
# Inning 1627: Total Runs = 165
# Inning 1628: Total Runs = 160
# Inning 1629: Total Runs = 158
# Inning 1630: Total Runs = 152
# Inning 1631: Total Runs = 135
# Inning 1632: Total Runs = 124
# Inning 1633: Total Runs = 201
# Inning 1634: Total Runs = 202
# Inning 1635: Total Runs = 81
# Inning 1636: Total Runs = 80
# Inning 1637: Total Runs = 129
# Inning 1638: Total Runs = 128
# Inning 1639: Total Runs = 98
# Inning 1640: Total Runs = 99
# Inning 1641: Total Runs = 144
# Inning 1642: Total Runs = 150
# Inning 1643: Total Runs = 146
# Inning 1644: Total Runs = 145
# Inning 1645: Total Runs = 187
# Inning 1646: Total Runs = 211
# Inning 1647: Total Runs = 161
# Inning 1648: Total Runs = 136
# Inning 1649: Total Runs = 179
# Inning 1650: Total Runs = 160
# Inning 1651: Total Runs = 189
# Inning 1652: Total Runs = 108
# Inning 1653: Total Runs = 163
# Inning 1654: Total Runs = 159
# Inning 1655: Total Runs = 180
# Inning 1656: Total Runs = 177
# Inning 1657: Total Runs = 174
# Inning 1658: Total Runs = 183
# Inning 1659: Total Runs = 189
# Inning 1660: Total Runs = 204
# Inning 1661: Total Runs = 142
# Inning 1662: Total Runs = 143
# Inning 1663: Total Runs = 164
# Inning 1664: Total Runs = 163
# Inning 1665: Total Runs = 131
# Inning 1666: Total Runs = 130
# Inning 1667: Total Runs = 160
# Inning 1668: Total Runs = 165
# Inning 1669: Total Runs = 172
# Inning 1670: Total Runs = 52
# Inning 1671: Total Runs = 175
# Inning 1672: Total Runs = 191
# Inning 1673: Total Runs = 130
# Inning 1674: Total Runs = 129
# Inning 1675: Total Runs = 168
# Inning 1676: Total Runs = 170
# Inning 1677: Total Runs = 98
# Inning 1678: Total Runs = 171
# Inning 1679: Total Runs = 190
# Inning 1680: Total Runs = 189
# Inning 1681: Total Runs = 178
# Inning 1682: Total Runs = 179
# Inning 1683: Total Runs = 138
# Inning 1684: Total Runs = 141
# Inning 1685: Total Runs = 193
# Inning 1686: Total Runs = 196
# Inning 1687: Total Runs = 140
# Inning 1688: Total Runs = 190
# Inning 1689: Total Runs = 86
# Inning 1690: Total Runs = 159
# Inning 1691: Total Runs = 60
# Inning 1692: Total Runs = 119
# Inning 1693: Total Runs = 158
# Inning 1694: Total Runs = 153
# Inning 1695: Total Runs = 82
# Inning 1696: Total Runs = 166
# Inning 1697: Total Runs = 160
# Inning 1698: Total Runs = 80
# Inning 1699: Total Runs = 176
# Inning 1700: Total Runs = 172
# Inning 1701: Total Runs = 130
# Inning 1702: Total Runs = 134
# Inning 1703: Total Runs = 60
# Inning 1704: Total Runs = 153
# Inning 1705: Total Runs = 176
# Inning 1706: Total Runs = 170
# Inning 1707: Total Runs = 166
# Inning 1708: Total Runs = 168
# Inning 1709: Total Runs = 120
# Inning 1710: Total Runs = 123
# Inning 1711: Total Runs = 117
# Inning 1712: Total Runs = 116
# Inning 1713: Total Runs = 85
# Inning 1714: Total Runs = 96
# Inning 1715: Total Runs = 165
# Inning 1716: Total Runs = 168
# Inning 1717: Total Runs = 231
# Inning 1718: Total Runs = 236
# Inning 1719: Total Runs = 97
# Inning 1720: Total Runs = 96
# Inning 1721: Total Runs = 117
# Inning 1722: Total Runs = 132
# Inning 1723: Total Runs = 126
# Inning 1724: Total Runs = 165
# Inning 1725: Total Runs = 31
# Inning 1726: Total Runs = 195
# Inning 1727: Total Runs = 126
# Inning 1728: Total Runs = 135
# Inning 1729: Total Runs = 140
# Inning 1730: Total Runs = 191
# Inning 1731: Total Runs = 135
# Inning 1732: Total Runs = 177
# Inning 1733: Total Runs = 182
# Inning 1734: Total Runs = 144
# Inning 1735: Total Runs = 127
# Inning 1736: Total Runs = 144
# Inning 1737: Total Runs = 145
# Inning 1738: Total Runs = 102
# Inning 1739: Total Runs = 101
# Inning 1740: Total Runs = 146
# Inning 1741: Total Runs = 145
# Inning 1742: Total Runs = 134
# Inning 1743: Total Runs = 135
# Inning 1744: Total Runs = 171
# Inning 1745: Total Runs = 172
# Inning 1746: Total Runs = 96
# Inning 1747: Total Runs = 148
# Inning 1748: Total Runs = 138
# Inning 1749: Total Runs = 169
# Inning 1750: Total Runs = 151
# Inning 1751: Total Runs = 152
# Inning 1752: Total Runs = 177
# Inning 1753: Total Runs = 145
# Inning 1754: Total Runs = 143
# Inning 1755: Total Runs = 141
# Inning 1756: Total Runs = 175
# Inning 1757: Total Runs = 146
# Inning 1758: Total Runs = 174
# Inning 1759: Total Runs = 172
# Inning 1760: Total Runs = 173
# Inning 1761: Total Runs = 172
# Inning 1762: Total Runs = 176
# Inning 1763: Total Runs = 175
# Inning 1764: Total Runs = 157
# Inning 1765: Total Runs = 158
# Inning 1766: Total Runs = 205
# Inning 1767: Total Runs = 204
# Inning 1768: Total Runs = 181
# Inning 1769: Total Runs = 178
# Inning 1770: Total Runs = 178
# Inning 1771: Total Runs = 124
# Inning 1772: Total Runs = 135
# Inning 1773: Total Runs = 145
# Inning 1774: Total Runs = 198
# Inning 1775: Total Runs = 118
# Inning 1776: Total Runs = 151
# Inning 1777: Total Runs = 188
# Inning 1778: Total Runs = 157
# Inning 1779: Total Runs = 184
# Inning 1780: Total Runs = 197
# Inning 1781: Total Runs = 200
# Inning 1782: Total Runs = 160
# Inning 1783: Total Runs = 146
# Inning 1784: Total Runs = 172
# Inning 1785: Total Runs = 169
# Inning 1786: Total Runs = 154
# Inning 1787: Total Runs = 4
# Inning 1788: Total Runs = 154
# Inning 1789: Total Runs = 3
# Inning 1790: Total Runs = 199
# Inning 1791: Total Runs = 200
# Inning 1792: Total Runs = 92
# Inning 1793: Total Runs = 96
# Inning 1794: Total Runs = 144
# Inning 1795: Total Runs = 140
# Inning 1796: Total Runs = 135
# Inning 1797: Total Runs = 139
# Inning 1798: Total Runs = 182
# Inning 1799: Total Runs = 179
# Inning 1800: Total Runs = 147
# Inning 1801: Total Runs = 142
# Inning 1802: Total Runs = 155
# Inning 1803: Total Runs = 171
# Inning 1804: Total Runs = 171
# Inning 1805: Total Runs = 168
# Inning 1806: Total Runs = 196
# Inning 1807: Total Runs = 101
# Inning 1808: Total Runs = 215
# Inning 1809: Total Runs = 185
# Inning 1810: Total Runs = 139
# Inning 1811: Total Runs = 162
# Inning 1812: Total Runs = 136
# Inning 1813: Total Runs = 123
# Inning 1814: Total Runs = 136
# Inning 1815: Total Runs = 121
# Inning 1816: Total Runs = 136
# Inning 1817: Total Runs = 131
# Inning 1818: Total Runs = 135
# Inning 1819: Total Runs = 136
# Inning 1820: Total Runs = 126
# Inning 1821: Total Runs = 107
# Inning 1822: Total Runs = 113
# Inning 1823: Total Runs = 119
# Inning 1824: Total Runs = 169
# Inning 1825: Total Runs = 170
# Inning 1826: Total Runs = 94
# Inning 1827: Total Runs = 79
# Inning 1828: Total Runs = 126
# Inning 1829: Total Runs = 182
# Inning 1830: Total Runs = 183
# Inning 1831: Total Runs = 146
# Inning 1832: Total Runs = 201
# Inning 1833: Total Runs = 134
# Inning 1834: Total Runs = 142
# Inning 1835: Total Runs = 230
# Inning 1836: Total Runs = 229
# Inning 1837: Total Runs = 119
# Inning 1838: Total Runs = 118
# Inning 1839: Total Runs = 122
# Inning 1840: Total Runs = 127
# Inning 1841: Total Runs = 157
# Inning 1842: Total Runs = 156
# Inning 1843: Total Runs = 180
# Inning 1844: Total Runs = 158
# Inning 1845: Total Runs = 145
# Inning 1846: Total Runs = 146
# Inning 1847: Total Runs = 193
# Inning 1848: Total Runs = 172
# Inning 1849: Total Runs = 122
# Inning 1850: Total Runs = 123
# Inning 1851: Total Runs = 70
# Inning 1852: Total Runs = 145
# Inning 1853: Total Runs = 171
# Inning 1854: Total Runs = 161
# Inning 1855: Total Runs = 160
# Inning 1856: Total Runs = 161
# Inning 1857: Total Runs = 122
# Inning 1858: Total Runs = 120
# Inning 1859: Total Runs = 159
# Inning 1860: Total Runs = 153
# Inning 1861: Total Runs = 192
# Inning 1862: Total Runs = 196
# Inning 1863: Total Runs = 155
# Inning 1864: Total Runs = 161
# Inning 1865: Total Runs = 166
# Inning 1866: Total Runs = 163
# Inning 1867: Total Runs = 167
# Inning 1868: Total Runs = 125
# Inning 1869: Total Runs = 156
# Inning 1870: Total Runs = 187
# Inning 1871: Total Runs = 162
# Inning 1872: Total Runs = 180
# Inning 1873: Total Runs = 101
# Inning 1874: Total Runs = 105
# Inning 1875: Total Runs = 196
# Inning 1876: Total Runs = 127
# Inning 1877: Total Runs = 84
# Inning 1878: Total Runs = 82
# Inning 1879: Total Runs = 121
# Inning 1880: Total Runs = 166
# Inning 1881: Total Runs = 85
# Inning 1882: Total Runs = 83
# Inning 1883: Total Runs = 147
# Inning 1884: Total Runs = 124
# Inning 1885: Total Runs = 142
# Inning 1886: Total Runs = 138
# Inning 1887: Total Runs = 131
# Inning 1888: Total Runs = 129
# Inning 1889: Total Runs = 151
# Inning 1890: Total Runs = 150
# Inning 1891: Total Runs = 120
# Inning 1892: Total Runs = 122
# Inning 1893: Total Runs = 263
# Inning 1894: Total Runs = 178
# Inning 1895: Total Runs = 130
# Inning 1896: Total Runs = 128

# %%
import pandas as pd

# Read the CSV file with the specified columns
df = pd.read_csv("merged_data.csv", usecols=['Col1', 'batter', 'total_runs_delivery', 'balls_faced', 'winning_team'])

# Identify the boundaries of each inning
inning_boundaries_indices = df[df['Col1'] == 0].index

# Append the end of the DataFrame as the last boundary
inning_boundaries_indices = list(inning_boundaries_indices) + [len(df)]

print("Inning Boundaries Indices:")
print(inning_boundaries_indices)

# Function to process each inning
def process_inning(df_inning):
    # Calculate the total runs
    total_runs = df_inning['total_runs_delivery'].sum()
    # Calculate the number of overs
    num_overs = (df_inning['Col1'].max() // 6) + 1
    # Calculate the average runs per over
    avg_runs_per_over = total_runs / num_overs
    return total_runs, num_overs, avg_runs_per_over

# List to store the results for each inning
inning_stats = []

# Iterate through each inning using the boundaries
for i in range(len(inning_boundaries_indices) - 1):
    start_idx = inning_boundaries_indices[i]
    end_idx = inning_boundaries_indices[i + 1]
    df_inning = df.iloc[start_idx:end_idx]
    total_runs, num_overs, avg_runs_per_over = process_inning(df_inning)
    inning_stats.append((total_runs, num_overs, avg_runs_per_over))

# Display the total runs, number of overs, and average runs per over for each inning
for i, (total_runs, num_overs, avg_runs_per_over) in enumerate(inning_stats, start=1):
    print(f"Inning {i}: Total Runs = {total_runs}, Number of Overs = {num_overs}, Average Runs per Over = {avg_runs_per_over:.2f}")
# Out:
# Inning Boundaries Indices:
# [0, 125, 250, 373, 497, 622, 737, 866, 990, 1072, 1197, 1320, 1444, 1578, 1688, 1805, 1929, 2052, 2174, 2265, 2387, 2476, 2597, 2723, 2848, 2971, 3094, 3215, 3342, 3455, 3583, 3706, 3829, 3931, 4059, 4183, 4309, 4321, 4444, 4534, 4660, 4785, 4914, 5007, 5128, 5199, 5325, 5439, 5563, 5654, 5781, 5903, 6030, 6155, 6284, 6409, 6533, 6622, 6746, 6873, 6998, 7115, 7237, 7344, 7468, 7589, 7712, 7839, 7954, 8079, 8189, 8311, 8404, 8521, 8642, 8767, 8886, 9006, 9129, 9253, 9368, 9425, 9549, 9654, 9752, 9873, 9989, 10118, 10242, 10365, 10479, 10512, 10607, 10732, 10855, 10977, 11102, 11216, 11335, 11458, 11579, 11692, 11815, 11941, 12062, 12188, 12237, 12287, 12393, 12505, 12629, 12751, 12875, 12997, 13126, 13252, 13373, 13490, 13616, 13738, 13863, 13961, 14087, 14198, 14317, 14443, 14575, 14683, 14804, 14932, 15057, 15175, 15308, 15422, 15546, 15674, 15783, 15904, 16030, 16152, 16276, 16401, 16525, 16647, 16739, 16866, 16994, 17115, 17239, 17324, 17446, 17563, 17666, 17787, 17909, 18030, 18156, 18277, 18409, 18487, 18589, 18690, 18814, 18924, 18993, 19116, 19240, 19368, 19489, 19612, 19734, 19859, 19985, 20109, 20233, 20355, 20479, 20587, 20691, 20813, 20939, 21061, 21187, 21314, 21441, 21566, 21687, 21693, 21819, 21827, 21951, 22075, 22199, 22305, 22369, 22433, 22540, 22651, 22773, 22901, 23024, 23146, 23263, 23379, 23501, 23627, 23750, 23876, 23933, 24055, 24184, 24311, 24419, 24536, 24646, 24769, 24860, 24980, 25103, 25219, 25285, 25417, 25537, 25650, 25773, 25893, 26018, 26136, 26264, 26391, 26514, 26644, 26751, 26852, 26973, 27098, 27222, 27339, 27463, 27584, 27707, 27830, 27953, 28055, 28176, 28287, 28410, 28539, 28663, 28789, 28919, 29040, 29170, 29291, 29362, 29426, 29505, 29628, 29749, 29883, 30009, 30137, 30262, 30384, 30509, 30632, 30757, 30826, 30906, 31027, 31131, 31256, 31378, 31459, 31576, 31688, 31809, 31829, 31919, 32035, 32155, 32233, 32357, 32477, 32602, 32724, 32847, 32965, 33094, 33226, 33316, 33440, 33561, 33690, 33787, 33905, 34025, 34151, 34256, 34377, 34498, 34622, 34721, 34839, 34961, 35084, 35208, 35339, 35455, 35580, 35705, 35817, 35938, 36058, 36180, 36305, 36434, 36559, 36668, 36741, 36747, 36813, 36820, 36944, 37069, 37177, 37300, 37422, 37428, 37548, 37554, 37681, 37686, 37809, 37815, 37937, 38061, 38170, 38294, 38421, 38520, 38636, 38760, 38882, 39007, 39129, 39249, 39350, 39474, 39601, 39722, 39847, 39971, 40100, 40226, 40337, 40449, 40573, 40699, 40825, 40947, 41071, 41194, 41317, 41439, 41564, 41682, 41808, 41930, 42053, 42169, 42289, 42412, 42511, 42629, 42754, 42878, 43003, 43111, 43234, 43356, 43480, 43604, 43732, 43837, 43960, 44083, 44182, 44311, 44437, 44552, 44565, 44682, 44750, 44874, 44994, 45119, 45222, 45346, 45471, 45598, 45706, 45831, 45953, 46052, 46172, 46265, 46386, 46510, 46631, 46755, 46761, 46884, 46890, 47011, 47136, 47261, 47382, 47509, 47633, 47749, 47871, 47965, 48088, 48185, 48308, 48409, 48519, 48648, 48777, 48793, 48909, 49032, 49150, 49270, 49391, 49512, 49624, 49748, 49876, 50000, 50124, 50228, 50351, 50468, 50596, 50690, 50816, 50940, 51042, 51153, 51211, 51272, 51395, 51522, 51644, 51769, 51881, 52004, 52125, 52248, 52374, 52497, 52616, 52739, 52861, 52983, 53106, 53208, 53327, 53449, 53544, 53666, 53791, 53900, 54012, 54135, 54259, 54383, 54514, 54636, 54744, 54869, 54969, 55093, 55218, 55337, 55462, 55582, 55709, 55794, 55903, 56024, 56154, 56273, 56400, 56523, 56644, 56765, 56888, 57011, 57142, 57264, 57390, 57498, 57622, 57744, 57867, 57951, 58077, 58191, 58314, 58432, 58553, 58656, 58784, 58908, 59035, 59160, 59288, 59413, 59540, 59667, 59796, 59918, 60043, 60164, 60286, 60406, 60531, 60647, 60772, 60892, 61015, 61107, 61230, 61324, 61449, 61573, 61703, 61833, 61958, 62082, 62210, 62336, 62437, 62562, 62688, 62816, 62943, 63038, 63168, 63294, 63423, 63556, 63612, 63737, 63861, 63869, 63887, 64011, 64129, 64253, 64256, 64378, 64384, 64486, 64611, 64726, 64847, 64973, 65097, 65218, 65333, 65456, 65583, 65707, 65828, 65953, 66077, 66198, 66316, 66437, 66560, 66676, 66 ...
# Inning 1: Total Runs = 168, Number of Overs = 21, Average Runs per Over = 8.00
# Inning 2: Total Runs = 172, Number of Overs = 21, Average Runs per Over = 8.19
# Inning 3: Total Runs = 173, Number of Overs = 21, Average Runs per Over = 8.24
# Inning 4: Total Runs = 176, Number of Overs = 21, Average Runs per Over = 8.38
# Inning 5: Total Runs = 187, Number of Overs = 21, Average Runs per Over = 8.90
# Inning 6: Total Runs = 146, Number of Overs = 20, Average Runs per Over = 7.30
# Inning 7: Total Runs = 168, Number of Overs = 22, Average Runs per Over = 7.64
# Inning 8: Total Runs = 170, Number of Overs = 21, Average Runs per Over = 8.10
# Inning 9: Total Runs = 103, Number of Overs = 14, Average Runs per Over = 7.36
# Inning 10: Total Runs = 99, Number of Overs = 21, Average Runs per Over = 4.71
# Inning 11: Total Runs = 138, Number of Overs = 21, Average Runs per Over = 6.57
# Inning 12: Total Runs = 135, Number of Overs = 21, Average Runs per Over = 6.43
# Inning 13: Total Runs = 141, Number of Overs = 23, Average Runs per Over = 6.13
# Inning 14: Total Runs = 143, Number of Overs = 19, Average Runs per Over = 7.53
# Inning 15: Total Runs = 148, Number of Overs = 20, Average Runs per Over = 7.40
# Inning 16: Total Runs = 195, Number of Overs = 21, Average Runs per Over = 9.29
# Inning 17: Total Runs = 167, Number of Overs = 21, Average Runs per Over = 7.95
# Inning 18: Total Runs = 194, Number of Overs = 21, Average Runs per Over = 9.24
# Inning 19: Total Runs = 107, Number of Overs = 16, Average Runs per Over = 6.69
# Inning 20: Total Runs = 185, Number of Overs = 21, Average Runs per Over = 8.81
# Inning 21: Total Runs = 143, Number of Overs = 15, Average Runs per Over = 9.53
# Inning 22: Total Runs = 142, Number of Overs = 21, Average Runs per Over = 6.76
# Inning 23: Total Runs = 171, Number of Overs = 21, Average Runs per Over = 8.14
# Inning 24: Total Runs = 174, Number of Overs = 21, Average Runs per Over = 8.29
# Inning 25: Total Runs = 181, Number of Overs = 21, Average Runs per Over = 8.62
# Inning 26: Total Runs = 162, Number of Overs = 21, Average Runs per Over = 7.71
# Inning 27: Total Runs = 155, Number of Overs = 21, Average Runs per Over = 7.38
# Inning 28: Total Runs = 176, Number of Overs = 22, Average Runs per Over = 8.00
# Inning 29: Total Runs = 148, Number of Overs = 19, Average Runs per Over = 7.79
# Inning 30: Total Runs = 147, Number of Overs = 22, Average Runs per Over = 6.68
# Inning 31: Total Runs = 139, Number of Overs = 21, Average Runs per Over = 6.62
# Inning 32: Total Runs = 144, Number of Overs = 21, Average Runs per Over = 6.86
# Inning 33: Total Runs = 127, Number of Overs = 17, Average Runs per Over = 7.47
# Inning 34: Total Runs = 202, Number of Overs = 22, Average Runs per Over = 9.18
# Inning 35: Total Runs = 244, Number of Overs = 21, Average Runs per Over = 11.62
# Inning 36: Total Runs = 245, Number of Overs = 21, Average Runs per Over = 11.67
# Inning 37: Total Runs = 15, Number of Overs = 2, Average Runs per Over = 7.50
# Inning 38: Total Runs = 143, Number of Overs = 21, Average Runs per Over = 6.81
# Inning 39: Total Runs = 116, Number of Overs = 15, Average Runs per Over = 7.73
# Inning 40: Total Runs = 115, Number of Overs = 21, Average Runs per Over = 5.48
# Inning 41: Total Runs = 160, Number of Overs = 21, Average Runs per Over = 7.62
# Inning 42: Total Runs = 144, Number of Overs = 22, Average Runs per Over = 6.55
# Inning 43: Total Runs = 108, Number of Overs = 16, Average Runs per Over = 6.75
# Inning 44: Total Runs = 103, Number of Overs = 21, Average Runs per Over = 4.90
# Inning 45: Total Runs = 96, Number of Overs = 12, Average Runs per Over = 8.00
# Inning 46: Total Runs = 117, Number of Overs = 21, Average Runs per Over = 5.57
# Inning 47: Total Runs = 161, Number of Overs = 19, Average Runs per Over = 8.47
# Inning 48: Total Runs = 155, Number of Overs = 21, Average Runs per Over = 7.38
# Inning 49: Total Runs = 138, Number of Overs = 16, Average Runs per Over = 8.62
# Inning 50: Total Runs = 137, Number of Overs = 22, Average Runs per Over = 6.23
# Inning 51: Total Runs = 184, Number of Overs = 21, Average Runs per Over = 8.76
# Inning 52: Total Runs = 196, Number of Overs = 22, Average Runs per Over = 8.91
# Inning 53: Total Runs = 245, Number of Overs = 21, Average Runs per Over = 11.67
# Inning 54: Total Runs = 243, Number of Overs = 22, Average Runs per Over = 11.05
# Inning 55: Total Runs = 194, Number of Overs = 21, Average Runs per Over = 9.24
# Inning 56: Total Runs = 192, Number of Overs = 21, Average Runs per Over = 9.14
# Inning 57: Total Runs = 121, Number of Overs = 15, Average Runs per Over = 8.07
# Inning 58: Total Runs = 150, Number of Overs = 21, Average Runs per Over = 7.14
# Inning 59: Total Runs = 175, Number of Overs = 22, Average Runs per Over = 7.95
# Inning 60: Total Runs = 195, Number of Overs = 21, Average Runs per Over = 9.29
# Inning 61: Total Runs = 141, Number of Overs = 20, Average Runs per Over = 7.05
# Inning 62: Total Runs = 224, Number of Overs = 21, Average Runs per Over = 10.67
# Inning 63: Total Runs = 115, Number of Overs = 18, Average Runs per Over = 6.39
# Inning 64: Total Runs = 111, Number of Overs = 21, Average Runs per Over = 5.29
# Inning 65: Total Runs = 132, Number of Overs = 21, Average Runs per Over = 6.29
# Inning 66: Total Runs = 129, Number of Overs = 21, Average Runs per Over = 6.14
# Inning 67: Total Runs = 155, Number of Overs = 22, Average Runs per Over = 7.05
# Inning 68: Total Runs = 158, Number of Overs = 20, Average Runs per Over = 7.90
# Inning 69: Total Runs = 176, Number of Overs = 21, Average Runs per Over = 8.38
# Inning 70: Total Runs = 131, Number of Overs = 19, Average Runs per Over = 6.89
# Inning 71: Total Runs = 137, Number of Overs = 21, Average Runs per Over = 6.52
# Inning 72: Total Runs = 138, Number of Overs = 16, Average Runs per Over = 8.62
# Inning 73: Total Runs = 127, Number of Overs = 20, Average Runs per Over = 6.35
# Inning 74: Total Runs = 124, Number of Overs = 21, Average Runs per Over = 5.90
# Inning 75: Total Runs = 190, Number of Overs = 21, Average Runs per Over = 9.05
# Inning 76: Total Runs = 194, Number of Overs = 20, Average Runs per Over = 9.70
# Inning 77: Total Runs = 174, Number of Overs = 20, Average Runs per Over = 8.70
# Inning 78: Total Runs = 170, Number of Overs = 21, Average Runs per Over = 8.10
# Inning 79: Total Runs = 187, Number of Overs = 21, Average Runs per Over = 8.90
# Inning 80: Total Runs = 140, Number of Overs = 20, Average Runs per Over = 7.00
# Inning 81: Total Runs = 102, Number of Overs = 10, Average Runs per Over = 10.20
# Inning 82: Total Runs = 243, Number of Overs = 21, Average Runs per Over = 11.57
# Inning 83: Total Runs = 124, Number of Overs = 18, Average Runs per Over = 6.89
# Inning 84: Total Runs = 106, Number of Overs = 17, Average Runs per Over = 6.24
# Inning 85: Total Runs = 105, Number of Overs = 21, Average Runs per Over = 5.00
# Inning 86: Total Runs = 153, Number of Overs = 20, Average Runs per Over = 7.65
# Inning 87: Total Runs = 201, Number of Overs = 22, Average Runs per Over = 9.14
# Inning 88: Total Runs = 163, Number of Overs = 21, Average Runs per Over = 7.76
# Inning 89: Total Runs = 181, Number of Overs = 21, Average Runs per Over = 8.62
# Inning 90: Total Runs = 118, Number of Overs = 19, Average Runs per Over = 6.21
# Inning 91: Total Runs = 49, Number of Overs = 6, Average Runs per Over = 8.17
# Inning 92: Total Runs = 122, Number of Overs = 16, Average Runs per Over = 7.62
# Inning 93: Total Runs = 118, Number of Overs = 21, Average Runs per Over = 5.62
# Inning 94: Total Runs = 193, Number of Overs = 21, Average Runs per Over = 9.19
# Inning 95: Total Runs = 221, Number of Overs = 21, Average Runs per Over = 10.52
# Inning 96: Total Runs = 159, Number of Overs = 21, Average Runs per Over = 7.57
# Inning 97: Total Runs = 163, Number of Overs = 19, Average Runs per Over = 8.58
# Inning 98: Total Runs = 149, Number of Overs = 20, Average Runs per Over = 7.45
# Inning 99: Total Runs = 148, Number of Overs = 21, Average Runs per Over = 7.05
# Inning 100: Total Runs = 198, Number of Overs = 21, Average Runs per Over = 9.43
# Inning 101: Total Runs = 201, Number of Overs = 19, Average Runs per Over = 10.58
# Inning 102: Total Runs = 202, Number of Overs = 21, Average Runs per Over = 9.62
# Inning 103: Total Runs = 149, Number of Overs = 21, Average Runs per Over = 7.10
# Inning 104: Total Runs = 156, Number of Overs = 21, Average Runs per Over = 7.43
# Inning 105: Total Runs = 196, Number of Overs = 21, Average Runs per Over = 9.33
# Inning 106: Total Runs = 67, Number of Overs = 9, Average Runs per Over = 7.44
# Inning 107: Total Runs = 61, Number of Overs = 9, Average Runs per Over = 6.78
# Inning 108: Total Runs = 103, Number of Overs = 18, Average Runs per Over = 5.72
# Inning 109: Total Runs = 102, Number of Overs = 19, Average Runs per Over = 5.37
# Inning 110: Total Runs = 125, Number of Overs = 21, Average Runs per Over = 5.95
# Inning 111: Total Runs = 124, Number of Overs = 21, Average Runs per Over = 5.90
# Inning 112: Total Runs = 180, Number of Overs = 21, Average Runs per Over = 8.57
# Inning 113: Total Runs = 144, Number of Overs = 21, Average Runs per Over = 6.86
# Inning 114: Total Runs = 203, Number of Overs = 22, Average Runs per Over = 9.23
# Inning 115: Total Runs = 175, Number of Overs = 21, Average Runs per Over = 8.33
# Inning 116: Total Runs = 188, Number of Overs = 21, Average Runs per Over = 8.95
# Inning 117: Total Runs = 189, Number of Overs = 20, Average Runs per Over = 9.45
# Inning 118: Total Runs = 172, Number of Overs = 21, Average Runs per Over = 8.19
# Inning 119: Total Runs = 165, Number of Overs = 21, Average Runs per Over = 7.86
# Inning 120: Total Runs = 180, Number of Overs = 21, Average Runs per Over = 8.57
# Inning 121: Total Runs = 87, Number of Overs = 17, Average Runs per Over = 5.12
# Inning 122: Total Runs = 260, Number of Overs = 21, Average Runs per Over = 12.38
# Inning 123: Total Runs = 172, Number of Overs = 19, Average Runs per Over = 9.05
# Inning 124: Total Runs = 139, Number of Overs = 20, Average Runs per Over = 6.95
# Inning 125: Total Runs = 135, Number of Overs = 21, Average Runs per Over = 6.43
# Inning 126: Total Runs = 193, Number of Overs = 22, Average Runs per Over = 8.77
# Inning 127: Total Runs = 194, Number of Overs = 18, Average Runs per Over = 10.78
# Inning 128: Total Runs = 135, Number of Overs = 21, Average Runs per Over = 6.43
# Inning 129: Total Runs = 210, Number of Overs = 22, Average Runs per Over = 9.55
# Inning 130: Total Runs = 174, Number of Overs = 21, Average Runs per Over = 8.29
# Inning 131: Total Runs = 175, Number of Overs = 20, Average Runs per Over = 8.75
# Inning 132: Total Runs = 139, Number of Overs = 23, Average Runs per Over = 6.04
# Inning 133: Total Runs = 140, Number of Overs = 19, Average Runs per Over = 7.37
# Inning 134: Total Runs = 215, Number of Overs = 21, Average Runs per Over = 10.24
# Inning 135: Total Runs = 214, Number of Overs = 22, Average Runs per Over = 9.73
# Inning 136: Total Runs = 153, Number of Overs = 19, Average Runs per Over = 8.05
# Inning 137: Total Runs = 152, Number of Overs = 21, Average Runs per Over = 7.24
# Inning 138: Total Runs = 159, Number of Overs = 21, Average Runs per Over = 7.57
# Inning 139: Total Runs = 176, Number of Overs = 21, Average Runs per Over = 8.38
# Inning 140: Total Runs = 160, Number of Overs = 21, Average Runs per Over = 7.62
# Inning 141: Total Runs = 159, Number of Overs = 21, Average Runs per Over = 7.57
# Inning 142: Total Runs = 166, Number of Overs = 21, Average Runs per Over = 7.90
# Inning 143: Total Runs = 168, Number of Overs = 21, Average Runs per Over = 8.00
# Inning 144: Total Runs = 121, Number of Overs = 16, Average Runs per Over = 7.56
# Inning 145: Total Runs = 120, Number of Overs = 22, Average Runs per Over = 5.45
# Inning 146: Total Runs = 158, Number of Overs = 22, Average Runs per Over = 7.18
# Inning 147: Total Runs = 141, Number of Overs = 21, Average Runs per Over = 6.71
# Inning 148: Total Runs = 203, Number of Overs = 21, Average Runs per Over = 9.67
# Inning 149: Total Runs = 60, Number of Overs = 15, Average Runs per Over = 4.00
# Inning 150: Total Runs = 205, Number of Overs = 21, Average Runs per Over = 9.76
# Inning 151: Total Runs = 123, Number of Overs = 20, Average Runs per Over = 6.15
# Inning 152: Total Runs = 154, Number of Overs = 18, Average Runs per Over = 8.56
# Inning 153: Total Runs = 153, Number of Overs = 21, Average Runs per Over = 7.29
# Inning 154: Total Runs = 187, Number of Overs = 21, Average Runs per Over = 8.90
# Inning 155: Total Runs = 157, Number of Overs = 21, Average Runs per Over = 7.48
# Inning 156: Total Runs = 208, Number of Overs = 21, Average Runs per Over = 9.90
# Inning 157: Total Runs = 132, Number of Overs = 21, Average Runs per Over = 6.29
# Inning 158: Total Runs = 213, Number of Overs = 22, Average Runs per Over = 9.68
# Inning 159: Total Runs = 70, Number of Overs = 13, Average Runs per Over = 5.38
# Inning 160: Total Runs = 98, Number of Overs = 17, Average Runs per Over = 5.76
# Inning 161: Total Runs = 99, Number of Overs = 17, Average Runs per Over = 5.82
# Inning 162: Total Runs = 182, Number of Overs = 21, Average Runs per Over = 8.67
# Inning 163: Total Runs = 108, Number of Overs = 19, Average Runs per Over = 5.68
# Inning 164: Total Runs = 117, Number of Overs = 12, Average Runs per Over = 9.75
# Inning 165: Total Runs = 116, Number of Overs = 21, Average Runs per Over = 5.52
# Inning 166: Total Runs = 229, Number of Overs = 21, Average Runs per Over = 10.90
# Inning 167: Total Runs = 129, Number of Overs = 22, Average Runs per Over = 5.86
# Inning 168: Total Runs = 163, Number of Overs = 21, Average Runs per Over = 7.76
# Inning 169: Total Runs = 162, Number of Overs = 21, Average Runs per Over = 7.71
# Inning 170: Total Runs = 149, Number of Overs = 21, Average Runs per Over = 7.10
# Inning 171: Total Runs = 194, Number of Overs = 21, Average Runs per Over = 9.24
# Inning 172: Total Runs = 154, Number of Overs = 21, Average Runs per Over = 7.33
# Inning 173: Total Runs = 151, Number of Overs = 21, Average Runs per Over = 7.19
# Inning 174: Total Runs = 183, Number of Overs = 21, Average Runs per Over = 8.71
# Inning 175: Total Runs = 187, Number of Overs = 21, Average Runs per Over = 8.90
# Inning 176: Total Runs = 160, Number of Overs = 21, Average Runs per Over = 7.62
# Inning 177: Total Runs = 126, Number of Overs = 18, Average Runs per Over = 7.00
# Inning 178: Total Runs = 135, Number of Overs = 18, Average Runs per Over = 7.50
# Inning 179: Total Runs = 132, Number of Overs = 21, Average Runs per Over = 6.29
# Inning 180: Total Runs = 186, Number of Overs = 21, Average Runs per Over = 8.86
# Inning 181: Total Runs = 192, Number of Overs = 21, Average Runs per Over = 9.14
# Inning 182: Total Runs = 181, Number of Overs = 21, Average Runs per Over = 8.62
# Inning 183: Total Runs = 188, Number of Overs = 22, Average Runs per Over = 8.55
# Inning 184: Total Runs = 168, Number of Overs = 22, Average Runs per Over = 7.64
# Inning 185: Total Runs = 141, Number of Overs = 21, Average Runs per Over = 6.71
# Inning 186: Total Runs = 134, Number of Overs = 21, Average Runs per Over = 6.38
# Inning 187: Total Runs = 14, Number of Overs = 1, Average Runs per Over = 14.00
# Inning 188: Total Runs = 134, Number of Overs = 21, Average Runs per Over = 6.38
# Inning 189: Total Runs = 5, Number of Overs = 2, Average Runs per Over = 2.50
# Inning 190: Total Runs = 180, Number of Overs = 21, Average Runs per Over = 8.57
# Inning 191: Total Runs = 164, Number of Overs = 21, Average Runs per Over = 7.81
# Inning 192: Total Runs = 198, Number of Overs = 21, Average Runs per Over = 9.43
# Inning 193: Total Runs = 137, Number of Overs = 18, Average Runs per Over = 7.61
# Inning 194: Total Runs = 87, Number of Overs = 11, Average Runs per Over = 7.91
# Inning 195: Total Runs = 108, Number of Overs = 11, Average Runs per Over = 9.82
# Inning 196: Total Runs = 158, Number of Overs = 18, Average Runs per Over = 8.78
# Inning 197: Total Runs = 169, Number of Overs = 19, Average Runs per Over = 8.89
# Inning 198: Total Runs = 132, Number of Overs = 21, Average Runs per Over = 6.29
# Inning 199: Total Runs = 164, Number of Overs = 22, Average Runs per Over = 7.45
# Inning 200: Total Runs = 168, Number of Overs = 21, Average Runs per Over = 8.00
# Inning 201: Total Runs = 167, Number of Overs = 21, Average Runs per Over = 7.95
# Inning 202: Total Runs = 122, Number of Overs = 20, Average Runs per Over = 6.10
# Inning 203: Total Runs = 135, Number of Overs = 20, Average Runs per Over = 6.75
# Inning 204: Total Runs = 134, Number of Overs = 21, Average Runs per Over = 6.38
# Inning 205: Total Runs = 145, Number of Overs = 21, Average Runs per Over = 6.90
# Inning 206: Total Runs = 144, Number of Overs = 21, Average Runs per Over = 6.86
# Inning 207: Total Runs = 143, Number of Overs = 21, Average Runs per Over = 6.81
# Inning 208: Total Runs = 93, Number of Overs = 10, Average Runs per Over = 9.30
# Inning 209: Total Runs = 171, Number of Overs = 21, Average Runs per Over = 8.14
# Inning 210: Total Runs = 159, Number of Overs = 22, Average Runs per Over = 7.23
# Inning 211: Total Runs = 184, Number of Overs = 22, Average Runs per Over = 8.36
# Inning 212: Total Runs = 135, Number of Overs = 18, Average Runs per Over = 7.50
# Inning 213: Total Runs = 160, Number of Overs = 20, Average Runs per Over = 8.00
# Inning 214: Total Runs = 144, Number of Overs = 19, Average Runs per Over = 7.58
# Inning 215: Total Runs = 160, Number of Overs = 21, Average Runs per Over = 7.62
# Inning 216: Total Runs = 79, Number of Overs = 16, Average Runs per Over = 4.94
# Inning 217: Total Runs = 175, Number of Overs = 20, Average Runs per Over = 8.75
# Inning 218: Total Runs = 173, Number of Overs = 21, Average Runs per Over = 8.24
# Inning 219: Total Runs = 129, Number of Overs = 20, Average Runs per Over = 6.45
# Inning 220: Total Runs = 130, Number of Overs = 11, Average Runs per Over = 11.82
# Inning 221: Total Runs = 211, Number of Overs = 22, Average Runs per Over = 9.59
# Inning 222: Total Runs = 175, Number of Overs = 20, Average Runs per Over = 8.75
# Inning 223: Total Runs = 140, Number of Overs = 19, Average Runs per Over = 7.37
# Inning 224: Total Runs = 190, Number of Overs = 21, Average Runs per Over = 9.05
# Inning 225: Total Runs = 139, Number of Overs = 20, Average Runs per Over = 6.95
# Inning 226: Total Runs = 219, Number of Overs = 21, Average Runs per Over = 10.43
# Inning 227: Total Runs = 162, Number of Overs = 20, Average Runs per Over = 8.10
# Inning 228: Total Runs = 158, Number of Overs = 22, Average Runs per Over = 7.18
# Inning 229: Total Runs = 208, Number of Overs = 22, Average Runs per Over = 9.45
# Inning 230: Total Runs = 212, Number of Overs = 21, Average Runs per Over = 10.10
# Inning 231: Total Runs = 179, Number of Overs = 22, Average Runs per Over = 8.14
# Inning 232: Total Runs = 144, Number of Overs = 18, Average Runs per Over = 8.00
# Inning 233: Total Runs = 89, Number of Overs = 17, Average Runs per Over = 5.24
# Inning 234: Total Runs = 155, Number of Overs = 21, Average Runs per Over = 7.38
# Inning 235: Total Runs = 136, Number of Overs = 21, Average Runs per Over = 6.48
# Inning 236: Total Runs = 147, Number of Overs = 21, Average Runs per Over = 7.00
# Inning 237: Total Runs = 117, Number of Overs = 20, Average Runs per Over = 5.85
# Inning 238: Total Runs = 150, Number of Overs = 21, Average Runs per Over = 7.14
# Inning 239: Total Runs = 146, Number of Overs = 21, Average Runs per Over = 6.95
# Inning 240: Total Runs = 148, Number of Overs = 21, Average Runs per Over = 7.05
# Inning 241: Total Runs = 153, Number of Overs = 21, Average Runs per Over = 7.29
# Inning 242: Total Runs = 154, Number of Overs = 21, Average Runs per Over = 7.33
# Inning 243: Total Runs = 119, Number of Overs = 17, Average Runs per Over = 7.00
# Inning 244: Total Runs = 166, Number of Overs = 21, Average Runs per Over = 7.90
# Inning 245: Total Runs = 110, Number of Overs = 19, Average Runs per Over = 5.79
# Inning 246: Total Runs = 109, Number of Overs = 21, Average Runs per Over = 5.19
# Inning 247: Total Runs = 195, Number of Overs = 22, Average Runs per Over = 8.86
# Inning 248: Total Runs = 124, Number of Overs = 21, Average Runs per Over = 5.90
# Inning 249: Total Runs = 182, Number of Overs = 21, Average Runs per Over = 8.67
# Inning 250: Total Runs = 181, Number of Overs = 22, Average Runs per Over = 8.23
# Inning 251: Total Runs = 161, Number of Overs = 21, Average Runs per Over = 7.67
# Inning 252: Total Runs = 160, Number of Overs = 22, Average Runs per Over = 7.27
# Inning 253: Total Runs = 182, Number of Overs = 21, Average Runs per Over = 8.67
# Inning 254: Total Runs = 45, Number of Overs = 12, Average Runs per Over = 3.75
# Inning 255: Total Runs = 72, Number of Overs = 11, Average Runs per Over = 6.55
# Inning 256: Total Runs = 71, Number of Overs = 14, Average Runs per Over = 5.07
# Inning 257: Total Runs = 136, Number of Overs = 21, Average Runs per Over = 6.48
# Inning 258: Total Runs = 132, Number of Overs = 21, Average Runs per Over = 6.29
# Inning 259: Total Runs = 278, Number of Overs = 23, Average Runs per Over = 12.09
# Inning 260: Total Runs = 194, Number of Overs = 21, Average Runs per Over = 9.24
# Inning 261: Total Runs = 210, Number of Overs = 22, Average Runs per Over = 9.55
# Inning 262: Total Runs = 178, Number of Overs = 21, Average Runs per Over = 8.48
# Inning 263: Total Runs = 127, Number of Overs = 21, Average Runs per Over = 6.05
# Inning 264: Total Runs = 126, Number of Overs = 21, Average Runs per Over = 6.00
# Inning 265: Total Runs = 194, Number of Overs = 21, Average Runs per Over = 9.24
# Inning 266: Total Runs = 190, Number of Overs = 21, Average Runs per Over = 9.05
# Inning 267: Total Runs = 134, Number of Overs = 12, Average Runs per Over = 11.17
# Inning 268: Total Runs = 132, Number of Overs = 14, Average Runs per Over = 9.43
# Inning 269: Total Runs = 171, Number of Overs = 21, Average Runs per Over = 8.14
# Inning 270: Total Runs = 172, Number of Overs = 18, Average Runs per Over = 9.56
# Inning 271: Total Runs = 233, Number of Overs = 21, Average Runs per Over = 11.10
# Inning 272: Total Runs = 99, Number of Overs = 21, Average Runs per Over = 4.71
# Inning 273: Total Runs = 118, Number of Overs = 14, Average Runs per Over = 8.43
# Inning 274: Total Runs = 117, Number of Overs = 20, Average Runs per Over = 5.85
# Inning 275: Total Runs = 145, Number of Overs = 19, Average Runs per Over = 7.63
# Inning 276: Total Runs = 142, Number of Overs = 21, Average Runs per Over = 6.76
# Inning 277: Total Runs = 41, Number of Overs = 4, Average Runs per Over = 10.25
# Inning 278: Total Runs = 107, Number of Overs = 15, Average Runs per Over = 7.13
# Inning 279: Total Runs = 151, Number of Overs = 20, Average Runs per Over = 7.55
# Inning 280: Total Runs = 150, Number of Overs = 20, Average Runs per Over = 7.50
# Inning 281: Total Runs = 109, Number of Overs = 13, Average Runs per Over = 8.38
# Inning 282: Total Runs = 106, Number of Overs = 21, Average Runs per Over = 5.05
# Inning 283: Total Runs = 176, Number of Overs = 20, Average Runs per Over = 8.80
# Inning 284: Total Runs = 177, Number of Overs = 21, Average Runs per Over = 8.43
# Inning 285: Total Runs = 204, Number of Overs = 21, Average Runs per Over = 9.71
# Inning 286: Total Runs = 202, Number of Overs = 21, Average Runs per Over = 9.62
# Inning 287: Total Runs = 226, Number of Overs = 20, Average Runs per Over = 11.30
# Inning 288: Total Runs = 222, Number of Overs = 22, Average Runs per Over = 10.09
# Inning 289: Total Runs = 196, Number of Overs = 22, Average Runs per Over = 8.91
# Inning 290: Total Runs = 89, Number of Overs = 15, Average Runs per Over = 5.93
# Inning 291: Total Runs = 146, Number of Overs = 21, Average Runs per Over = 6.95
# Inning 292: Total Runs = 158, Number of Overs = 21, Average Runs per Over = 7.52
# Inning 293: Total Runs = 193, Number of Overs = 22, Average Runs per Over = 8.77
# Inning 294: Total Runs = 96, Number of Overs = 17, Average Runs per Over = 5.65
# Inning 295: Total Runs = 151, Number of Overs = 20, Average Runs per Over = 7.55
# Inning 296: Total Runs = 149, Number of Overs = 20, Average Runs per Over = 7.45
# Inning 297: Total Runs = 134, Number of Overs = 21, Average Runs per Over = 6.38
# Inning 298: Total Runs = 140, Number of Overs = 18, Average Runs per Over = 7.78
# Inning 299: Total Runs = 154, Number of Overs = 21, Average Runs per Over = 7.33
# Inning 300: Total Runs = 148, Number of Overs = 21, Average Runs per Over = 7.05
# Inning 301: Total Runs = 153, Number of Overs = 21, Average Runs per Over = 7.29
# Inning 302: Total Runs = 154, Number of Overs = 17, Average Runs per Over = 9.06
# Inning 303: Total Runs = 144, Number of Overs = 20, Average Runs per Over = 7.20
# Inning 304: Total Runs = 174, Number of Overs = 21, Average Runs per Over = 8.29
# Inning 305: Total Runs = 209, Number of Overs = 21, Average Runs per Over = 9.95
# Inning 306: Total Runs = 207, Number of Overs = 21, Average Runs per Over = 9.86
# Inning 307: Total Runs = 170, Number of Overs = 22, Average Runs per Over = 7.73
# Inning 308: Total Runs = 173, Number of Overs = 20, Average Runs per Over = 8.65
# Inning 309: Total Runs = 240, Number of Overs = 21, Average Runs per Over = 11.43
# Inning 310: Total Runs = 173, Number of Overs = 21, Average Runs per Over = 8.24
# Inning 311: Total Runs = 154, Number of Overs = 19, Average Runs per Over = 8.11
# Inning 312: Total Runs = 153, Number of Overs = 21, Average Runs per Over = 7.29
# Inning 313: Total Runs = 155, Number of Overs = 20, Average Runs per Over = 7.75
# Inning 314: Total Runs = 176, Number of Overs = 21, Average Runs per Over = 8.38
# Inning 315: Total Runs = 166, Number of Overs = 21, Average Runs per Over = 7.90
# Inning 316: Total Runs = 180, Number of Overs = 22, Average Runs per Over = 8.18
# Inning 317: Total Runs = 241, Number of Overs = 21, Average Runs per Over = 11.48
# Inning 318: Total Runs = 165, Number of Overs = 19, Average Runs per Over = 8.68
# Inning 319: Total Runs = 146, Number of Overs = 13, Average Runs per Over = 11.23
# Inning 320: Total Runs = 17, Number of Overs = 1, Average Runs per Over = 17.00
# Inning 321: Total Runs = 146, Number of Overs = 11, Average Runs per Over = 13.27
# Inning 322: Total Runs = 8, Number of Overs = 2, Average Runs per Over = 4.00
# Inning 323: Total Runs = 204, Number of Overs = 21, Average Runs per Over = 9.71
# Inning 324: Total Runs = 203, Number of Overs = 21, Average Runs per Over = 9.67
# Inning 325: Total Runs = 135, Number of Overs = 18, Average Runs per Over = 7.50
# Inning 326: Total Runs = 132, Number of Overs = 21, Average Runs per Over = 6.29
# Inning 327: Total Runs = 179, Number of Overs = 21, Average Runs per Over = 8.52
# Inning 328: Total Runs = 20, Number of Overs = 1, Average Runs per Over = 20.00
# Inning 329: Total Runs = 179, Number of Overs = 20, Average Runs per Over = 8.95
# Inning 330: Total Runs = 17, Number of Overs = 1, Average Runs per Over = 17.00
# Inning 331: Total Runs = 165, Number of Overs = 22, Average Runs per Over = 7.50
# Inning 332: Total Runs = 16, Number of Overs = 1, Average Runs per Over = 16.00
# Inning 333: Total Runs = 165, Number of Overs = 21, Average Runs per Over = 7.86
# Inning 334: Total Runs = 13, Number of Overs = 1, Average Runs per Over = 13.00
# Inning 335: Total Runs = 163, Number of Overs = 21, Average Runs per Over = 7.76
# Inning 336: Total Runs = 156, Number of Overs = 21, Average Runs per Over = 7.43
# Inning 337: Total Runs = 98, Number of Overs = 19, Average Runs per Over = 5.16
# Inning 338: Total Runs = 95, Number of Overs = 21, Average Runs per Over = 4.52
# Inning 339: Total Runs = 167, Number of Overs = 22, Average Runs per Over = 7.59
# Inning 340: Total Runs = 98, Number of Overs = 17, Average Runs per Over = 5.76
# Inning 341: Total Runs = 150, Number of Overs = 20, Average Runs per Over = 7.50
# Inning 342: Total Runs = 146, Number of Overs = 21, Average Runs per Over = 6.95
# Inning 343: Total Runs = 175, Number of Overs = 21, Average Runs per Over = 8.33
# Inning 344: Total Runs = 174, Number of Overs = 21, Average Runs per Over = 8.29
# Inning 345: Total Runs = 165, Number of Overs = 21, Average Runs per Over = 7.86
# Inning 346: Total Runs = 161, Number of Overs = 20, Average Runs per Over = 8.05
# Inning 347: Total Runs = 88, Number of Overs = 17, Average Runs per Over = 5.18
# Inning 348: Total Runs = 125, Number of Overs = 21, Average Runs per Over = 5.95
# Inning 349: Total Runs = 134, Number of Overs = 22, Average Runs per Over = 6.09
# Inning 350: Total Runs = 164, Number of Overs = 21, Average Runs per Over = 7.81
# Inning 351: Total Runs = 147, Number of Overs = 21, Average Runs per Over = 7.00
# Inning 352: Total Runs = 106, Number of Overs = 21, Average Runs per Over = 5.05
# Inning 353: Total Runs = 156, Number of Overs = 22, Average Runs per Over = 7.09
# Inning 354: Total Runs = 127, Number of Overs = 21, Average Runs per Over = 6.05
# Inning 355: Total Runs = 148, Number of Overs = 19, Average Runs per Over = 7.79
# Inning 356: Total Runs = 144, Number of Overs = 19, Average Runs per Over = 7.58
# Inning 357: Total Runs = 197, Number of Overs = 21, Average Runs per Over = 9.38
# Inning 358: Total Runs = 169, Number of Overs = 21, Average Runs per Over = 8.05
# Inning 359: Total Runs = 164, Number of Overs = 21, Average Runs per Over = 7.81
# Inning 360: Total Runs = 139, Number of Overs = 21, Average Runs per Over = 6.62
# Inning 361: Total Runs = 175, Number of Overs = 21, Average Runs per Over = 8.33
# Inning 362: Total Runs = 136, Number of Overs = 21, Average Runs per Over = 6.48
# Inning 363: Total Runs = 155, Number of Overs = 21, Average Runs per Over = 7.38
# Inning 364: Total Runs = 156, Number of Overs = 21, Average Runs per Over = 7.43
# Inning 365: Total Runs = 138, Number of Overs = 21, Average Runs per Over = 6.57
# Inning 366: Total Runs = 139, Number of Overs = 20, Average Runs per Over = 6.95
# Inning 367: Total Runs = 160, Number of Overs = 21, Average Runs per Over = 7.62
# Inning 368: Total Runs = 162, Number of Overs = 21, Average Runs per Over = 7.71
# Inning 369: Total Runs = 157, Number of Overs = 21, Average Runs per Over = 7.48
# Inning 370: Total Runs = 158, Number of Overs = 20, Average Runs per Over = 7.90
# Inning 371: Total Runs = 146, Number of Overs = 20, Average Runs per Over = 7.30
# Inning 372: Total Runs = 145, Number of Overs = 21, Average Runs per Over = 6.90
# Inning 373: Total Runs = 131, Number of Overs = 17, Average Runs per Over = 7.71
# Inning 374: Total Runs = 199, Number of Overs = 20, Average Runs per Over = 9.95
# Inning 375: Total Runs = 195, Number of Overs = 21, Average Runs per Over = 9.29
# Inning 376: Total Runs = 185, Number of Overs = 21, Average Runs per Over = 8.81
# Inning 377: Total Runs = 190, Number of Overs = 21, Average Runs per Over = 9.05
# Inning 378: Total Runs = 101, Number of Overs = 18, Average Runs per Over = 5.61
# Inning 379: Total Runs = 165, Number of Overs = 21, Average Runs per Over = 7.86
# Inning 380: Total Runs = 147, Number of Overs = 21, Average Runs per Over = 7.00
# Inning 381: Total Runs = 182, Number of Overs = 21, Average Runs per Over = 8.67
# Inning 382: Total Runs = 134, Number of Overs = 21, Average Runs per Over = 6.38
# Inning 383: Total Runs = 147, Number of Overs = 22, Average Runs per Over = 6.68
# Inning 384: Total Runs = 144, Number of Overs = 18, Average Runs per Over = 8.00
# Inning 385: Total Runs = 142, Number of Overs = 21, Average Runs per Over = 6.76
# Inning 386: Total Runs = 201, Number of Overs = 21, Average Runs per Over = 9.57
# Inning 387: Total Runs = 123, Number of Overs = 17, Average Runs per Over = 7.24
# Inning 388: Total Runs = 208, Number of Overs = 22, Average Runs per Over = 9.45
# Inning 389: Total Runs = 204, Number of Overs = 21, Average Runs per Over = 9.71
# Inning 390: Total Runs = 147, Number of Overs = 20, Average Runs per Over = 7.35
# Inning 391: Total Runs = 16, Number of Overs = 3, Average Runs per Over = 5.33
# Inning 392: Total Runs = 138, Number of Overs = 20, Average Runs per Over = 6.90
# Inning 393: Total Runs = 140, Number of Overs = 12, Average Runs per Over = 11.67
# Inning 394: Total Runs = 141, Number of Overs = 21, Average Runs per Over = 6.71
# Inning 395: Total Runs = 142, Number of Overs = 20, Average Runs per Over = 7.10
# Inning 396: Total Runs = 136, Number of Overs = 21, Average Runs per Over = 6.48
# Inning 397: Total Runs = 137, Number of Overs = 18, Average Runs per Over = 7.61
# Inning 398: Total Runs = 171, Number of Overs = 21, Average Runs per Over = 8.14
# Inning 399: Total Runs = 196, Number of Overs = 21, Average Runs per Over = 9.33
# Inning 400: Total Runs = 155, Number of Overs = 22, Average Runs per Over = 7.05
# Inning 401: Total Runs = 158, Number of Overs = 18, Average Runs per Over = 8.78
# Inning 402: Total Runs = 200, Number of Overs = 21, Average Runs per Over = 9.52
# Inning 403: Total Runs = 152, Number of Overs = 21, Average Runs per Over = 7.24
# Inning 404: Total Runs = 120, Number of Overs = 17, Average Runs per Over = 7.06
# Inning 405: Total Runs = 119, Number of Overs = 20, Average Runs per Over = 5.95
# Inning 406: Total Runs = 133, Number of Overs = 16, Average Runs per Over = 8.31
# Inning 407: Total Runs = 172, Number of Overs = 21, Average Runs per Over = 8.19
# Inning 408: Total Runs = 184, Number of Overs = 21, Average Runs per Over = 8.76
# Inning 409: Total Runs = 163, Number of Overs = 21, Average Runs per Over = 7.76
# Inning 410: Total Runs = 142, Number of Overs = 21, Average Runs per Over = 6.76
# Inning 411: Total Runs = 8, Number of Overs = 1, Average Runs per Over = 8.00
# Inning 412: Total Runs = 142, Number of Overs = 21, Average Runs per Over = 6.76
# Inning 413: Total Runs = 12, Number of Overs = 1, Average Runs per Over = 12.00
# Inning 414: Total Runs = 150, Number of Overs = 21, Average Runs per Over = 7.14
# Inning 415: Total Runs = 161, Number of Overs = 21, Average Runs per Over = 7.67
# Inning 416: Total Runs = 194, Number of Overs = 21, Average Runs per Over = 9.24
# Inning 417: Total Runs = 195, Number of Overs = 21, Average Runs per Over = 9.29
# Inning 418: Total Runs = 186, Number of Overs = 22, Average Runs per Over = 8.45
# Inning 419: Total Runs = 174, Number of Overs = 21, Average Runs per Over = 8.29
# Inning 420: Total Runs = 157, Number of Overs = 20, Average Runs per Over = 7.85
# Inning 421: Total Runs = 156, Number of Overs = 21, Average Runs per Over = 7.43
# Inning 422: Total Runs = 137, Number of Overs = 16, Average Runs per Over = 8.56
# Inning 423: Total Runs = 134, Number of Overs = 21, Average Runs per Over = 6.38
# Inning 424: Total Runs = 130, Number of Overs = 17, Average Runs per Over = 7.65
# Inning 425: Total Runs = 129, Number of Overs = 21, Average Runs per Over = 6.14
# Inning 426: Total Runs = 179, Number of Overs = 17, Average Runs per Over = 10.53
# Inning 427: Total Runs = 180, Number of Overs = 19, Average Runs per Over = 9.47
# Inning 428: Total Runs = 238, Number of Overs = 22, Average Runs per Over = 10.82
# Inning 429: Total Runs = 166, Number of Overs = 22, Average Runs per Over = 7.55
# Inning 430: Total Runs = 25, Number of Overs = 3, Average Runs per Over = 8.33
# Inning 431: Total Runs = 156, Number of Overs = 20, Average Runs per Over = 7.80
# Inning 432: Total Runs = 153, Number of Overs = 21, Average Runs per Over = 7.29
# Inning 433: Total Runs = 164, Number of Overs = 20, Average Runs per Over = 8.20
# Inning 434: Total Runs = 163, Number of Overs = 20, Average Runs per Over = 8.15
# Inning 435: Total Runs = 173, Number of Overs = 21, Average Runs per Over = 8.24
# Inning 436: Total Runs = 177, Number of Overs = 21, Average Runs per Over = 8.43
# Inning 437: Total Runs = 131, Number of Overs = 19, Average Runs per Over = 6.89
# Inning 438: Total Runs = 184, Number of Overs = 21, Average Runs per Over = 8.76
# Inning 439: Total Runs = 215, Number of Overs = 22, Average Runs per Over = 9.77
# Inning 440: Total Runs = 219, Number of Overs = 21, Average Runs per Over = 10.43
# Inning 441: Total Runs = 208, Number of Overs = 21, Average Runs per Over = 9.90
# Inning 442: Total Runs = 144, Number of Overs = 18, Average Runs per Over = 8.00
# Inning 443: Total Runs = 156, Number of Overs = 21, Average Runs per Over = 7.43
# Inning 444: Total Runs = 106, Number of Overs = 20, Average Runs per Over = 5.30
# Inning 445: Total Runs = 142, Number of Overs = 22, Average Runs per Over = 6.45
# Inning 446: Total Runs = 143, Number of Overs = 16, Average Runs per Over = 8.94
# Inning 447: Total Runs = 144, Number of Overs = 21, Average Runs per Over = 6.86
# Inning 448: Total Runs = 210, Number of Overs = 21, Average Runs per Over = 10.00
# Inning 449: Total Runs = 142, Number of Overs = 17, Average Runs per Over = 8.35
# Inning 450: Total Runs = 173, Number of Overs = 19, Average Runs per Over = 9.11
# Inning 451: Total Runs = 76, Number of Overs = 10, Average Runs per Over = 7.60
# Inning 452: Total Runs = 141, Number of Overs = 11, Average Runs per Over = 12.82
# Inning 453: Total Runs = 183, Number of Overs = 21, Average Runs per Over = 8.71
# Inning 454: Total Runs = 179, Number of Overs = 22, Average Runs per Over = 8.14
# Inning 455: Total Runs = 147, Number of Overs = 21, Average Runs per Over = 7.00
# Inning 456: Total Runs = 146, Number of Overs = 21, Average Runs per Over = 6.95
# Inning 457: Total Runs = 192, Number of Overs = 19, Average Runs per Over = 10.11
# Inning 458: Total Runs = 191, Number of Overs = 21, Average Runs per Over = 9.10
# Inning 459: Total Runs = 201, Number of Overs = 21, Average Runs per Over = 9.57
# Inning 460: Total Runs = 232, Number of Overs = 21, Average Runs per Over = 11.05
# Inning 461: Total Runs = 200, Number of Overs = 21, Average Runs per Over = 9.52
# Inning 462: Total Runs = 155, Number of Overs = 21, Average Runs per Over = 7.38
# Inning 463: Total Runs = 155, Number of Overs = 20, Average Runs per Over = 7.75
# Inning 464: Total Runs = 154, Number of Overs = 21, Average Runs per Over = 7.33
# Inning 465: Total Runs = 169, Number of Overs = 21, Average Runs per Over = 8.05
# Inning 466: Total Runs = 166, Number of Overs = 21, Average Runs per Over = 7.90
# Inning 467: Total Runs = 144, Number of Overs = 21, Average Runs per Over = 6.86
# Inning 468: Total Runs = 145, Number of Overs = 17, Average Runs per Over = 8.53
# Inning 469: Total Runs = 169, Number of Overs = 20, Average Runs per Over = 8.45
# Inning 470: Total Runs = 164, Number of Overs = 21, Average Runs per Over = 7.81
# Inning 471: Total Runs = 130, Number of Overs = 16, Average Runs per Over = 8.12
# Inning 472: Total Runs = 124, Number of Overs = 21, Average Runs per Over = 5.90
# Inning 473: Total Runs = 164, Number of Overs = 21, Average Runs per Over = 7.81
# Inning 474: Total Runs = 166, Number of Overs = 19, Average Runs per Over = 8.74
# Inning 475: Total Runs = 158, Number of Overs = 19, Average Runs per Over = 8.32
# Inning 476: Total Runs = 156, Number of Overs = 21, Average Runs per Over = 7.43
# Inning 477: Total Runs = 177, Number of Overs = 21, Average Runs per Over = 8.43
# Inning 478: Total Runs = 185, Number of Overs = 21, Average Runs per Over = 8.81
# Inning 479: Total Runs = 188, Number of Overs = 22, Average Runs per Over = 8.55
# Inning 480: Total Runs = 224, Number of Overs = 21, Average Runs per Over = 10.67
# Inning 481: Total Runs = 130, Number of Overs = 18, Average Runs per Over = 7.22
# Inning 482: Total Runs = 129, Number of Overs = 21, Average Runs per Over = 6.14
# Inning 483: Total Runs = 108, Number of Overs = 17, Average Runs per Over = 6.35
# Inning 484: Total Runs = 111, Number of Overs = 21, Average Runs per Over = 5.29
# Inning 485: Total Runs = 180, Number of Overs = 21, Average Runs per Over = 8.57
# Inning 486: Total Runs = 91, Number of Overs = 20, Average Runs per Over = 4.55
# Inning 487: Total Runs = 189, Number of Overs = 21, Average Runs per Over = 9.00
# Inning 488: Total Runs = 188, Number of Overs = 20, Average Runs per Over = 9.40
# Inning 489: Total Runs = 140, Number of Overs = 22, Average Runs per Over = 6.36
# Inning 490: Total Runs = 141, Number of Overs = 15, Average Runs per Over = 9.40
# Inning 491: Total Runs = 205, Number of Overs = 19, Average Runs per Over = 10.79
# Inning 492: Total Runs = 203, Number of Overs = 21, Average Runs per Over = 9.67
# Inning 493: Total Runs = 149, Number of Overs = 22, Average Runs per Over = 6.77
# Inning 494: Total Runs = 144, Number of Overs = 20, Average Runs per Over = 7.20
# Inning 495: Total Runs = 132, Number of Overs = 22, Average Runs per Over = 6.00
# Inning 496: Total Runs = 165, Number of Overs = 21, Average Runs per Over = 7.86
# Inning 497: Total Runs = 117, Number of Overs = 21, Average Runs per Over = 5.57
# Inning 498: Total Runs = 159, Number of Overs = 21, Average Runs per Over = 7.57
# Inning 499: Total Runs = 140, Number of Overs = 21, Average Runs per Over = 6.67
# Inning 500: Total Runs = 189, Number of Overs = 21, Average Runs per Over = 9.00
# Inning 501: Total Runs = 198, Number of Overs = 22, Average Runs per Over = 9.00
# Inning 502: Total Runs = 150, Number of Overs = 21, Average Runs per Over = 7.14
# Inning 503: Total Runs = 193, Number of Overs = 21, Average Runs per Over = 9.19
# Inning 504: Total Runs = 148, Number of Overs = 18, Average Runs per Over = 8.22
# Inning 505: Total Runs = 183, Number of Overs = 21, Average Runs per Over = 8.71
# Inning 506: Total Runs = 136, Number of Overs = 21, Average Runs per Over = 6.48
# Inning 507: Total Runs = 131, Number of Overs = 21, Average Runs per Over = 6.24
# Inning 508: Total Runs = 134, Number of Overs = 14, Average Runs per Over = 9.57
# Inning 509: Total Runs = 160, Number of Overs = 21, Average Runs per Over = 7.62
# Inning 510: Total Runs = 117, Number of Overs = 19, Average Runs per Over = 6.16
# Inning 511: Total Runs = 131, Number of Overs = 21, Average Runs per Over = 6.24
# Inning 512: Total Runs = 134, Number of Overs = 20, Average Runs per Over = 6.70
# Inning 513: Total Runs = 103, Number of Overs = 21, Average Runs per Over = 4.90
# Inning 514: Total Runs = 104, Number of Overs = 18, Average Runs per Over = 5.78
# Inning 515: Total Runs = 171, Number of Overs = 22, Average Runs per Over = 7.77
# Inning 516: Total Runs = 170, Number of Overs = 21, Average Runs per Over = 8.10
# Inning 517: Total Runs = 204, Number of Overs = 22, Average Runs per Over = 9.27
# Inning 518: Total Runs = 224, Number of Overs = 21, Average Runs per Over = 10.67
# Inning 519: Total Runs = 193, Number of Overs = 22, Average Runs per Over = 8.77
# Inning 520: Total Runs = 159, Number of Overs = 21, Average Runs per Over = 7.57
# Inning 521: Total Runs = 162, Number of Overs = 22, Average Runs per Over = 7.36
# Inning 522: Total Runs = 179, Number of Overs = 22, Average Runs per Over = 8.14
# Inning 523: Total Runs = 149, Number of Overs = 22, Average Runs per Over = 6.77
# Inning 524: Total Runs = 138, Number of Overs = 21, Average Runs per Over = 6.57
# Inning 525: Total Runs = 99, Number of Overs = 21, Average Runs per Over = 4.71
# Inning 526: Total Runs = 118, Number of Overs = 21, Average Runs per Over = 5.62
# Inning 527: Total Runs = 165, Number of Overs = 21, Average Runs per Over = 7.86
# Inning 528: Total Runs = 141, Number of Overs = 20, Average Runs per Over = 7.05
# Inning 529: Total Runs = 164, Number of Overs = 21, Average Runs per Over = 7.81
# Inning 530: Total Runs = 126, Number of Overs = 20, Average Runs per Over = 6.30
# Inning 531: Total Runs = 132, Number of Overs = 21, Average Runs per Over = 6.29
# Inning 532: Total Runs = 133, Number of Overs = 20, Average Runs per Over = 6.65
# Inning 533: Total Runs = 81, Number of Overs = 21, Average Runs per Over = 3.86
# Inning 534: Total Runs = 82, Number of Overs = 16, Average Runs per Over = 5.12
# Inning 535: Total Runs = 160, Number of Overs = 21, Average Runs per Over = 7.62
# Inning 536: Total Runs = 161, Number of Overs = 16, Average Runs per Over = 10.06
# Inning 537: Total Runs = 166, Number of Overs = 21, Average Runs per Over = 7.90
# Inning 538: Total Runs = 150, Number of Overs = 21, Average Runs per Over = 7.14
# Inning 539: Total Runs = 167, Number of Overs = 22, Average Runs per Over = 7.59
# Inning 540: Total Runs = 166, Number of Overs = 22, Average Runs per Over = 7.55
# Inning 541: Total Runs = 146, Number of Overs = 21, Average Runs per Over = 6.95
# Inning 542: Total Runs = 167, Number of Overs = 21, Average Runs per Over = 7.95
# Inning 543: Total Runs = 168, Number of Overs = 22, Average Runs per Over = 7.64
# Inning 544: Total Runs = 143, Number of Overs = 21, Average Runs per Over = 6.81
# ...
# Inning 1702: Total Runs = 134, Number of Overs = 19, Average Runs per Over = 7.05
# Inning 1703: Total Runs = 60, Number of Overs = 10, Average Runs per Over = 6.00
# Inning 1704: Total Runs = 153, Number of Overs = 21, Average Runs per Over = 7.29
# Inning 1705: Total Runs = 176, Number of Overs = 21, Average Runs per Over = 8.38
# Inning 1706: Total Runs = 170, Number of Overs = 21, Average Runs per Over = 8.10
# Inning 1707: Total Runs = 166, Number of Overs = 21, Average Runs per Over = 7.90
# Inning 1708: Total Runs = 168, Number of Overs = 21, Average Runs per Over = 8.00
# Inning 1709: Total Runs = 120, Number of Overs = 21, Average Runs per Over = 5.71
# Inning 1710: Total Runs = 123, Number of Overs = 21, Average Runs per Over = 5.86
# Inning 1711: Total Runs = 117, Number of Overs = 20, Average Runs per Over = 5.85
# Inning 1712: Total Runs = 116, Number of Overs = 21, Average Runs per Over = 5.52
# Inning 1713: Total Runs = 85, Number of Overs = 20, Average Runs per Over = 4.25
# Inning 1714: Total Runs = 96, Number of Overs = 21, Average Runs per Over = 4.57
# Inning 1715: Total Runs = 165, Number of Overs = 21, Average Runs per Over = 7.86
# Inning 1716: Total Runs = 168, Number of Overs = 20, Average Runs per Over = 8.40
# Inning 1717: Total Runs = 231, Number of Overs = 22, Average Runs per Over = 10.50
# Inning 1718: Total Runs = 236, Number of Overs = 21, Average Runs per Over = 11.24
# Inning 1719: Total Runs = 97, Number of Overs = 15, Average Runs per Over = 6.47
# Inning 1720: Total Runs = 96, Number of Overs = 21, Average Runs per Over = 4.57
# Inning 1721: Total Runs = 117, Number of Overs = 16, Average Runs per Over = 7.31
# Inning 1722: Total Runs = 132, Number of Overs = 20, Average Runs per Over = 6.60
# Inning 1723: Total Runs = 126, Number of Overs = 20, Average Runs per Over = 6.30
# Inning 1724: Total Runs = 165, Number of Overs = 21, Average Runs per Over = 7.86
# Inning 1725: Total Runs = 31, Number of Overs = 5, Average Runs per Over = 6.20
# Inning 1726: Total Runs = 195, Number of Overs = 21, Average Runs per Over = 9.29
# Inning 1727: Total Runs = 126, Number of Overs = 21, Average Runs per Over = 6.00
# Inning 1728: Total Runs = 135, Number of Overs = 21, Average Runs per Over = 6.43
# Inning 1729: Total Runs = 140, Number of Overs = 20, Average Runs per Over = 7.00
# Inning 1730: Total Runs = 191, Number of Overs = 21, Average Runs per Over = 9.10
# Inning 1731: Total Runs = 135, Number of Overs = 17, Average Runs per Over = 7.94
# Inning 1732: Total Runs = 177, Number of Overs = 21, Average Runs per Over = 8.43
# Inning 1733: Total Runs = 182, Number of Overs = 21, Average Runs per Over = 8.67
# Inning 1734: Total Runs = 144, Number of Overs = 21, Average Runs per Over = 6.86
# Inning 1735: Total Runs = 127, Number of Overs = 20, Average Runs per Over = 6.35
# Inning 1736: Total Runs = 144, Number of Overs = 21, Average Runs per Over = 6.86
# Inning 1737: Total Runs = 145, Number of Overs = 20, Average Runs per Over = 7.25
# Inning 1738: Total Runs = 102, Number of Overs = 14, Average Runs per Over = 7.29
# Inning 1739: Total Runs = 101, Number of Overs = 21, Average Runs per Over = 4.81
# Inning 1740: Total Runs = 146, Number of Overs = 21, Average Runs per Over = 6.95
# Inning 1741: Total Runs = 145, Number of Overs = 21, Average Runs per Over = 6.90
# Inning 1742: Total Runs = 134, Number of Overs = 21, Average Runs per Over = 6.38
# Inning 1743: Total Runs = 135, Number of Overs = 21, Average Runs per Over = 6.43
# Inning 1744: Total Runs = 171, Number of Overs = 21, Average Runs per Over = 8.14
# Inning 1745: Total Runs = 172, Number of Overs = 16, Average Runs per Over = 10.75
# Inning 1746: Total Runs = 96, Number of Overs = 20, Average Runs per Over = 4.80
# Inning 1747: Total Runs = 148, Number of Overs = 21, Average Runs per Over = 7.05
# Inning 1748: Total Runs = 138, Number of Overs = 21, Average Runs per Over = 6.57
# Inning 1749: Total Runs = 169, Number of Overs = 21, Average Runs per Over = 8.05
# Inning 1750: Total Runs = 151, Number of Overs = 21, Average Runs per Over = 7.19
# Inning 1751: Total Runs = 152, Number of Overs = 19, Average Runs per Over = 8.00
# Inning 1752: Total Runs = 177, Number of Overs = 21, Average Runs per Over = 8.43
# Inning 1753: Total Runs = 145, Number of Overs = 21, Average Runs per Over = 6.90
# Inning 1754: Total Runs = 143, Number of Overs = 17, Average Runs per Over = 8.41
# Inning 1755: Total Runs = 141, Number of Overs = 21, Average Runs per Over = 6.71
# Inning 1756: Total Runs = 175, Number of Overs = 22, Average Runs per Over = 7.95
# Inning 1757: Total Runs = 146, Number of Overs = 21, Average Runs per Over = 6.95
# Inning 1758: Total Runs = 174, Number of Overs = 20, Average Runs per Over = 8.70
# Inning 1759: Total Runs = 172, Number of Overs = 21, Average Runs per Over = 8.19
# Inning 1760: Total Runs = 173, Number of Overs = 20, Average Runs per Over = 8.65
# Inning 1761: Total Runs = 172, Number of Overs = 21, Average Runs per Over = 8.19
# Inning 1762: Total Runs = 176, Number of Overs = 21, Average Runs per Over = 8.38
# Inning 1763: Total Runs = 175, Number of Overs = 21, Average Runs per Over = 8.33
# Inning 1764: Total Runs = 157, Number of Overs = 21, Average Runs per Over = 7.48
# Inning 1765: Total Runs = 158, Number of Overs = 20, Average Runs per Over = 7.90
# Inning 1766: Total Runs = 205, Number of Overs = 22, Average Runs per Over = 9.32
# Inning 1767: Total Runs = 204, Number of Overs = 21, Average Runs per Over = 9.71
# Inning 1768: Total Runs = 181, Number of Overs = 20, Average Runs per Over = 9.05
# Inning 1769: Total Runs = 178, Number of Overs = 21, Average Runs per Over = 8.48
# Inning 1770: Total Runs = 178, Number of Overs = 22, Average Runs per Over = 8.09
# Inning 1771: Total Runs = 124, Number of Overs = 21, Average Runs per Over = 5.90
# Inning 1772: Total Runs = 135, Number of Overs = 21, Average Runs per Over = 6.43
# Inning 1773: Total Runs = 145, Number of Overs = 21, Average Runs per Over = 6.90
# Inning 1774: Total Runs = 198, Number of Overs = 21, Average Runs per Over = 9.43
# Inning 1775: Total Runs = 118, Number of Overs = 21, Average Runs per Over = 5.62
# Inning 1776: Total Runs = 151, Number of Overs = 21, Average Runs per Over = 7.19
# Inning 1777: Total Runs = 188, Number of Overs = 22, Average Runs per Over = 8.55
# Inning 1778: Total Runs = 157, Number of Overs = 21, Average Runs per Over = 7.48
# Inning 1779: Total Runs = 184, Number of Overs = 21, Average Runs per Over = 8.76
# Inning 1780: Total Runs = 197, Number of Overs = 21, Average Runs per Over = 9.38
# Inning 1781: Total Runs = 200, Number of Overs = 22, Average Runs per Over = 9.09
# Inning 1782: Total Runs = 160, Number of Overs = 21, Average Runs per Over = 7.62
# Inning 1783: Total Runs = 146, Number of Overs = 21, Average Runs per Over = 6.95
# Inning 1784: Total Runs = 172, Number of Overs = 21, Average Runs per Over = 8.19
# Inning 1785: Total Runs = 169, Number of Overs = 22, Average Runs per Over = 7.68
# Inning 1786: Total Runs = 154, Number of Overs = 22, Average Runs per Over = 7.00
# Inning 1787: Total Runs = 4, Number of Overs = 1, Average Runs per Over = 4.00
# Inning 1788: Total Runs = 154, Number of Overs = 21, Average Runs per Over = 7.33
# Inning 1789: Total Runs = 3, Number of Overs = 1, Average Runs per Over = 3.00
# Inning 1790: Total Runs = 199, Number of Overs = 22, Average Runs per Over = 9.05
# Inning 1791: Total Runs = 200, Number of Overs = 21, Average Runs per Over = 9.52
# Inning 1792: Total Runs = 92, Number of Overs = 19, Average Runs per Over = 4.84
# Inning 1793: Total Runs = 96, Number of Overs = 18, Average Runs per Over = 5.33
# Inning 1794: Total Runs = 144, Number of Overs = 18, Average Runs per Over = 8.00
# Inning 1795: Total Runs = 140, Number of Overs = 21, Average Runs per Over = 6.67
# Inning 1796: Total Runs = 135, Number of Overs = 21, Average Runs per Over = 6.43
# Inning 1797: Total Runs = 139, Number of Overs = 16, Average Runs per Over = 8.69
# Inning 1798: Total Runs = 182, Number of Overs = 21, Average Runs per Over = 8.67
# Inning 1799: Total Runs = 179, Number of Overs = 21, Average Runs per Over = 8.52
# Inning 1800: Total Runs = 147, Number of Overs = 11, Average Runs per Over = 13.36
# Inning 1801: Total Runs = 142, Number of Overs = 21, Average Runs per Over = 6.76
# Inning 1802: Total Runs = 155, Number of Overs = 21, Average Runs per Over = 7.38
# Inning 1803: Total Runs = 171, Number of Overs = 21, Average Runs per Over = 8.14
# Inning 1804: Total Runs = 171, Number of Overs = 18, Average Runs per Over = 9.50
# Inning 1805: Total Runs = 168, Number of Overs = 22, Average Runs per Over = 7.64
# Inning 1806: Total Runs = 196, Number of Overs = 21, Average Runs per Over = 9.33
# Inning 1807: Total Runs = 101, Number of Overs = 17, Average Runs per Over = 5.94
# Inning 1808: Total Runs = 215, Number of Overs = 21, Average Runs per Over = 10.24
# Inning 1809: Total Runs = 185, Number of Overs = 21, Average Runs per Over = 8.81
# Inning 1810: Total Runs = 139, Number of Overs = 21, Average Runs per Over = 6.62
# Inning 1811: Total Runs = 162, Number of Overs = 21, Average Runs per Over = 7.71
# Inning 1812: Total Runs = 136, Number of Overs = 21, Average Runs per Over = 6.48
# Inning 1813: Total Runs = 123, Number of Overs = 21, Average Runs per Over = 5.86
# Inning 1814: Total Runs = 136, Number of Overs = 21, Average Runs per Over = 6.48
# Inning 1815: Total Runs = 121, Number of Overs = 21, Average Runs per Over = 5.76
# Inning 1816: Total Runs = 136, Number of Overs = 19, Average Runs per Over = 7.16
# Inning 1817: Total Runs = 131, Number of Overs = 20, Average Runs per Over = 6.55
# Inning 1818: Total Runs = 135, Number of Overs = 22, Average Runs per Over = 6.14
# Inning 1819: Total Runs = 136, Number of Overs = 21, Average Runs per Over = 6.48
# Inning 1820: Total Runs = 126, Number of Overs = 11, Average Runs per Over = 11.45
# Inning 1821: Total Runs = 107, Number of Overs = 10, Average Runs per Over = 10.70
# Inning 1822: Total Runs = 113, Number of Overs = 20, Average Runs per Over = 5.65
# Inning 1823: Total Runs = 119, Number of Overs = 20, Average Runs per Over = 5.95
# Inning 1824: Total Runs = 169, Number of Overs = 21, Average Runs per Over = 8.05
# Inning 1825: Total Runs = 170, Number of Overs = 21, Average Runs per Over = 8.10
# Inning 1826: Total Runs = 94, Number of Overs = 9, Average Runs per Over = 10.44
# Inning 1827: Total Runs = 79, Number of Overs = 19, Average Runs per Over = 4.16
# Inning 1828: Total Runs = 126, Number of Overs = 21, Average Runs per Over = 6.00
# Inning 1829: Total Runs = 182, Number of Overs = 21, Average Runs per Over = 8.67
# Inning 1830: Total Runs = 183, Number of Overs = 21, Average Runs per Over = 8.71
# Inning 1831: Total Runs = 146, Number of Overs = 21, Average Runs per Over = 6.95
# Inning 1832: Total Runs = 201, Number of Overs = 21, Average Runs per Over = 9.57
# Inning 1833: Total Runs = 134, Number of Overs = 21, Average Runs per Over = 6.38
# Inning 1834: Total Runs = 142, Number of Overs = 21, Average Runs per Over = 6.76
# Inning 1835: Total Runs = 230, Number of Overs = 22, Average Runs per Over = 10.45
# Inning 1836: Total Runs = 229, Number of Overs = 21, Average Runs per Over = 10.90
# Inning 1837: Total Runs = 119, Number of Overs = 17, Average Runs per Over = 7.00
# Inning 1838: Total Runs = 118, Number of Overs = 19, Average Runs per Over = 6.21
# Inning 1839: Total Runs = 122, Number of Overs = 21, Average Runs per Over = 5.81
# Inning 1840: Total Runs = 127, Number of Overs = 19, Average Runs per Over = 6.68
# Inning 1841: Total Runs = 157, Number of Overs = 19, Average Runs per Over = 8.26
# Inning 1842: Total Runs = 156, Number of Overs = 21, Average Runs per Over = 7.43
# Inning 1843: Total Runs = 180, Number of Overs = 21, Average Runs per Over = 8.57
# Inning 1844: Total Runs = 158, Number of Overs = 21, Average Runs per Over = 7.52
# Inning 1845: Total Runs = 145, Number of Overs = 21, Average Runs per Over = 6.90
# Inning 1846: Total Runs = 146, Number of Overs = 21, Average Runs per Over = 6.95
# Inning 1847: Total Runs = 193, Number of Overs = 21, Average Runs per Over = 9.19
# Inning 1848: Total Runs = 172, Number of Overs = 21, Average Runs per Over = 8.19
# Inning 1849: Total Runs = 122, Number of Overs = 21, Average Runs per Over = 5.81
# Inning 1850: Total Runs = 123, Number of Overs = 21, Average Runs per Over = 5.86
# Inning 1851: Total Runs = 70, Number of Overs = 16, Average Runs per Over = 4.38
# Inning 1852: Total Runs = 145, Number of Overs = 21, Average Runs per Over = 6.90
# Inning 1853: Total Runs = 171, Number of Overs = 21, Average Runs per Over = 8.14
# Inning 1854: Total Runs = 161, Number of Overs = 22, Average Runs per Over = 7.32
# Inning 1855: Total Runs = 160, Number of Overs = 22, Average Runs per Over = 7.27
# Inning 1856: Total Runs = 161, Number of Overs = 20, Average Runs per Over = 8.05
# Inning 1857: Total Runs = 122, Number of Overs = 19, Average Runs per Over = 6.42
# Inning 1858: Total Runs = 120, Number of Overs = 21, Average Runs per Over = 5.71
# Inning 1859: Total Runs = 159, Number of Overs = 18, Average Runs per Over = 8.83
# Inning 1860: Total Runs = 153, Number of Overs = 21, Average Runs per Over = 7.29
# Inning 1861: Total Runs = 192, Number of Overs = 21, Average Runs per Over = 9.14
# Inning 1862: Total Runs = 196, Number of Overs = 20, Average Runs per Over = 9.80
# Inning 1863: Total Runs = 155, Number of Overs = 21, Average Runs per Over = 7.38
# Inning 1864: Total Runs = 161, Number of Overs = 21, Average Runs per Over = 7.67
# Inning 1865: Total Runs = 166, Number of Overs = 20, Average Runs per Over = 8.30
# Inning 1866: Total Runs = 163, Number of Overs = 21, Average Runs per Over = 7.76
# Inning 1867: Total Runs = 167, Number of Overs = 21, Average Runs per Over = 7.95
# Inning 1868: Total Runs = 125, Number of Overs = 21, Average Runs per Over = 5.95
# Inning 1869: Total Runs = 156, Number of Overs = 21, Average Runs per Over = 7.43
# Inning 1870: Total Runs = 187, Number of Overs = 21, Average Runs per Over = 8.90
# Inning 1871: Total Runs = 162, Number of Overs = 20, Average Runs per Over = 8.10
# Inning 1872: Total Runs = 180, Number of Overs = 21, Average Runs per Over = 8.57
# Inning 1873: Total Runs = 101, Number of Overs = 21, Average Runs per Over = 4.81
# Inning 1874: Total Runs = 105, Number of Overs = 19, Average Runs per Over = 5.53
# Inning 1875: Total Runs = 196, Number of Overs = 22, Average Runs per Over = 8.91
# Inning 1876: Total Runs = 127, Number of Overs = 21, Average Runs per Over = 6.05
# Inning 1877: Total Runs = 84, Number of Overs = 14, Average Runs per Over = 6.00
# Inning 1878: Total Runs = 82, Number of Overs = 19, Average Runs per Over = 4.32
# Inning 1879: Total Runs = 121, Number of Overs = 21, Average Runs per Over = 5.76
# Inning 1880: Total Runs = 166, Number of Overs = 21, Average Runs per Over = 7.90
# Inning 1881: Total Runs = 85, Number of Overs = 17, Average Runs per Over = 5.00
# Inning 1882: Total Runs = 83, Number of Overs = 19, Average Runs per Over = 4.37
# Inning 1883: Total Runs = 147, Number of Overs = 21, Average Runs per Over = 7.00
# Inning 1884: Total Runs = 124, Number of Overs = 21, Average Runs per Over = 5.90
# Inning 1885: Total Runs = 142, Number of Overs = 20, Average Runs per Over = 7.10
# Inning 1886: Total Runs = 138, Number of Overs = 21, Average Runs per Over = 6.57
# Inning 1887: Total Runs = 131, Number of Overs = 20, Average Runs per Over = 6.55
# Inning 1888: Total Runs = 129, Number of Overs = 20, Average Runs per Over = 6.45
# Inning 1889: Total Runs = 151, Number of Overs = 20, Average Runs per Over = 7.55
# Inning 1890: Total Runs = 150, Number of Overs = 21, Average Runs per Over = 7.14
# Inning 1891: Total Runs = 120, Number of Overs = 16, Average Runs per Over = 7.50
# Inning 1892: Total Runs = 122, Number of Overs = 14, Average Runs per Over = 8.71
# Inning 1893: Total Runs = 263, Number of Overs = 21, Average Runs per Over = 12.52
# Inning 1894: Total Runs = 178, Number of Overs = 21, Average Runs per Over = 8.48
# Inning 1895: Total Runs = 130, Number of Overs = 19, Average Runs per Over = 6.84
# Inning 1896: Total Runs = 128, Number of Overs = 21, Average Runs per Over = 6.10

# %%
import pandas as pd

# Read the CSV file with the specified columns
df = pd.read_csv("merged_data.csv", usecols=['Col1', 'batter', 'total_runs_delivery', 'balls_faced', 'winning_team'])

# Identify the boundaries of each inning
inning_boundaries_indices = df[df['Col1'] == 0].index

# Append the end of the DataFrame as the last boundary
inning_boundaries_indices = list(inning_boundaries_indices) + [len(df)]

print("Inning Boundaries Indices:")
print(inning_boundaries_indices)

# Function to process each inning
def process_inning(df_inning):
    # Calculate the total runs
    total_runs = df_inning['total_runs_delivery'].sum()
    # Calculate the number of overs
    num_overs = (df_inning['Col1'].max() // 6) + 1
    # Calculate the average runs per over
    avg_runs_per_over = total_runs / num_overs
    return total_runs, num_overs, avg_runs_per_over

# List to store the results for each inning
inning_stats = []

# Iterate through each inning using the boundaries
for i in range(len(inning_boundaries_indices) - 1):
    start_idx = inning_boundaries_indices[i]
    end_idx = inning_boundaries_indices[i + 1]
    df_inning = df.iloc[start_idx:end_idx]
    total_runs, num_overs, avg_runs_per_over = process_inning(df_inning)
    inning_stats.append({
        'Inning': i + 1,
        'Total Runs': total_runs,
        'Number of Overs': num_overs,
        'Average Runs per Over': avg_runs_per_over
    })

# Create a DataFrame from the list of dictionaries
inning_stats_df = pd.DataFrame(inning_stats)

# Display the DataFrame
print(inning_stats_df)
# Out:
# Inning Boundaries Indices:
# [0, 125, 250, 373, 497, 622, 737, 866, 990, 1072, 1197, 1320, 1444, 1578, 1688, 1805, 1929, 2052, 2174, 2265, 2387, 2476, 2597, 2723, 2848, 2971, 3094, 3215, 3342, 3455, 3583, 3706, 3829, 3931, 4059, 4183, 4309, 4321, 4444, 4534, 4660, 4785, 4914, 5007, 5128, 5199, 5325, 5439, 5563, 5654, 5781, 5903, 6030, 6155, 6284, 6409, 6533, 6622, 6746, 6873, 6998, 7115, 7237, 7344, 7468, 7589, 7712, 7839, 7954, 8079, 8189, 8311, 8404, 8521, 8642, 8767, 8886, 9006, 9129, 9253, 9368, 9425, 9549, 9654, 9752, 9873, 9989, 10118, 10242, 10365, 10479, 10512, 10607, 10732, 10855, 10977, 11102, 11216, 11335, 11458, 11579, 11692, 11815, 11941, 12062, 12188, 12237, 12287, 12393, 12505, 12629, 12751, 12875, 12997, 13126, 13252, 13373, 13490, 13616, 13738, 13863, 13961, 14087, 14198, 14317, 14443, 14575, 14683, 14804, 14932, 15057, 15175, 15308, 15422, 15546, 15674, 15783, 15904, 16030, 16152, 16276, 16401, 16525, 16647, 16739, 16866, 16994, 17115, 17239, 17324, 17446, 17563, 17666, 17787, 17909, 18030, 18156, 18277, 18409, 18487, 18589, 18690, 18814, 18924, 18993, 19116, 19240, 19368, 19489, 19612, 19734, 19859, 19985, 20109, 20233, 20355, 20479, 20587, 20691, 20813, 20939, 21061, 21187, 21314, 21441, 21566, 21687, 21693, 21819, 21827, 21951, 22075, 22199, 22305, 22369, 22433, 22540, 22651, 22773, 22901, 23024, 23146, 23263, 23379, 23501, 23627, 23750, 23876, 23933, 24055, 24184, 24311, 24419, 24536, 24646, 24769, 24860, 24980, 25103, 25219, 25285, 25417, 25537, 25650, 25773, 25893, 26018, 26136, 26264, 26391, 26514, 26644, 26751, 26852, 26973, 27098, 27222, 27339, 27463, 27584, 27707, 27830, 27953, 28055, 28176, 28287, 28410, 28539, 28663, 28789, 28919, 29040, 29170, 29291, 29362, 29426, 29505, 29628, 29749, 29883, 30009, 30137, 30262, 30384, 30509, 30632, 30757, 30826, 30906, 31027, 31131, 31256, 31378, 31459, 31576, 31688, 31809, 31829, 31919, 32035, 32155, 32233, 32357, 32477, 32602, 32724, 32847, 32965, 33094, 33226, 33316, 33440, 33561, 33690, 33787, 33905, 34025, 34151, 34256, 34377, 34498, 34622, 34721, 34839, 34961, 35084, 35208, 35339, 35455, 35580, 35705, 35817, 35938, 36058, 36180, 36305, 36434, 36559, 36668, 36741, 36747, 36813, 36820, 36944, 37069, 37177, 37300, 37422, 37428, 37548, 37554, 37681, 37686, 37809, 37815, 37937, 38061, 38170, 38294, 38421, 38520, 38636, 38760, 38882, 39007, 39129, 39249, 39350, 39474, 39601, 39722, 39847, 39971, 40100, 40226, 40337, 40449, 40573, 40699, 40825, 40947, 41071, 41194, 41317, 41439, 41564, 41682, 41808, 41930, 42053, 42169, 42289, 42412, 42511, 42629, 42754, 42878, 43003, 43111, 43234, 43356, 43480, 43604, 43732, 43837, 43960, 44083, 44182, 44311, 44437, 44552, 44565, 44682, 44750, 44874, 44994, 45119, 45222, 45346, 45471, 45598, 45706, 45831, 45953, 46052, 46172, 46265, 46386, 46510, 46631, 46755, 46761, 46884, 46890, 47011, 47136, 47261, 47382, 47509, 47633, 47749, 47871, 47965, 48088, 48185, 48308, 48409, 48519, 48648, 48777, 48793, 48909, 49032, 49150, 49270, 49391, 49512, 49624, 49748, 49876, 50000, 50124, 50228, 50351, 50468, 50596, 50690, 50816, 50940, 51042, 51153, 51211, 51272, 51395, 51522, 51644, 51769, 51881, 52004, 52125, 52248, 52374, 52497, 52616, 52739, 52861, 52983, 53106, 53208, 53327, 53449, 53544, 53666, 53791, 53900, 54012, 54135, 54259, 54383, 54514, 54636, 54744, 54869, 54969, 55093, 55218, 55337, 55462, 55582, 55709, 55794, 55903, 56024, 56154, 56273, 56400, 56523, 56644, 56765, 56888, 57011, 57142, 57264, 57390, 57498, 57622, 57744, 57867, 57951, 58077, 58191, 58314, 58432, 58553, 58656, 58784, 58908, 59035, 59160, 59288, 59413, 59540, 59667, 59796, 59918, 60043, 60164, 60286, 60406, 60531, 60647, 60772, 60892, 61015, 61107, 61230, 61324, 61449, 61573, 61703, 61833, 61958, 62082, 62210, 62336, 62437, 62562, 62688, 62816, 62943, 63038, 63168, 63294, 63423, 63556, 63612, 63737, 63861, 63869, 63887, 64011, 64129, 64253, 64256, 64378, 64384, 64486, 64611, 64726, 64847, 64973, 65097, 65218, 65333, 65456, 65583, 65707, 65828, 65953, 66077, 66198, 66316, 66437, 66560, 66676, 66 ...
#       Inning  Total Runs  Number of Overs  Average Runs per Over
# 0          1         168               21               8.000000
# 1          2         172               21               8.190476
# 2          3         173               21               8.238095
# 3          4         176               21               8.380952
# 4          5         187               21               8.904762
# ...      ...         ...              ...                    ...
# 1891    1892         122               14               8.714286
# 1892    1893         263               21              12.523810
# 1893    1894         178               21               8.476190
# 1894    1895         130               19               6.842105
# 1895    1896         128               21               6.095238
#
# [1896 rows x 4 columns]

# %%
import pandas as pd

# Read the CSV file with the specified columns
df = pd.read_csv("merged_data.csv", usecols=['Col1', 'batter', 'total_runs_delivery', 'balls_faced', 'winning_team', 'current_team_total'])

# Identify the boundaries of each inning
inning_boundaries_indices = df[df['Col1'] == 0].index

# Append the end of the DataFrame as the last boundary
inning_boundaries_indices = list(inning_boundaries_indices) + [len(df)]

print("Inning Boundaries Indices:")
print(inning_boundaries_indices)

# Function to process each inning
def process_inning(df_inning):
    # Calculate the total runs
    total_runs = df_inning['total_runs_delivery'].sum()
    # Calculate the number of overs
    num_overs = (df_inning['Col1'].max() // 6) + 1
    # Calculate the average runs per over
    avg_runs_per_over = total_runs / num_overs
    # Extract the final team score
    final_team_score = df_inning['current_team_total'].iloc[-1]
    return final_team_score, avg_runs_per_over

# List to store the results for each inning
inning_stats = []

# Iterate through each inning using the boundaries
for i in range(len(inning_boundaries_indices) - 1):
    start_idx = inning_boundaries_indices[i]
    end_idx = inning_boundaries_indices[i + 1]
    df_inning = df.iloc[start_idx:end_idx]
    final_team_score, avg_runs_per_over = process_inning(df_inning)
    inning_stats.append({
        'Inning': i + 1,
        'Final Team Score': final_team_score,
        'Average Runs per Over': avg_runs_per_over
    })

# Create a DataFrame from the list of dictionaries
inning_stats_df = pd.DataFrame(inning_stats)

# Plot final team score vs average runs per over
plt.figure(figsize=(10, 6))
plt.scatter(inning_stats_df['Final Team Score'], inning_stats_df['Average Runs per Over'], color='blue')
plt.xlabel('Final Team Score')
plt.ylabel('Average Runs per Over')
plt.title('Final Team Score vs Average Runs per Over')
plt.grid(True)
plt.show()
# Out:
# Inning Boundaries Indices:
# [0, 125, 250, 373, 497, 622, 737, 866, 990, 1072, 1197, 1320, 1444, 1578, 1688, 1805, 1929, 2052, 2174, 2265, 2387, 2476, 2597, 2723, 2848, 2971, 3094, 3215, 3342, 3455, 3583, 3706, 3829, 3931, 4059, 4183, 4309, 4321, 4444, 4534, 4660, 4785, 4914, 5007, 5128, 5199, 5325, 5439, 5563, 5654, 5781, 5903, 6030, 6155, 6284, 6409, 6533, 6622, 6746, 6873, 6998, 7115, 7237, 7344, 7468, 7589, 7712, 7839, 7954, 8079, 8189, 8311, 8404, 8521, 8642, 8767, 8886, 9006, 9129, 9253, 9368, 9425, 9549, 9654, 9752, 9873, 9989, 10118, 10242, 10365, 10479, 10512, 10607, 10732, 10855, 10977, 11102, 11216, 11335, 11458, 11579, 11692, 11815, 11941, 12062, 12188, 12237, 12287, 12393, 12505, 12629, 12751, 12875, 12997, 13126, 13252, 13373, 13490, 13616, 13738, 13863, 13961, 14087, 14198, 14317, 14443, 14575, 14683, 14804, 14932, 15057, 15175, 15308, 15422, 15546, 15674, 15783, 15904, 16030, 16152, 16276, 16401, 16525, 16647, 16739, 16866, 16994, 17115, 17239, 17324, 17446, 17563, 17666, 17787, 17909, 18030, 18156, 18277, 18409, 18487, 18589, 18690, 18814, 18924, 18993, 19116, 19240, 19368, 19489, 19612, 19734, 19859, 19985, 20109, 20233, 20355, 20479, 20587, 20691, 20813, 20939, 21061, 21187, 21314, 21441, 21566, 21687, 21693, 21819, 21827, 21951, 22075, 22199, 22305, 22369, 22433, 22540, 22651, 22773, 22901, 23024, 23146, 23263, 23379, 23501, 23627, 23750, 23876, 23933, 24055, 24184, 24311, 24419, 24536, 24646, 24769, 24860, 24980, 25103, 25219, 25285, 25417, 25537, 25650, 25773, 25893, 26018, 26136, 26264, 26391, 26514, 26644, 26751, 26852, 26973, 27098, 27222, 27339, 27463, 27584, 27707, 27830, 27953, 28055, 28176, 28287, 28410, 28539, 28663, 28789, 28919, 29040, 29170, 29291, 29362, 29426, 29505, 29628, 29749, 29883, 30009, 30137, 30262, 30384, 30509, 30632, 30757, 30826, 30906, 31027, 31131, 31256, 31378, 31459, 31576, 31688, 31809, 31829, 31919, 32035, 32155, 32233, 32357, 32477, 32602, 32724, 32847, 32965, 33094, 33226, 33316, 33440, 33561, 33690, 33787, 33905, 34025, 34151, 34256, 34377, 34498, 34622, 34721, 34839, 34961, 35084, 35208, 35339, 35455, 35580, 35705, 35817, 35938, 36058, 36180, 36305, 36434, 36559, 36668, 36741, 36747, 36813, 36820, 36944, 37069, 37177, 37300, 37422, 37428, 37548, 37554, 37681, 37686, 37809, 37815, 37937, 38061, 38170, 38294, 38421, 38520, 38636, 38760, 38882, 39007, 39129, 39249, 39350, 39474, 39601, 39722, 39847, 39971, 40100, 40226, 40337, 40449, 40573, 40699, 40825, 40947, 41071, 41194, 41317, 41439, 41564, 41682, 41808, 41930, 42053, 42169, 42289, 42412, 42511, 42629, 42754, 42878, 43003, 43111, 43234, 43356, 43480, 43604, 43732, 43837, 43960, 44083, 44182, 44311, 44437, 44552, 44565, 44682, 44750, 44874, 44994, 45119, 45222, 45346, 45471, 45598, 45706, 45831, 45953, 46052, 46172, 46265, 46386, 46510, 46631, 46755, 46761, 46884, 46890, 47011, 47136, 47261, 47382, 47509, 47633, 47749, 47871, 47965, 48088, 48185, 48308, 48409, 48519, 48648, 48777, 48793, 48909, 49032, 49150, 49270, 49391, 49512, 49624, 49748, 49876, 50000, 50124, 50228, 50351, 50468, 50596, 50690, 50816, 50940, 51042, 51153, 51211, 51272, 51395, 51522, 51644, 51769, 51881, 52004, 52125, 52248, 52374, 52497, 52616, 52739, 52861, 52983, 53106, 53208, 53327, 53449, 53544, 53666, 53791, 53900, 54012, 54135, 54259, 54383, 54514, 54636, 54744, 54869, 54969, 55093, 55218, 55337, 55462, 55582, 55709, 55794, 55903, 56024, 56154, 56273, 56400, 56523, 56644, 56765, 56888, 57011, 57142, 57264, 57390, 57498, 57622, 57744, 57867, 57951, 58077, 58191, 58314, 58432, 58553, 58656, 58784, 58908, 59035, 59160, 59288, 59413, 59540, 59667, 59796, 59918, 60043, 60164, 60286, 60406, 60531, 60647, 60772, 60892, 61015, 61107, 61230, 61324, 61449, 61573, 61703, 61833, 61958, 62082, 62210, 62336, 62437, 62562, 62688, 62816, 62943, 63038, 63168, 63294, 63423, 63556, 63612, 63737, 63861, 63869, 63887, 64011, 64129, 64253, 64256, 64378, 64384, 64486, 64611, 64726, 64847, 64973, 65097, 65218, 65333, 65456, 65583, 65707, 65828, 65953, 66077, 66198, 66316, 66437, 66560, 66676, 66 ...
